# %%
import pandas as pd

# %%
hazard = pd.read_csv("hwgenids.csv")

# %%
hazard
# Out:
#                                  Name             2nd Name  \
# 0                  1010 DENTAL ON ELM                  NaN
# 1             102ND INTELLIGENCE WING  OTIS AIR FORCE BASE
# 2               1030 SOUTH STREET LLC                  NaN
# 3                   1071 MAIN ST SITE                  NaN
# 4      1160 ROCKDALE AVE REALTY TRUST                  NaN
# 5                           123 MOBIL                  NaN
# 6                  128 NEWTON GAS DBA   A&E 128 SOUTH CORP
# 7                128 OLDSMOBILE MAZDA                  NaN
# 8                            128 TIRE                  NaN
# 9                      128 VOLVO SAAB                  NaN
# 10                  1366 TECHNOLOGIES                  NaN
# 11                 1600 OSGOOD ST LLC                  NaN
# 12                  1812 PAINT & BODY                  NaN
# 13                            1A AUTO                  NaN
# 14                        1A AUTO WAY                  NaN
# ...
