# %%
#Importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Input data files are available in the "../input/" directory.
import os
import matplotlib.pyplot as plt#visualization
from PIL import  Image
# %matplotlib inline
import pandas as pd
import seaborn as sns#visualization
import itertools
import warnings
warnings.filterwarnings("ignore")
import io
import plotly.offline as py#visualization
py.init_notebook_mode(connected=True)#visualization
import plotly.graph_objs as go#visualization
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# Read csv data file
rv = pd.read_csv("Revere Crash Data 2001-2016.csv")
wt = pd.read_csv("Revere Weather Data 1990-2018.csv")

# %%
rv.head()
# Out:
#    Crash Number  Crash Date Crash Time          Crash Hour City/Town Locality  \
# 0       1403053  11/25/2001    9:30 PM  09:00PM to 09:59PM    REVERE   REVERE
# 1       1403045  11/23/2001   11:47 PM  11:00PM to 11:59PM    REVERE   REVERE
# 2       1403048  11/25/2001    7:05 AM  07:00AM to 07:59AM    REVERE   REVERE
# 3       1401357  11/19/2001    6:19 PM  06:00PM to 06:59PM    REVERE   REVERE
# 4       1401360  11/19/2001    6:00 PM  06:00PM to 06:59PM    REVERE   REVERE
#
#   RPA Abbreviation  MassHighway District    Crash Severity  \
# 0             MAPC                     4  Non-fatal injury
# 1             MAPC                     4  Non-fatal injury
# 2             MAPC                     4  Non-fatal injury
# 3             MAPC                     4  Non-fatal injury
# 4             MAPC                     4  Non-fatal injury
#
#         Maximum Injury Severity Reported            ...             \
# 0  Non-fatal injury - Non-incapacitating            ...
# 1  Non-fatal injury - Non-incapacitating            ...
# 2  Non-fatal injury - Non-incapacitating            ...
# 3            Non-fatal injury - Possible            ...
# 4            Non-fatal injury - Possible            ...
#
#    Crash Status  Road Segment ID   County                   RMV Document #  \
# 0        Closed         325377.0  SUFFOLK                   PR200200300335
# 1        Closed         325724.0  SUFFOLK                   PR200200300333
# 2        Closed              NaN  SUFFOLK                   PR200200300334
# 3        Closed         325962.0  SUFFOLK  PR200134000814 / OR200210600140
# 4        Closed              NaN  SUFFOLK                   PR200134000815
#
#   Driver Distracted By Age of Non-Motorist - Youngest Known  \
# 0                  NaN                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                                  NaN
# 3                  NaN                                  NaN
# 4                  NaN                                  NaN
#
#   Age of Non-Motorist - Oldest Known Report IDs  \
# 0                                NaN        NaN
# 1                                NaN        NaN
# 2                                NaN        NaN
# 3                                NaN        NaN
# 4                                NaN        NaN
#
#   Federal Functional Classification Roadway Contributing Code
# 0                   Major Collector              Not reported
# 1                   Major Collector              Not reported
# 2                               NaN              Not reported
# 3        Principal Arterial - Other              Not reported
# 4                               NaN              Not reported
#
# [5 rows x 81 columns]

# %%
wt.head()
# Out:
#        STATION           NAME  LATITUDE  LONGITUDE  ELEVATION      DATE  ACMH  \
# 0  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  1/1/1990  50.0
# 1  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  1/2/1990  20.0
# 2  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  1/3/1990  10.0
# 3  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  1/4/1990  70.0
# 4  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  1/5/1990  30.0
#
#     ACSH   AWND    PGTM  ...   WT11  WT13  WT14  WT15  WT16  WT17  WT18  WT19  \
# 0   60.0  21.92  1303.0  ...    NaN   NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 1   50.0  17.67  1051.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   10.0  10.74   159.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  100.0  15.21  1941.0  ...    NaN   NaN   1.0   NaN   1.0   NaN   NaN   NaN
# 4   60.0  13.20   428.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WT21  WT22
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN
#
# [5 rows x 40 columns]

# %%
number = rv['Crash Number']

# %%
weather = rv['Weather Condition']

# %%
road = rv['Road Surface']
light = rv['Ambient Light']

# %%
def union(R, S):
    return R + S


def difference(R, S):
    return [t for t in R if t not in S]


def intersect(R, S):
    return [t for t in R if t in S]


def project(R, p):
    return [p(t) for t in R]


def select(R, s):
    # type: (object, object) -> object
    return [t for t in R if s(t)]


def product(R, S):
    return [(t, u) for t in R for u in S]


def aggregate(R, f):
    keys = {r[0] for r in R}
    return [(key, f([v for (k, v) in R if k == key])) for key in keys]

# %%
A = rv[['Crash Number','Crash Date','Crash Severity','Ambient Light']]

# %%
A.to_csv('table1.csv')

# %%
B = wt[['DATE','PRCP','SNOW','SNWD','TSUN','WT01']]

# %%
left = pd.DataFrame({'Date':A['Crash Date'],
                    'Crash Number':A['Crash Number'],'Crash Severity':A['Crash Severity'],'Ambient Light':A['Ambient Light']})
right = pd.DataFrame({'Date':wt['DATE'],'Snow':B['SNOW'],'Precipation':B['PRCP'],'Snow Dpeth':B['SNWD'],'Fog':B['WT01']})

result = pd.merge(left,right,on='Date')
result.fillna(0)
# Out:
#              Date  Crash Number                       Crash Severity  \
# 0      11/25/2001       1403053                     Non-fatal injury
# 1      11/25/2001       1403048                     Non-fatal injury
# 2      11/25/2001       1402888                     Non-fatal injury
# 3      11/25/2001       1430169                         Not Reported
# 4      11/25/2001       1424639                         Not Reported
# 5      11/25/2001       1444751                         Not Reported
# 6      11/25/2001       1457103                         Not Reported
# 7      11/25/2001       1460054                     Non-fatal injury
# 8      11/23/2001       1403045                     Non-fatal injury
# 9      11/23/2001       1443254                              Unknown
# 10     11/23/2001       1444950  Property damage only (none injured)
# 11     11/23/2001       1460445  Property damage only (none injured)
# 12     11/19/2001       1401357                     Non-fatal injury
# 13     11/19/2001       1401360                     Non-fatal injury
# 14     11/19/2001       1433984                         Not Reported
# 15     11/19/2001       1448935                         Not Reported
# 16     11/19/2001       1458408                         Not Reported
# 17     11/19/2001       1462835                         Not Reported
# 18     11/20/2001       1403023                     Non-fatal injury
# 19     11/20/2001       1445649                         Not Reported
# 20     11/20/2001       1490554                         Not Reported
# 21      11/9/2001       1400524                         Not Reported
# 22      11/9/2001       1457169  Property damage only (none injured)
# 23      11/9/2001       1459292                         Not Reported
# 24     11/16/2001       1401351                     Non-fatal injury
# 25     11/16/2001       1401354                     Non-fatal injury
# 26     11/15/2001       1401356                     Non-fatal injury
# 27     11/15/2001       1456847                     Non-fatal injury
# 28     11/15/2001       1459551                         Not Reported
# 29     12/25/2001       1406308                         Not Reported
# ...           ...           ...                                  ...
# 12805  12/17/2016       4311778  Property damage only (none injured)
# 12806  12/20/2016       4308049  Property damage only (none injured)
# 12807  12/22/2016       4310088                     Non-fatal injury
# 12808  12/23/2016       4310089  Property damage only (none injured)
# 12809  12/23/2016       4310091  Property damage only (none injured)
# 12810  12/23/2016       4311782  Property damage only (none injured)
# 12811  12/25/2016       4310090  Property damage only (none injured)
# 12812  12/25/2016       4311784  Property damage only (none injured)
# 12813  12/25/2016       4332745                         Fatal injury
# 12814  12/24/2016       4310092  Property damage only (none injured)
# 12815  12/24/2016       4310093                     Non-fatal injury
# 12816  12/24/2016       4311861  Property damage only (none injured)
# 12817  12/21/2016       4310094                     Non-fatal injury
# 12818  12/19/2016       4310095  Property damage only (none injured)
# 12819  12/19/2016       4310096                     Non-fatal injury
# 12820  12/19/2016       4310097  Property damage only (none injured)
# 12821  12/19/2016       4310099  Property damage only (none injured)
# 12822  12/19/2016       4310101                     Non-fatal injury
# 12823   12/5/2016       4311764  Property damage only (none injured)
# 12824   12/5/2016       4311766  Property damage only (none injured)
# 12825  12/13/2016       4311770  Property damage only (none injured)
# 12826  12/27/2016       4311786  Property damage only (none injured)
# 12827  12/30/2016       4311790                     Non-fatal injury
# 12828  12/30/2016       4311791  Property damage only (none injured)
# 12829  12/30/2016       4312047  Property damage only (none injured)
# 12830  12/30/2016       4315717                     Non-fatal injury
# 12831  12/14/2016       4315300  Property damage only (none injured)
# 12832  12/26/2016       4315307  Property damage only (none injured)
# 12833  12/28/2016       4315722  Property damage only (none injured)
# 12834   3/31/2016       4326618  Property damage only (none injured)
#
#                          Ambient Light  Snow  Precipation  Snow Dpeth  Fog
# 0               Dark - lighted roadway   0.0         0.08         0.0  1.0
# 1                             Daylight   0.0         0.08         0.0  1.0
# 2               Dark - lighted roadway   0.0         0.08         0.0  1.0
# 3               Dark - lighted roadway   0.0         0.08         0.0  1.0
# 4               Dark - lighted roadway   0.0         0.08         0.0  1.0
# 5                             Daylight   0.0         0.08         0.0  1.0
# 6                             Daylight   0.0         0.08         0.0  1.0
# 7                             Daylight   0.0         0.08         0.0  1.0
# 8               Dark - lighted roadway   0.0         0.00         0.0  1.0
# 9                             Daylight   0.0         0.00         0.0  1.0
# 10              Dark - lighted roadway   0.0         0.00         0.0  1.0
# 11                            Daylight   0.0         0.00         0.0  1.0
# 12              Dark - lighted roadway   0.0         0.00         0.0  0.0
# 13                            Daylight   0.0         0.00         0.0  0.0
# 14                            Daylight   0.0         0.00         0.0  0.0
# 15                            Daylight   0.0         0.00         0.0  0.0
# 16                            Daylight   0.0         0.00         0.0  0.0
# 17     Dark - unknown roadway lighting   0.0         0.00         0.0  0.0
# 18                            Daylight   0.0         0.02         0.0  0.0
# 19                                Dawn   0.0         0.02         0.0  0.0
# 20                            Daylight   0.0         0.02         0.0  0.0
# 21                                   0   0.0         0.05         0.0  1.0
# 22                            Daylight   0.0         0.05         0.0  1.0
# 23                            Daylight   0.0         0.05         0.0  1.0
# 24                            Daylight   0.0         0.00         0.0  0.0
# 25              Dark - lighted roadway   0.0         0.00         0.0  0.0
# 26                            Daylight   0.0         0.00         0.0  1.0
# 27                            Daylight   0.0         0.00         0.0  1.0
# 28                                Dusk   0.0         0.00         0.0  1.0
# 29              Dark - lighted roadway   0.0         0.00         0.0  0.0
# ...                                ...   ...          ...         ...  ...
# 12805           Dark - lighted roadway   4.3         0.53         0.0  1.0
# 12806                         Daylight   0.0         0.00         0.0  0.0
# 12807           Dark - lighted roadway   0.0         0.02         0.0  1.0
# 12808           Dark - lighted roadway   0.0         0.00         0.0  0.0
# 12809                         Daylight   0.0         0.00         0.0  0.0
# 12810                         Daylight   0.0         0.00         0.0  0.0
# 12811           Dark - lighted roadway   0.0         0.00         0.0  0.0
# 12812                         Daylight   0.0         0.00         0.0  0.0
# 12813       Dark - roadway not lighted   0.0         0.00         0.0  0.0
# 12814                         Daylight   0.0         0.38         0.0  1.0
# 12815                             Dawn   0.0         0.38         0.0  1.0
# 12816       Dark - roadway not lighted   0.0         0.38         0.0  1.0
# 12817           Dark - lighted roadway   0.0         0.00         0.0  0.0
# 12818                         Daylight   0.0         0.00         0.0  0.0
# 12819                             Dusk   0.0         0.00         0.0  0.0
# 12820           Dark - lighted roadway   0.0         0.00         0.0  0.0
# 12821           Dark - lighted roadway   0.0         0.00         0.0  0.0
# 12822                         Daylight   0.0         0.00         0.0  0.0
# 12823           Dark - lighted roadway   0.3         0.14         0.0  1.0
# 12824           Dark - lighted roadway   0.3         0.14         0.0  1.0
# 12825                         Daylight   0.0         0.00         0.0  0.0
# 12826       Dark - roadway not lighted   0.0         0.00         0.0  0.0
# 12827                         Daylight   0.0         0.00         0.0  0.0
# 12828                         Daylight   0.0         0.00         0.0  0.0
# 12829           Dark - lighted roadway   0.0         0.00         0.0  0.0
# 12830                         Daylight   0.0         0.00         0.0  0.0
# 12831                         Daylight   0.0         0.00         0.0  0.0
# 12832           Dark - lighted roadway   0.0         0.01         0.0  1.0
# 12833           Dark - lighted roadway   0.0         0.00         0.0  0.0
# 12834                     Not reported   0.0         0.00         0.0  0.0
#
# [12835 rows x 8 columns]

# %%
for t in result:
    print(t)
# Out:
# Date
# Crash Number
# Crash Severity
# Ambient Light
# Snow
# Precipation
# Snow Dpeth
# Fog

# %%
#labels
lab = rv["Road Surface"].value_counts().keys().tolist()
#values
val = rv["Road Surface"].value_counts().values.tolist()

trace = go.Pie(labels = lab ,
               values = val ,
               marker = dict(colors =  [ 'royalblue' ,'lime'],
                             line = dict(color = "white",
                                         width =  1.3)
                            ),
               rotation = 90,
               hoverinfo = "label+value+text",
               hole = .5
              )
layout = go.Layout(dict(title = "Customer attrition in data",
                        plot_bgcolor  = "rgb(243,243,243)",
                        paper_bgcolor = "rgb(243,243,243)",
                       )
                  )

data = [trace]
fig = go.Figure(data = data,layout = layout)
py.iplot(fig)
# Out:
# <div id="4d7e245e-48ab-47e2-974e-89ec366925a3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4d7e245e-48ab-47e2-974e-89ec366925a3", [{"hole": 0.5, "hoverinfo": "label+value+text", "labels": ["Dry", "Wet", "Not reported", "Snow", "Ice", "Slush", "Sand, mud, dirt, oil, gravel", "Unknown", "Water (standing, moving)", "Other"], "marker": {"colors": ["royalblue", "lime"], "line": {"color": "white", "width": 1.3}}, "rotation": 90, "values": [8802, 2743, 545, 330, 220, 50, 45, 41, 36, 23], "type": "pie", "uid": "5acbf96c-86e0-47d9-98a3-4bc6a04fc699"}], {"paper_bgcolor": "rgb(243,243,243)", "plot_bgcolor": "rgb(243,243,243)", "title": {"text": "Customer attrition in data"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("4d7e245e-48ab-47e2-974e-89ec366925a3"));});</script>
