# %%
import pandas as pd
import requests
import json
import dml
import prov.model
import datetime
import uuid
import csv 
from io import StringIO
import json
import pymongo
import numpy as np

import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans

# %%
contributor = 'mmao95_Dongyihe_weijiang_zhukk'
reads = [contributor + '.streetbook_filtered']
writes = [contributor + '.street_clustered_location']

# %%
startTime = datetime.datetime.now()

# Set up the database connection.
client = dml.pymongo.MongoClient()
repo = client.repo
repo.authenticate(contributor, contributor)
# Out:
# True

# %%
streetbook_filtered_list = list(repo[reads[0]].find())
streetbook_filtered_df = pd.DataFrame(streetbook_filtered_list)
streetbook_filtered_list = np.array(streetbook_filtered_df).tolist()

street_lat_long = pd.read_csv("http://datamechanics.io/data/roads_2013_jzi.csv").values.tolist()

# %%
print(streetbook_filtered_list[0])
print(street_lat_long[0])
# Out:
# ['Adamson Street,', 'Adamson', '02134', ObjectId('5cc64b271877df93d4e8badf')]
# ['roads_2013_jzi.1', 'MULTILINESTRING ((-71.158407 42.260028, -71.158463 42.260158))', 25, 25, 85728971, 205866436, 205862089, 'S1400', 'Stimson St', 2758.0, nan, nan, nan, nan, nan, nan, 15.16, 5, 5, 0, 0, 'None', 250251304043.0, 25025130404.0]

# %%
# process street latitude and longitude dataset
street_lat_long_data = [(fullName, location, length) for (fId, location, s, c, tl, tf, tf2, m, fullName,
                                                    sm, lf, lt, rf, rt, zi, zipr, length, classGroup, r,
                                                    cluster, m, zone, bg, ct) in street_lat_long]

# print(street_lat_long[0])
lat_long_df = pd.DataFrame(street_lat_long_data)
lat_long_df.columns = ['fullName', 'location', 'length']
lat_long_df = lat_long_df.dropna()

# %%
lat_long_list = np.array(lat_long_df).tolist()
print(lat_long_list[0])
# Out:
# ['Stimson St', 'MULTILINESTRING ((-71.158407 42.260028, -71.158463 42.260158))', 15.16]

# %%
# normalize latitude and longitude list
for i in range(0, len(lat_long_list)):
    lat_long_list[i][1] = lat_long_list[i][1][18 : -2]

for i in range(0, len(lat_long_list)):
    pairs = lat_long_list[i][1].split(',')
    for j in range(0, len(pairs)):
        pairs[j] = pairs[j].lstrip()
    
    pair_tuple = []
    for j in range(0, len(pairs)):
        str = pairs[j].split(' ')
        pair_tuple.append([float(str[0]), float(str[1])])
    lat_long_list[i][1] = pair_tuple

print(len(lat_long_list))
# Out:
# 20233

# %%
# aggregate same street name
def aggregate(R, f):
    keys = {r[0] for r in R}
    return [(key, f([v for (k,v) in R if k == key])) for key in keys]

# %%
# lat_long_list = [(fullName, (location, length)) for (fullName, location, length) in lat_long_list]
name_unique = np.array(lat_long_df['fullName'].unique()).tolist()
street_agg_list = [[fullName, [], 0] for fullName in name_unique]
print(type(street_agg_list[0][1]))
print(type(lat_long_list[0][1]))
for i in range(0, len(street_agg_list)):
    for j in range(0, len(lat_long_list)):
        if(street_agg_list[i][0] == lat_long_list[j][0]):
            street_agg_list[i][1].extend(lat_long_list[j][1])
            street_agg_list[i][2] += lat_long_list[j][2]
            
print(street_agg_list[4])
# Out:
# <class 'list'>
# <class 'list'>
# ['Weymouth Ave', [[-71.151772, 42.266096], [-71.151862, 42.266202], [-71.15186199999998, 42.266201999999986], [-71.15228499999999, 42.266504999999995], [-71.15292599999998, 42.267053999999995], [-71.153097, 42.26720799999999]], 165.29]

# %%
# process datasets for K means
output_street_location = []
for i in range(0, len(street_agg_list)):
    count1 = 0
    count2 = 0
    for j in range(0, len(street_agg_list[i][1])):
        count1 += street_agg_list[i][1][j][0]
        count2 += street_agg_list[i][1][j][1]
    output_street_location += [[street_agg_list[i][0], count1 / len(street_agg_list[i][1]), count2 / len(street_agg_list[i][1]), street_agg_list[i][2]]]
print(len(output_street_location))
# Out:
# 4567

# %%
long_lat_list = [(long, lat) for (fullName, long, lat, length) in output_street_location]
long_lat_df = pd.DataFrame(long_lat_list)
long_lat_df.columns = ['long', 'lat']
x = long_lat_df['long']
y = long_lat_df['lat']
colors = np.random.rand(len(long_lat_df))
plt.figure(figsize=(20,20))
plt.scatter(x, y,c = colors, alpha = 0.5)
plt.show()

# %%
# set datasets into 34 clusters
X = long_lat_df
X = X[~np.isnan(X)]

#K means Clustering 
def doKmeans(X, nclust):
    model = KMeans(nclust)
    model.fit(X)
    clust_labels = model.predict(X)
    cent = model.cluster_centers_
    return (clust_labels, cent)

clust_labels, cent = doKmeans(X, 23)
kmeans = pd.DataFrame(clust_labels)
X.insert((X.shape[1]),'kmeans',kmeans)

#Plot the clusters obtained using k means
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111)
scatter = ax.scatter(X['long'],X['lat'],
                     c = kmeans[0],s = 50)
ax.set_title('K-Means Clustering')
ax.set_xlabel('Long')
ax.set_ylabel('Lat')
plt.colorbar(scatter)

# %%
kmeans_list = np.array(kmeans).tolist()
for i in range(0, len(output_street_location)):
    output_street_location[i] += (kmeans_list[i])

print(output_street_location)
# Out:
# [['Stimson St', -71.16210674358973, 42.261810846153836, 992.73, 19], ['Grove St', -71.14318346969696, 42.27903903030301, 1704.0800000000002, 0], ['Washington St', -71.10704185440608, 42.309478670498066, 26210.980000000003, 6], ['Rockingham Ave', -71.15560211764705, 42.264634764705875, 312.82, 19], ['Weymouth Ave', -71.15230066666666, 42.266544499999995, 165.29, 19], ['Vershire St', -71.14684733333333, 42.2715701111111, 201.7, 19], ['Cowing St', -71.14794948, 42.2738862, 616.0899999999999, 19], ['Buchanan Rd', -71.13697786206896, 42.29539620689655, 601.33, 8], ['Centre St', -71.12502912400633, 42.298888465818784, 14643.889999999998, 6], ['Starbird Ave', -71.11480442857143, 42.28472528571428, 263.24, 8], ['Neponset Ave', -71.06856199999997, 42.283470074829914, 3973.0900000000006, 17], ['Canterbury St', -71.11038266911767, 42.2851104632353, 3395.15, 8], ['American Legion Hwy', -71.10496155502388, 42.286906392344505, 7878.700000000001, 5], ['Jalleison St', -71.1166894, 42.276050399999995, 131.61, 8], ['Morton St', -71.09174303583059, 42.289817605863185, 8367.330000000002, 13], ['Park Dr', -71.10033554666671, 42.34360799333333, 2768.8499999999995, 10], ['Jersey St', -71.097496, 42.34383400000001, 588.47, 10], ['Cambridge St', -71.10797288501733, 42.36118009059235, 6169.089999999997, 10], ['Reservation Rd', -71.13100195588233, 42.25121555882353, 1344.7700000000004, 4], ['W Broadway', -71.05286693617019, 42.34010482978723, 1415.5700000000002, 2], ['Pleasant St', -71.07109134831461, 42.31275620224719, 1769.1100000000001, 18], ['I- 93', -71.05710214121696, 42.33838680597008, 26071.890000000018, 2], ['Cummins Hwy', -71.1096645177305, 42.275202184397145, 3662.02, 5], ['Sumner Ter', -71.06161775, 42.319224500000004, 61.22, 18], ['Sumner St', -71.04481120987653, 42.35231783950616, 1882.7800000000004, 16], ['Sylvester Rd', -71.0475485, 42.2846525, 193.17, 9], ['Riverway', -71.11342683251227, 42.333558881773406, 3826.9900000000002, 10], ['City Sq', -71.0616501764706, 42.371880411764714, 187.36, 7], ['Maurice Tobin Brg', -71.05479398113206, 42.37738911320755, 1878.3499999999997, 7], ['Chelsea St', -71.04348012244895, 42.376918585034005, 4122.569999999999, 21], ['Blue Hill Ave', -71.0868982286432, 42.29563076130653, 11576.14, 13], ['Kensington Park', -71.08203075, 42.321007249999994, 77.7, 1], ['Warren St', -71.08425041441434, 42.33113166666666, 5070.780000000001, 1], ['Storrow Memorial Dr', -71.08867384302326, 42.35274957558141, 6635.769999999999, 22], ['Cahners Pl', -71.07281819999999, 42.3480732, 54.5, 22], ['Commonwealth Ave', -71.12872206708589, 42.34691370230609, 24264.400000000005, 3], ['Kneeland St', -71.06000653571428, 42.35022064285714, 514.5199999999999, 16], ['Addison St', -71.01614633333332, 42.385275666666665, 431.99, 11], ['Austin St', -71.08460018382354, 42.34205403676472, 2445.4599999999996, 22], ['N380', -71.05219972413794, 42.343047879310326, 1278.53, 2], ['Embankment Rd', -71.0709785038168, 42.36251135877861, 2454.6600000000003, 16], ['Huntington Ave', -71.0960596428571, 42.33287251360547, 8590.670000000004, 10], ['St Botolph St', -71.083997902439, 42.34235865853658, 1019.3400000000001, 22], ['Prentiss St', -71.09333406666664, 42.33354133333332, 307.21, 10], ['William T Morrissey Blvd', -71.04719885964909, 42.30156228421053, 8254.320000000002, 9], ['Boston-Providence Tpke', -71.17010153086419, 42.267311469135805, 2153.36, 19], ['Pilgrim Rd', -71.10815237209304, 42.33960725581395, 806.19, 10], ['Leverett Connector S', -71.0690872295082, 42.3727551967213, 1258.8600000000001, 7], ['I- 90', -71.07168307391767, 42.354107874340045, 30227.650000000005, 22], ['Fulton St', -71.09032538095236, 42.30384304761904, 429.79999999999995, 13], ['Seaport Blvd', -71.04703853488371, 42.35255810465116, 1924.2899999999997, 16], ['Weld St', -71.14780701923077, 42.29317278846152, 2636.3199999999993, 0], ['Callahan Tunl', -71.04758079687498, 42.36688018749998, 1753.34, 16], ['N Beacon St', -71.15332058124996, 42.35730549374996, 3006.1499999999996,  ...

# %%
print(len(output_street_location))
print(output_street_location[4])
# Out:
# 4567
# ['Weymouth Ave', -71.15230066666666, 42.266544499999995, 165.29, 19]

# %%
street_clustered = [[cluster, fullName] for (fullName, long, lat, length, cluster) in output_street_location]
later_use = street_clustered
street_clustered = [[cluster, name] for (cluster, fullName1) in street_clustered 
                    for (fullName2, name, zipcode, id) in streetbook_filtered_list if fullName2.startswith(fullName1)]

# print(street_clustered)
# print(len(street_clustered))

result = [[i, ] for i in range(0, 23)]
for i in range(0, 23):
    for j in range(0, len(street_clustered)):
        if(i == street_clustered[j][0]):
            result[i] += [street_clustered[j][1]]

# print(result[0])
# print(len(result[0]))

# for i in range(0, 23):
#     str = ""
#     for j in range(1, len(result[i])):
#         str += result[i][j] + ","
#     result[i] = [i, str]
print(result)
print(len(result))
# Out:
# [[0, 'Berwick', 'Porter', 'Newfield', 'Glenham', 'Lasell', 'Vermont', 'Chellman', 'Westover', 'Cerdan', 'Pender', 'March', 'Rutledge', 'March', 'Pelton', 'Stratford', 'Colbert', 'Colberg', 'Ardent', 'Edgemont', 'Tennyson', 'Landseer', 'Perham', 'Lyall', 'Ruskin', 'Grayfield', 'Dent', 'Westmount', 'Richwood', 'Landseer', 'Aldrich', 'Clement', 'Burard', 'Houston', 'Broadlawn', 'Brucewood', 'Sanborn', 'Wolfe', 'Potomac', 'Maxfield', 'March', 'Hackensack', 'Thurlow', 'Elgin', 'Graham', 'Ellswood', 'Caspar', 'Carlson', 'Montview', 'Chapin', 'Lyall', 'Durant', 'Capital', 'Kirk', 'Allenwood', 'Bradwood'], [1, 'Dubois', 'Seaver', 'Seaver', 'Howland', 'Tileston', 'Tileston', 'Dearborn', 'Hampden', 'Copeland', 'Burton', 'Dunreath', 'Julian', 'Stafford', 'Gerard', 'Farnham', 'Langdon', 'Burgess', 'Rusfield', 'Sunderland', 'Laredo', 'Thornton', 'Clifton', 'Deckard', 'Ballard', 'Edgewood', 'Kearsarge', 'Moreland', 'Cedric', 'Partridge', 'Judson', 'Leyland', 'Wabeno', 'Otisfield', 'Perth', 'Dorr', 'Millmont', 'Guild', 'Crispus', 'Elbert', 'Akron', 'Kavanaugh', 'Regent', 'Akron', 'Bower', 'Copeland', 'Regent', 'Keegan', 'Roswell', 'Wabon', 'Dunkeld', 'Stanwood', 'Greenheys', 'Logan', 'Munroe', 'Mayfair', 'Creston', 'Balfour', 'Dalkeith', 'Maywood', 'Woodward', 'Gayland', 'Woodledge', 'Hartwell', 'Woodcliff', 'Blanchard', 'Hulbert', 'Maywood', 'Fairland', 'Jarvis', 'Dalin', 'Lester', 'Shabazz', 'Marvin', 'Irwin', 'Irwin', 'Half', 'Woodford', 'Rockledge', 'Fenwick', 'Weldon', 'Stanwood', 'Fenno', 'Regent', 'Edgewood', 'Bard', 'Presby', 'Rockford', 'Newman'], [2, 'Newmarket', 'Binford', 'Damrell', 'Wendeller', 'Burke', 'Cottrell', 'Athens', 'Gustin', 'Iron', 'Cypher', 'Woodward', 'Woodward', 'Earl', 'Mercer', 'Mercer', 'Pacific', 'Covington', 'Rawson', 'Dyer', 'Costello', 'Wormwood', 'Ewer', 'Gifford', 'Patterson', 'Dixfield', 'Carpenter', 'Von', 'Wendell', 'Humboldt', 'Transit', 'Knowlton', 'Grimes', 'Washburn', 'Tuckerman', 'Lovis', 'Rogers', 'Jenkins'], [3, 'Hooker', 'Hichborn', 'Gordon', 'Pomeroy', 'Saunders', 'Spurr', 'Bertram', 'Myrick', 'Farrington', 'Armington', 'Quint', 'Feneno', 'Ashford', 'Athol', 'Wadsworth', 'Windom', 'Kelton', 'Antwerp', 'Guilford', 'Melvin', 'Craftsman', 'Pratt', 'Manton', 'Raymond', 'Babcock', 'McDonald', 'Higgins', 'Portsmouth', 'Duval', 'Bradbury', 'Adamson', 'Telford', 'Ashford', 'Harvester', 'Travis', 'Holman', 'Redford', 'Amboy', 'Ascot', 'Clevemont', 'Appian', 'Mackin', 'Brentwood', 'Alcott', 'Bayard', 'Barrows', 'Vinal', 'Woodstock', 'Walbridge', 'Benson', 'Malvern', 'Harry', 'Fiske', 'Ridgemont', 'Arden', 'Islington', 'Lothrop', 'Wilton'], [4, 'Lawton', 'Chesterfield', 'Perkins', 'Stanbro', 'Knight', 'Glenwood', 'Glenwood', 'Colchester', 'Damon', 'Van', 'Van', 'Fairview', 'Ernest', 'Alvarado', 'Brainard', 'Lawton', 'Waterloo'], [5, 'Clifford', 'Clifford', 'Canaan', 'Kennebec', 'Oakwood', 'Oakwood', 'Hebron', 'Woolson', 'Fessenden', 'Almont', 'Woodhaven', 'Rexford', 'Edgewater', 'Colorado', 'Croydon', 'Harmon', 'Ormond', 'Viking', 'Verrill', 'Crown', 'Poydras', 'Caton', 'Mattakeeset', 'Hollingsworth', 'Hallowell', 'Frazer', 'Frazer', 'Pleasantview', 'Sefton', 'Gilmer', 'Culbert', 'Fairlawn', 'Fremont', 'Banfield', 'Errol', 'Arborcrest', 'Holmfield', 'Rockway', 'Leston', 'Halborn', 'Jamestown'], [6, 'Meehan', 'Whitcomb', 'Arborway', 'Barlow', 'Wilton', 'Wilton', 'Arborway', 'Ballard', 'Seaverns', 'Alveston', 'Newbern', 'Anson', 'Bismarck', 'Bismarck', 'Ellis', 'Ellis', 'Gartland', 'Bardwell', 'Weld', 'Regent', 'Burnett', 'Plainfield', 'Woodman', 'Lochstead', 'Custer', 'Rodman', 'Spalding', 'Atwood', 'Jaeger', 'Patten', 'Lester', 'Greenview', 'Boynton', 'Woodlawn', 'Alveston', 'Craft', 'Aldworth', 'Shurland'], [7, 'Alford', 'Hamblen', 'Cordis', 'Cordis', 'Walford', 'Blaban', 'Cook', 'Cook', 'Holden', 'Polk', 'Arrow', 'Phipps', 'Caldwell', 'Mishawum', 'Dexter', 'Roland', 'Cordis', 'Devens', 'Lawnwood', 'Hathon', 'Holston', 'Ludlow', 'Ellwood', 'Albion'], [8, 'Hillock', 'Penfield', 'Walworth', 'Albano', 'Birc ...
# 23

# %%
# for i in range(0, 23):
#     str = ""
#     for j in range(1, len(result[i])):
#         str += result[i][j]
#         str += ","
#     result[i] = [i, str]
# print(result)

# %%
# generate csv file
# street_agg_list
street_agg_df = pd.DataFrame(street_agg_list)
street_agg_df.columns = ['Full Name', 'Longitude and Latitude', 'Street Length']
street_agg_df.to_csv("/Users/zjallenjiang/Documents/GitHub/street_agg.csv")
# output_street_location
output_street_location_df = pd.DataFrame(output_street_location)
output_street_location_df.columns = ['Full Name', 'Longitude', 'Latitude', 'Street Length', 'Cluster']
output_street_location_df.to_csv("/Users/zjallenjiang/Documents/GitHub/street_location.csv")
# result
result_df = pd.DataFrame(result) 
# result_df.columns = ['Cluster', 'Names']
result_df.to_csv("/Users/zjallenjiang/Documents/GitHub/street_clustered.csv")
result_df.to_json(path_or_buf = "/Users/zjallenjiang/Documents/GitHub/street_clustered.json", orient="records")

# %%
data = json.loads(output_street_location_df.to_json(orient="records"))
repo.dropCollection('street_clustered_location')
repo.createCollection('street_clustered_location')
repo[writes[0]].insert_many(data)

# %%
repo[writes[0]].metadata({'complete': True})
print(repo[writes[0]].metadata())
[record for record in repo[writes[0]].find()]
# Out:
# {'_id': ObjectId('5cc64f121877df94dfc0d6de'), 'complete': True}
# [{'_id': ObjectId('5cc64f121877df94dfc0c507'),
#   'Full Name': 'Stimson St',
#   'Longitude': -71.1621067436,
#   'Latitude': 42.2618108462,
#   'Street Length': 992.73,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c508'),
#   'Full Name': 'Grove St',
#   'Longitude': -71.1431834697,
#   'Latitude': 42.2790390303,
#   'Street Length': 1704.08,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c509'),
#   'Full Name': 'Washington St',
#   'Longitude': -71.1070418544,
#   'Latitude': 42.3094786705,
#   'Street Length': 26210.98,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c50a'),
#   'Full Name': 'Rockingham Ave',
#   'Longitude': -71.1556021176,
#   'Latitude': 42.2646347647,
#   'Street Length': 312.82,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c50b'),
#   'Full Name': 'Weymouth Ave',
#   'Longitude': -71.1523006667,
#   'Latitude': 42.2665445,
#   'Street Length': 165.29,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c50c'),
#   'Full Name': 'Vershire St',
#   'Longitude': -71.1468473333,
#   'Latitude': 42.2715701111,
#   'Street Length': 201.7,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c50d'),
#   'Full Name': 'Cowing St',
#   'Longitude': -71.14794948,
#   'Latitude': 42.2738862,
#   'Street Length': 616.09,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c50e'),
#   'Full Name': 'Buchanan Rd',
#   'Longitude': -71.1369778621,
#   'Latitude': 42.2953962069,
#   'Street Length': 601.33,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c50f'),
#   'Full Name': 'Centre St',
#   'Longitude': -71.125029124,
#   'Latitude': 42.2988884658,
#   'Street Length': 14643.89,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c510'),
#   'Full Name': 'Starbird Ave',
#   'Longitude': -71.1148044286,
#   'Latitude': 42.2847252857,
#   'Street Length': 263.24,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c511'),
#   'Full Name': 'Neponset Ave',
#   'Longitude': -71.068562,
#   'Latitude': 42.2834700748,
#   'Street Length': 3973.09,
#   'Cluster': 17},
#  {'_id': ObjectId('5cc64f121877df94dfc0c512'),
#   'Full Name': 'Canterbury St',
#   'Longitude': -71.1103826691,
#   'Latitude': 42.2851104632,
#   'Street Length': 3395.15,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c513'),
#   'Full Name': 'American Legion Hwy',
#   'Longitude': -71.104961555,
#   'Latitude': 42.2869063923,
#   'Street Length': 7878.7,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c514'),
#   'Full Name': 'Jalleison St',
#   'Longitude': -71.1166894,
#   'Latitude': 42.2760504,
#   'Street Length': 131.61,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c515'),
#   'Full Name': 'Morton St',
#   'Longitude': -71.0917430358,
#   'Latitude': 42.2898176059,
#   'Street Length': 8367.33,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c516'),
#   'Full Name': 'Park Dr',
#   'Longitude': -71.1003355467,
#   'Latitude': 42.3436079933,
#   'Street Length': 2768.85,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c517'),
#   'Full Name': 'Jersey St',
#   'Longitude': -71.097496,
#   'Latitude': 42.343834,
#   'Street Length': 588.47,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c518'),
#   'Full Name': 'Cambridge St',
#   'Longitude': -71.107972885,
#   'Latitude': 42.3611800906,
#   'Street Length': 6169.09,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c519'),
#   'Full Name': 'Reservation Rd',
#   'Longitude': -71.1310019559,
#   'Latitude': 42.2512155588,
#   'Street Length': 1344.77,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c51a'),
#   'Full Name': 'W Broadway',
#   'Longitude': -71.0528669362,
#   'Latitude': 42.3401048298,
#   'Street Length': 1415.57,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c51b'),
#   'Full Name': 'Pleasant St',
#   'Longitude': -71.0710913483,
#   'Latitude': 42.3127562022,
#   'Street Length': 1769.11,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c51c'),
#   'Full Name': 'I- 93',
#   'Longitude': -71.0571021412,
#   'Latitude': 42.338386806,
#   'Street Length': 26071.89,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c51d'),
#   'Full Name': 'Cummins Hwy',
#   'Longitude': -71.1096645177,
#   'Latitude': 42.2752021844,
#   'Street Length': 3662.02,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c51e'),
#   'Full Name': 'Sumner Ter',
#   'Longitude': -71.06161775,
#   'Latitude': 42.3192245,
#   'Street Length': 61.22,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c51f'),
#   'Full Name': 'Sumner St',
#   'Longitude': -71.0448112099,
#   'Latitude': 42.3523178395,
#   'Street Length': 1882.78,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c520'),
#   'Full Name': 'Sylvester Rd',
#   'Longitude': -71.0475485,
#   'Latitude': 42.2846525,
#   'Street Length': 193.17,
#   'Cluster': 9},
#  {'_id': ObjectId('5cc64f121877df94dfc0c521'),
#   'Full Name': 'Riverway',
#   'Longitude': -71.1134268325,
#   'Latitude': 42.3335588818,
#   'Street Length': 3826.99,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c522'),
#   'Full Name': 'City Sq',
#   'Longitude': -71.0616501765,
#   'Latitude': 42.3718804118,
#   'Street Length': 187.36,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c523'),
#   'Full Name': 'Maurice Tobin Brg',
#   'Longitude': -71.0547939811,
#   'Latitude': 42.3773891132,
#   'Street Length': 1878.35,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c524'),
#   'Full Name': 'Chelsea St',
#   'Longitude': -71.0434801224,
#   'Latitude': 42.376918585,
#   'Street Length': 4122.57,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c525'),
#   'Full Name': 'Blue Hill Ave',
#   'Longitude': -71.0868982286,
#   'Latitude': 42.2956307613,
#   'Street Length': 11576.14,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c526'),
#   'Full Name': 'Kensington Park',
#   'Longitude': -71.08203075,
#   'Latitude': 42.32100725,
#   'Street Length': 77.7,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c527'),
#   'Full Name': 'Warren St',
#   'Longitude': -71.0842504144,
#   'Latitude': 42.3311316667,
#   'Street Length': 5070.78,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c528'),
#   'Full Name': 'Storrow Memorial Dr',
#   'Longitude': -71.088673843,
#   'Latitude': 42.3527495756,
#   'Street Length': 6635.77,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c529'),
#   'Full Name': 'Cahners Pl',
#   'Longitude': -71.0728182,
#   'Latitude': 42.3480732,
#   'Street Length': 54.5,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c52a'),
#   'Full Name': 'Commonwealth Ave',
#   'Longitude': -71.1287220671,
#   'Latitude': 42.3469137023,
#   'Street Length': 24264.4,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c52b'),
#   'Full Name': 'Kneeland St',
#   'Longitude': -71.0600065357,
#   'Latitude': 42.3502206429,
#   'Street Length': 514.52,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c52c'),
#   'Full Name': 'Addison St',
#   'Longitude': -71.0161463333,
#   'Latitude': 42.3852756667,
#   'Street Length': 431.99,
#   'Cluster': 11},
#  {'_id': ObjectId('5cc64f121877df94dfc0c52d'),
#   'Full Name': 'Austin St',
#   'Longitude': -71.0846001838,
#   'Latitude': 42.3420540368,
#   'Street Length': 2445.46,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c52e'),
#   'Full Name': 'N380',
#   'Longitude': -71.0521997241,
#   'Latitude': 42.3430478793,
#   'Street Length': 1278.53,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c52f'),
#   'Full Name': 'Embankment Rd',
#   'Longitude': -71.0709785038,
#   'Latitude': 42.3625113588,
#   'Street Length': 2454.66,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c530'),
#   'Full Name': 'Huntington Ave',
#   'Longitude': -71.0960596429,
#   'Latitude': 42.3328725136,
#   'Street Length': 8590.67,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c531'),
#   'Full Name': 'St Botolph St',
#   'Longitude': -71.0839979024,
#   'Latitude': 42.3423586585,
#   'Street Length': 1019.34,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c532'),
#   'Full Name': 'Prentiss St',
#   'Longitude': -71.0933340667,
#   'Latitude': 42.3335413333,
#   'Street Length': 307.21,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c533'),
#   'Full Name': 'William T Morrissey Blvd',
#   'Longitude': -71.0471988596,
#   'Latitude': 42.3015622842,
#   'Street Length': 8254.32,
#   'Cluster': 9},
#  {'_id': ObjectId('5cc64f121877df94dfc0c534'),
#   'Full Name': 'Boston-Providence Tpke',
#   'Longitude': -71.1701015309,
#   'Latitude': 42.2673114691,
#   'Street Length': 2153.36,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c535'),
#   'Full Name': 'Pilgrim Rd',
#   'Longitude': -71.1081523721,
#   'Latitude': 42.3396072558,
#   'Street Length': 806.19,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c536'),
#   'Full Name': 'Leverett Connector S',
#   'Longitude': -71.0690872295,
#   'Latitude': 42.3727551967,
#   'Street Length': 1258.86,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c537'),
#   'Full Name': 'I- 90',
#   'Longitude': -71.0716830739,
#   'Latitude': 42.3541078743,
#   'Street Length': 30227.65,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c538'),
#   'Full Name': 'Fulton St',
#   'Longitude': -71.090325381,
#   'Latitude': 42.3038430476,
#   'Street Length': 429.8,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c539'),
#   'Full Name': 'Seaport Blvd',
#   'Longitude': -71.0470385349,
#   'Latitude': 42.3525581047,
#   'Street Length': 1924.29,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c53a'),
#   'Full Name': 'Weld St',
#   'Longitude': -71.1478070192,
#   'Latitude': 42.2931727885,
#   'Street Length': 2636.32,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c53b'),
#   'Full Name': 'Callahan Tunl',
#   'Longitude': -71.0475807969,
#   'Latitude': 42.3668801875,
#   'Street Length': 1753.34,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c53c'),
#   'Full Name': 'N Beacon St',
#   'Longitude': -71.1533205812,
#   'Latitude': 42.3573054937,
#   'Street Length': 3006.15,
#   'Cluster': 12},
#  {'_id': ObjectId('5cc64f121877df94dfc0c53d'),
#   'Full Name': 'Hamilton St',
#   'Longitude': -71.08091105,
#   'Latitude': 42.2924697,
#   'Street Length': 1317.04,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c53e'),
#   'Full Name': 'Clifford St',
#   'Longitude': -71.1091941579,
#   'Latitude': 42.2704902632,
#   'Street Length': 855.21,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c53f'),
#   'Full Name': 'Lawton St',
#   'Longitude': -71.1284691667,
#   'Latitude': 42.235014,
#   'Street Length': 190.99,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c540'),
#   'Full Name': 'Hooker St',
#   'Longitude': -71.12849305,
#   'Latitude': 42.3584243,
#   'Street Length': 415.83,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c541'),
#   'Full Name': 'Sorrento St',
#   'Longitude': -71.12493925,
#   'Latitude': 42.3589535,
#   'Street Length': 81.15,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c542'),
#   'Full Name': 'Saratoga St',
#   'Longitude': -71.0152275146,
#   'Latitude': 42.3827842039,
#   'Street Length': 4311.55,
#   'Cluster': 11},
#  {'_id': ObjectId('5cc64f121877df94dfc0c543'),
#   'Full Name': 'Henderson Rd',
#   'Longitude': -71.0548215,
#   'Latitude': 42.2832331667,
#   'Street Length': 172.54,
#   'Cluster': 9},
#  {'_id': ObjectId('5cc64f121877df94dfc0c544'),
#   'Full Name': 'Corbet St',
#   'Longitude': -71.0833985714,
#   'Latitude': 42.2822365714,
#   'Street Length': 363.62,
#   'Cluster': 17},
#  {'_id': ObjectId('5cc64f121877df94dfc0c545'),
#   'Full Name': 'Airport Rd - Arrival Level',
#   'Longitude': -71.0192555435,
#   'Latitude': 42.3661877174,
#   'Street Length': 934.28,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c546'),
#   'Full Name': 'Ditmus Ct',
#   'Longitude': -71.08245,
#   'Latitude': 42.3371925,
#   'Street Length': 61.6,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c547'),
#   'Full Name': 'Livermore St',
#   'Longitude': -71.1065586316,
#   'Latitude': 42.2750005263,
#   'Street Length': 481.88,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c548'),
#   'Full Name': 'Battery Wharf',
#   'Longitude': -71.050862,
#   'Latitude': 42.36688425,
#   'Street Length': 154.37,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c549'),
#   'Full Name': 'Parley Vale',
#   'Longitude': -71.1114771429,
#   'Latitude': 42.3148999524,
#   'Street Length': 212.71,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c54a'),
#   'Full Name': 'Green St',
#   'Longitude': -71.0964286441,
#   'Latitude': 42.3291158983,
#   'Street Length': 1309.43,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c54b'),
#   'Full Name': 'Back St',
#   'Longitude': -71.0912647297,
#   'Latitude': 42.3517467973,
#   'Street Length': 2566.44,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c54c'),
#   'Full Name': 'Chestnut Pl',
#   'Longitude': -71.13007525,
#   'Latitude': 42.330919,
#   'Street Length': 85.43,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c54d'),
#   'Full Name': 'Shepard St',
#   'Longitude': -71.150670625,
#   'Latitude': 42.34673425,
#   'Street Length': 290.35,
#   'Cluster': 12},
#  {'_id': ObjectId('5cc64f121877df94dfc0c54e'),
#   'Full Name': 'Brighton Ave',
#   'Longitude': -71.1306382045,
#   'Latitude': 42.3528252386,
#   'Street Length': 2167.54,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c54f'),
#   'Full Name': 'Meehan St',
#   'Longitude': -71.107096125,
#   'Latitude': 42.306790375,
#   'Street Length': 187.62,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c550'),
#   'Full Name': 'Anderer Ln',
#   'Longitude': -71.1694972308,
#   'Latitude': 42.2937136923,
#   'Street Length': 322.45,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c551'),
#   'Full Name': 'Brook Farm Rd',
#   'Longitude': -71.16665,
#   'Latitude': 42.2922502647,
#   'Street Length': 792.86,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c552'),
#   'Full Name': 'River St',
#   'Longitude': -71.1062079709,
#   'Latitude': 42.2636334213,
#   'Street Length': 8222.13,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c553'),
#   'Full Name': 'Dedham Pkwy',
#   'Longitude': -71.1430502424,
#   'Latitude': 42.2557741515,
#   'Street Length': 806.48,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c554'),
#   'Full Name': 'Mount Vernon St',
#   'Longitude': -71.0841054184,
#   'Latitude': 42.3298698227,
#   'Street Length': 4453.65,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c555'),
#   'Full Name': 'Williams St',
#   'Longitude': -71.1036442333,
#   'Latitude': 42.3093364,
#   'Street Length': 831.51,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c556'),
#   'Full Name': 'Ruggles St',
#   'Longitude': -71.0894802407,
#   'Latitude': 42.334928537,
#   'Street Length': 1131.11,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c557'),
#   'Full Name': 'Dewitt Dr',
#   'Longitude': -71.0842391667,
#   'Latitude': 42.333153625,
#   'Street Length': 543.43,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c558'),
#   'Full Name': 'Melnea Cass Blvd',
#   'Longitude': -71.0811087328,
#   'Latitude': 42.3334680948,
#   'Street Length': 3254.47,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c559'),
#   'Full Name': 'Albany St',
#   'Longitude': -71.0683662202,
#   'Latitude': 42.337933156,
#   'Street Length': 2861.12,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c55a'),
#   'Full Name': 'Chadwick St',
#   'Longitude': -71.07641425,
#   'Latitude': 42.33050025,
#   'Street Length': 112.7,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c55b'),
#   'Full Name': 'Columbia Rd',
#   'Longitude': -71.0599647153,
#   'Latitude': 42.3187072315,
#   'Street Length': 10594.1,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c55c'),
#   'Full Name': 'Commercial St',
#   'Longitude': -71.0531706771,
#   'Latitude': 42.36519525,
#   'Street Length': 1455.1,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c55d'),
#   'Full Name': 'Allandale St',
#   'Longitude': -71.1339885854,
#   'Latitude': 42.3013199512,
#   'Street Length': 1075.1,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c55e'),
#   'Full Name': 'South St',
#   'Longitude': -71.122328686,
#   'Latitude': 42.2994424463,
#   'Street Length': 4840.24,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c55f'),
#   'Full Name': 'Egremont Rd',
#   'Longitude': -71.1430899524,
#   'Latitude': 42.3414917143,
#   'Street Length': 382.41,
#   'Cluster': 12},
#  {'_id': ObjectId('5cc64f121877df94dfc0c560'),
#   'Full Name': 'James St',
#   'Longitude': -71.106599,
#   'Latitude': 42.2834224,
#   'Street Length': 207.26,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c561'),
#   'Full Name': 'Savin Hill Ave',
#   'Longitude': -71.0514865556,
#   'Latitude': 42.3112832407,
#   'Street Length': 2115.42,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c562'),
#   'Full Name': 'Savin Hill Ct',
#   'Longitude': -71.0512764,
#   'Latitude': 42.3130378,
#   'Street Length': 73.17,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c563'),
#   'Full Name': 'Wave Ave',
#   'Longitude': -71.0506375,
#   'Latitude': 42.3128965,
#   'Street Length': 59.9,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c564'),
#   'Full Name': 'Beacon St',
#   'Longitude': -71.1096528362,
#   'Latitude': 42.3388006351,
#   'Street Length': 7741.42,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c565'),
#   'Full Name': 'Medford St',
#   'Longitude': -71.0613268941,
#   'Latitude': 42.3805358824,
#   'Street Length': 1832.77,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c566'),
#   'Full Name': 'N071',
#   'Longitude': -71.1248164286,
#   'Latitude': 42.2351281429,
#   'Street Length': 467.27,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c567'),
#   'Full Name': 'Pond St',
#   'Longitude': -71.1190391333,
#   'Latitude': 42.3037322167,
#   'Street Length': 2307.38,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c568'),
#   'Full Name': 'Albemarle Ct',
#   'Longitude': -71.0995945,
#   'Latitude': 42.30926725,
#   'Street Length': 273.55,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c569'),
#   'Full Name': 'Ardmore Rd',
#   'Longitude': -71.148135,
#   'Latitude': 42.2898166,
#   'Street Length': 104.22,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c56a'),
#   'Full Name': 'Amtrak RR',
#   'Longitude': -71.0806824667,
#   'Latitude': 42.3437368,
#   'Street Length': 549.3,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c56b'),
#   'Full Name': 'Lagrange St',
#   'Longitude': -71.1568233022,
#   'Latitude': 42.2861172033,
#   'Street Length': 4431.91,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c56c'),
#   'Full Name': 'Lawrence St',
#   'Longitude': -71.0997054737,
#   'Latitude': 42.3624323158,
#   'Street Length': 711.7,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c56d'),
#   'Full Name': 'N Washington St',
#   'Longitude': -71.0592494457,
#   'Latitude': 42.3668022174,
#   'Street Length': 1741.61,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c56e'),
#   'Full Name': 'Charles River Dam Rd',
#   'Longitude': -71.0693106,
#   'Latitude': 42.36726716,
#   'Street Length': 419.32,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c56f'),
#   'Full Name': '5th St',
#   'Longitude': -71.0558883,
#   'Latitude': 42.3750351,
#   'Street Length': 125.3,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c570'),
#   'Full Name': 'Vancouver St',
#   'Longitude': -71.0970538,
#   'Latitude': 42.3370707,
#   'Street Length': 266.02,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c571'),
#   'Full Name': 'Gorham St',
#   'Longitude': -71.1327711,
#   'Latitude': 42.3488359,
#   'Street Length': 152.18,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c572'),
#   'Full Name': 'Silver Line Way',
#   'Longitude': -71.0390455769,
#   'Latitude': 42.3473643077,
#   'Street Length': 527.54,
#   'Cluster': 20},
#  {'_id': ObjectId('5cc64f121877df94dfc0c573'),
#   'Full Name': 'New Rutherford Ave',
#   'Longitude': -71.0656998222,
#   'Latitude': 42.3730796444,
#   'Street Length': 2615.16,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c574'),
#   'Full Name': 'N Arsenal St',
#   'Longitude': -71.1462232963,
#   'Latitude': 42.3616033333,
#   'Street Length': 207.37,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c575'),
#   'Full Name': 'Sullivan Square Tunl',
#   'Longitude': -71.072536,
#   'Latitude': 42.3831123729,
#   'Street Length': 2206.16,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c576'),
#   'Full Name': 'W Newton St',
#   'Longitude': -71.078611975,
#   'Latitude': 42.34302005,
#   'Street Length': 995.76,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c577'),
#   'Full Name': 'Strathmore Rd',
#   'Longitude': -71.151204875,
#   'Latitude': 42.338900925,
#   'Street Length': 847.19,
#   'Cluster': 12},
#  {'_id': ObjectId('5cc64f121877df94dfc0c578'),
#   'Full Name': 'Columbia Ter',
#   'Longitude': -71.0726779,
#   'Latitude': 42.3094192,
#   'Street Length': 123.69,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c579'),
#   'Full Name': 'Msn Park Dr',
#   'Longitude': -71.109362,
#   'Latitude': 42.333318,
#   'Street Length': 21.1,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c57a'),
#   'Full Name': 'Roxbury St',
#   'Longitude': -71.0901129545,
#   'Latitude': 42.3301525909,
#   'Street Length': 901.26,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c57b'),
#   'Full Name': 'N447',
#   'Longitude': -71.0861020833,
#   'Latitude': 42.32956225,
#   'Street Length': 289.06,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c57c'),
#   'Full Name': 'Berkeley St',
#   'Longitude': -71.0723746379,
#   'Latitude': 42.3498468966,
#   'Street Length': 1204.31,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c57d'),
#   'Full Name': 'Gardner St',
#   'Longitude': -71.1522135,
#   'Latitude': 42.3077923182,
#   'Street Length': 2080.04,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c57e'),
#   'Full Name': 'Union Wharf',
#   'Longitude': -71.0503226667,
#   'Latitude': 42.3653253333,
#   'Street Length': 150.01,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c57f'),
#   'Full Name': 'Maverick Sq',
#   'Longitude': -71.0394188571,
#   'Latitude': 42.3695455714,
#   'Street Length': 153.49,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c580'),
#   'Full Name': 'Neptune Rd',
#   'Longitude': -71.0244700278,
#   'Latitude': 42.3793660833,
#   'Street Length': 482.54,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c581'),
#   'Full Name': 'St James St',
#   'Longitude': -71.08529316,
#   'Latitude': 42.32654348,
#   'Street Length': 363.47,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c582'),
#   'Full Name': 'Decatur St',
#   'Longitude': -71.0483546522,
#   'Latitude': 42.3752575217,
#   'Street Length': 494.41,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c583'),
#   'Full Name': 'Vine St',
#   'Longitude': -71.0618764,
#   'Latitude': 42.3633037667,
#   'Street Length': 399.95,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c584'),
#   'Full Name': 'Bennington St',
#   'Longitude': -71.0109454043,
#   'Latitude': 42.3851457522,
#   'Street Length': 7171.64,
#   'Cluster': 11},
#  {'_id': ObjectId('5cc64f121877df94dfc0c585'),
#   'Full Name': 'E Springfield St',
#   'Longitude': -71.0756532,
#   'Latitude': 42.3363494,
#   'Street Length': 227.69,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c586'),
#   'Full Name': 'Central Sq',
#   'Longitude': -71.0394256667,
#   'Latitude': 42.374494,
#   'Street Length': 170.58,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c587'),
#   'Full Name': 'B St',
#   'Longitude': -71.0551793333,
#   'Latitude': 42.3379679375,
#   'Street Length': 1353.07,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c588'),
#   'Full Name': 'D St',
#   'Longitude': -71.0503127279,
#   'Latitude': 42.3487863529,
#   'Street Length': 3288.48,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c589'),
#   'Full Name': 'New Dudley St',
#   'Longitude': -71.0920482105,
#   'Latitude': 42.3312114211,
#   'Street Length': 540.94,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c58a'),
#   'Full Name': 'E Boston Expy',
#   'Longitude': -71.0299733765,
#   'Latitude': 42.3762977778,
#   'Street Length': 4072.39,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c58b'),
#   'Full Name': 'Albemarle St',
#   'Longitude': -71.1031618,
#   'Latitude': 42.3024026,
#   'Street Length': 247.22,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c58c'),
#   'Full Name': 'N Harvard St',
#   'Longitude': -71.1274523433,
#   'Latitude': 42.363353791,
#   'Street Length': 1513.01,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c58d'),
#   'Full Name': 'Western Ave',
#   'Longitude': -71.1299604805,
#   'Latitude': 42.3633721948,
#   'Street Length': 2289.33,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c58e'),
#   'Full Name': 'Riley Rd',
#   'Longitude': -71.1276291579,
#   'Latitude': 42.2372968947,
#   'Street Length': 292.3,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c58f'),
#   'Full Name': 'Veterans of Foreign Wars Pkwy',
#   'Longitude': -71.159918604,
#   'Latitude': 42.2890488757,
#   'Street Length': 10086.07,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c590'),
#   'Full Name': 'Soldiers Field Rd',
#   'Longitude': -71.1291677791,
#   'Latitude': 42.3635563495,
#   'Street Length': 12677.93,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c591'),
#   'Full Name': 'Haul Rd',
#   'Longitude': -71.0443951139,
#   'Latitude': 42.3478123165,
#   'Street Length': 1103.25,
#   'Cluster': 20},
#  {'_id': ObjectId('5cc64f121877df94dfc0c592'),
#   'Full Name': 'Alford St',
#   'Longitude': -71.0718412381,
#   'Latitude': 42.3880914048,
#   'Street Length': 1623.61,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c593'),
#   'Full Name': 'Vfw Pkwy',
#   'Longitude': -71.1528828261,
#   'Latitude': 42.2931454565,
#   'Street Length': 447.17,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c594'),
#   'Full Name': 'Dana Ave',
#   'Longitude': -71.1216242083,
#   'Latitude': 42.2499295625,
#   'Street Length': 1404.83,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c595'),
#   'Full Name': 'Forest Hills St',
#   'Longitude': -71.1036117326,
#   'Latitude': 42.3060291977,
#   'Street Length': 1490.42,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c596'),
#   'Full Name': 'Stonley Rd',
#   'Longitude': -71.1083605,
#   'Latitude': 42.3038025,
#   'Street Length': 124.14,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c597'),
#   'Full Name': 'Preble St',
#   'Longitude': -71.0546946667,
#   'Latitude': 42.3293039444,
#   'Street Length': 347.52,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c598'),
#   'Full Name': 'Sullivan Sq',
#   'Longitude': -71.0734044167,
#   'Latitude': 42.3843967083,
#   'Street Length': 415.7,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c599'),
#   'Full Name': 'Bryon Rd',
#   'Longitude': -71.1670632727,
#   'Latitude': 42.3018379091,
#   'Street Length': 410.09,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c59a'),
#   'Full Name': 'Westchester Rd',
#   'Longitude': -71.1312672727,
#   'Latitude': 42.3044887879,
#   'Street Length': 844.19,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c59b'),
#   'Full Name': 'Stanley St',
#   'Longitude': -71.06905725,
#   'Latitude': 42.3101650833,
#   'Street Length': 319.85,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c59c'),
#   'Full Name': 'Bradlee St',
#   'Longitude': -71.1026041333,
#   'Latitude': 42.2788063667,
#   'Street Length': 940.55,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c59d'),
#   'Full Name': 'Tremont St',
#   'Longitude': -71.0855982575,
#   'Latitude': 42.3432787291,
#   'Street Length': 7410.02,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c59e'),
#   'Full Name': 'Stillman St',
#   'Longitude': -71.0569165,
#   'Latitude': 42.363776,
#   'Street Length': 158.86,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c59f'),
#   'Full Name': 'Carleton St',
#   'Longitude': -71.0784530714,
#   'Latitude': 42.3453622143,
#   'Street Length': 328.13,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a0'),
#   'Full Name': 'Wedgewood Rd',
#   'Longitude': -71.137069,
#   'Latitude': 42.2946665,
#   'Street Length': 97.14,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a1'),
#   'Full Name': 'St Gregory St',
#   'Longitude': -71.0696661429,
#   'Latitude': 42.2757708571,
#   'Street Length': 411.72,
#   'Cluster': 17},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a2'),
#   'Full Name': 'Meadow Rd',
#   'Longitude': -71.1298719667,
#   'Latitude': 42.2316876,
#   'Street Length': 923.33,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a3'),
#   'Full Name': 'Brainerd Rd',
#   'Longitude': -71.1328788696,
#   'Latitude': 42.3478021739,
#   'Street Length': 567.47,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a4'),
#   'Full Name': 'Gallivan Blvd',
#   'Longitude': -71.0568397385,
#   'Latitude': 42.2821606651,
#   'Street Length': 4585.3,
#   'Cluster': 9},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a5'),
#   'Full Name': 'University Rd',
#   'Longitude': -71.109523,
#   'Latitude': 42.35118375,
#   'Street Length': 116.39,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a6'),
#   'Full Name': 'Metropolitan Cir',
#   'Longitude': -71.1262168,
#   'Latitude': 42.2769198,
#   'Street Length': 53.23,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a7'),
#   'Full Name': 'Wachusett St',
#   'Longitude': -71.1141783095,
#   'Latitude': 42.2892056905,
#   'Street Length': 1436.14,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a8'),
#   'Full Name': 'Gainsborough St',
#   'Longitude': -71.0870929615,
#   'Latitude': 42.3415276923,
#   'Street Length': 703.71,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5a9'),
#   'Full Name': 'Arlington St',
#   'Longitude': -71.0998362551,
#   'Latitude': 42.325622398,
#   'Street Length': 2459.32,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5aa'),
#   'Full Name': 'I- 90 Eb Hov Lane',
#   'Longitude': -71.0498758,
#   'Latitude': 42.3469117217,
#   'Street Length': 1980.09,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ab'),
#   'Full Name': 'Forest Hills Opas',
#   'Longitude': -71.1107484259,
#   'Latitude': 42.3013014444,
#   'Street Length': 1334.1,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ac'),
#   'Full Name': 'Liverpool St',
#   'Longitude': -71.0414740714,
#   'Latitude': 42.371508,
#   'Street Length': 531.8,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ad'),
#   'Full Name': 'Crosby Sq',
#   'Longitude': -71.0761455,
#   'Latitude': 42.33006175,
#   'Street Length': 147.8,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ae'),
#   'Full Name': 'Daniel Ct',
#   'Longitude': -71.14111725,
#   'Latitude': 42.2524795,
#   'Street Length': 63.25,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5af'),
#   'Full Name': 'Joan Rd',
#   'Longitude': -71.1437006,
#   'Latitude': 42.2529996,
#   'Street Length': 247.84,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b0'),
#   'Full Name': 'Leighton Rd',
#   'Longitude': -71.1439417143,
#   'Latitude': 42.2512248286,
#   'Street Length': 781.14,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b1'),
#   'Full Name': 'Sleeper St',
#   'Longitude': -71.0491908333,
#   'Latitude': 42.3519520556,
#   'Street Length': 535.64,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b2'),
#   'Full Name': 'Hazelwood Ct',
#   'Longitude': -71.0849585,
#   'Latitude': 42.317902,
#   'Street Length': 46.43,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b3'),
#   'Full Name': 'Boylston St',
#   'Longitude': -71.0909753514,
#   'Latitude': 42.338308536,
#   'Street Length': 5263.64,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b4'),
#   'Full Name': 'Charlesgate',
#   'Longitude': -71.0923451687,
#   'Latitude': 42.3488489277,
#   'Street Length': 1149.47,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b5'),
#   'Full Name': 'Rutherford Ave',
#   'Longitude': -71.0697331538,
#   'Latitude': 42.3787318462,
#   'Street Length': 2267.19,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b6'),
#   'Full Name': 'Norcross Pl',
#   'Longitude': -71.036455,
#   'Latitude': 42.33164,
#   'Street Length': 42.09,
#   'Cluster': 20},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b7'),
#   'Full Name': 'Business St',
#   'Longitude': -71.1275125161,
#   'Latitude': 42.2533621935,
#   'Street Length': 715.02,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b8'),
#   'Full Name': 'Dunning Way',
#   'Longitude': -71.1084094286,
#   'Latitude': 42.3006191429,
#   'Street Length': 106.96,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5b9'),
#   'Full Name': 'Brookline Ave',
#   'Longitude': -71.1031055,
#   'Latitude': 42.3428908625,
#   'Street Length': 1887.47,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ba'),
#   'Full Name': 'Peaceable St',
#   'Longitude': -71.152305,
#   'Latitude': 42.347937,
#   'Street Length': 150.23,
#   'Cluster': 12},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5bb'),
#   'Full Name': 'Forsyth St',
#   'Longitude': -71.0911424286,
#   'Latitude': 42.3395118214,
#   'Street Length': 589.43,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5bc'),
#   'Full Name': 'Louis Prang St',
#   'Longitude': -71.0966010714,
#   'Latitude': 42.3381052143,
#   'Street Length': 152.53,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5bd'),
#   'Full Name': 'Whittier St',
#   'Longitude': -71.0891459167,
#   'Latitude': 42.334179,
#   'Street Length': 375.8,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5be'),
#   'Full Name': 'Melrose St',
#   'Longitude': -71.0677276667,
#   'Latitude': 42.3492797778,
#   'Street Length': 262.05,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5bf'),
#   'Full Name': 'Harrison Ave',
#   'Longitude': -71.070292609,
#   'Latitude': 42.3401621731,
#   'Street Length': 3455.26,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c0'),
#   'Full Name': 'Meridian St',
#   'Longitude': -71.03914375,
#   'Latitude': 42.3764932115,
#   'Street Length': 1533.73,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c1'),
#   'Full Name': 'London St',
#   'Longitude': -71.039498037,
#   'Latitude': 42.3725538889,
#   'Street Length': 856.24,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c2'),
#   'Full Name': 'Frontage Rd',
#   'Longitude': -71.0608419231,
#   'Latitude': 42.3416421635,
#   'Street Length': 2362.71,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c3'),
#   'Full Name': 'Beach St',
#   'Longitude': -71.0586379091,
#   'Latitude': 42.337773,
#   'Street Length': 886.87,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c4'),
#   'Full Name': 'A St',
#   'Longitude': -71.0736906489,
#   'Latitude': 42.3306707128,
#   'Street Length': 1793.48,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c5'),
#   'Full Name': 'Mass Ave Con',
#   'Longitude': -71.0676795873,
#   'Latitude': 42.3348445873,
#   'Street Length': 1409.13,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c6'),
#   'Full Name': 'Logan Airport Terminal E',
#   'Longitude': -71.0214148267,
#   'Latitude': 42.36900916,
#   'Street Length': 1967.79,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c7'),
#   'Full Name': 'Harborside Dr',
#   'Longitude': -71.0272382761,
#   'Latitude': 42.3666718358,
#   'Street Length': 2567.36,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c8'),
#   'Full Name': 'Wayburn Rd',
#   'Longitude': -71.1127964444,
#   'Latitude': 42.2898721111,
#   'Street Length': 180.66,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5c9'),
#   'Full Name': 'Airport Road Uturn To Departure Level',
#   'Longitude': -71.0268676471,
#   'Latitude': 42.3687297059,
#   'Street Length': 521.7,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ca'),
#   'Full Name': 'Hotel Dr',
#   'Longitude': -71.0251346701,
#   'Latitude': 42.3680801237,
#   'Street Length': 825.98,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5cb'),
#   'Full Name': 'Parkside Dr',
#   'Longitude': -71.1310311212,
#   'Latitude': 42.3114568182,
#   'Street Length': 546.51,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5cc'),
#   'Full Name': 'Arlington Ave',
#   'Longitude': -71.0745991667,
#   'Latitude': 42.3871058333,
#   'Street Length': 333.35,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5cd'),
#   'Full Name': 'Lamson St',
#   'Longitude': -71.0325409,
#   'Latitude': 42.3664842,
#   'Street Length': 360.23,
#   'Cluster': 21},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ce'),
#   'Full Name': 'Cornhill St',
#   'Longitude': -71.0583145,
#   'Latitude': 42.3593615,
#   'Street Length': 27.37,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5cf'),
#   'Full Name': 'Congress St',
#   'Longitude': -71.0503521295,
#   'Latitude': 42.3528762302,
#   'Street Length': 2615.49,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d0'),
#   'Full Name': 'Gaffney St',
#   'Longitude': -71.119089,
#   'Latitude': 42.352285,
#   'Street Length': 117.21,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d1'),
#   'Full Name': 'Louders Ln',
#   'Longitude': -71.1284702927,
#   'Latitude': 42.3056935366,
#   'Street Length': 941.37,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d2'),
#   'Full Name': 'David Rd',
#   'Longitude': -71.128221,
#   'Latitude': 42.3061566667,
#   'Street Length': 126.93,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d3'),
#   'Full Name': 'Whitcomb Ave',
#   'Longitude': -71.12942296,
#   'Latitude': 42.303032,
#   'Street Length': 634.54,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d4'),
#   'Full Name': 'Appleton St',
#   'Longitude': -71.0722676667,
#   'Latitude': 42.3457918333,
#   'Street Length': 633.91,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d5'),
#   'Full Name': 'Richards St',
#   'Longitude': -71.0533995714,
#   'Latitude': 42.344492,
#   'Street Length': 219.98,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d6'),
#   'Full Name': 'Mercantile St',
#   'Longitude': -71.053001,
#   'Latitude': 42.3607165,
#   'Street Length': 106.1,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d7'),
#   'Full Name': 'High St',
#   'Longitude': -71.0578670114,
#   'Latitude': 42.3596505682,
#   'Street Length': 1385.83,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d8'),
#   'Full Name': 'Hanover St',
#   'Longitude': -71.0548672535,
#   'Latitude': 42.3637303239,
#   'Street Length': 790.21,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5d9'),
#   'Full Name': 'Purchase St',
#   'Longitude': -71.0532755,
#   'Latitude': 42.3547403235,
#   'Street Length': 606.57,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5da'),
#   'Full Name': 'Sumner Tunl',
#   'Longitude': -71.0480696984,
#   'Latitude': 42.3671416825,
#   'Street Length': 1851.3,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5db'),
#   'Full Name': 'Ipswich St',
#   'Longitude': -71.0928156,
#   'Latitude': 42.3471094,
#   'Street Length': 742.09,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5dc'),
#   'Full Name': 'Arborway',
#   'Longitude': -71.1185905392,
#   'Latitude': 42.3069725392,
#   'Street Length': 6485.03,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5dd'),
#   'Full Name': 'Savin Hill Ln',
#   'Longitude': -71.046759,
#   'Latitude': 42.310512,
#   'Street Length': 43.81,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5de'),
#   'Full Name': 'Old Colony Ter',
#   'Longitude': -71.046758,
#   'Latitude': 42.3122915,
#   'Street Length': 69.14,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5df'),
#   'Full Name': 'Hyde Park Ave',
#   'Longitude': -71.1234146211,
#   'Latitude': 42.2641740529,
#   'Street Length': 7769.23,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e0'),
#   'Full Name': 'Baker St',
#   'Longitude': -71.1698682167,
#   'Latitude': 42.2829925083,
#   'Street Length': 2934.85,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e1'),
#   'Full Name': 'Peterborough St',
#   'Longitude': -71.0976324706,
#   'Latitude': 42.3436445294,
#   'Street Length': 635.74,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e2'),
#   'Full Name': 'Stoughton St',
#   'Longitude': -71.06546712,
#   'Latitude': 42.32235908,
#   'Street Length': 725.28,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e3'),
#   'Full Name': 'Newmarket Sq',
#   'Longitude': -71.0665705294,
#   'Latitude': 42.3290709412,
#   'Street Length': 1081.54,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e4'),
#   'Full Name': 'Alger St',
#   'Longitude': -71.0569718571,
#   'Latitude': 42.3327562857,
#   'Street Length': 275.93,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e5'),
#   'Full Name': 'Dubois St',
#   'Longitude': -71.0760643636,
#   'Latitude': 42.3286578182,
#   'Street Length': 228.73,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e6'),
#   'Full Name': 'David G Mugar Way',
#   'Longitude': -71.0726920238,
#   'Latitude': 42.3573326667,
#   'Street Length': 593.28,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e7'),
#   'Full Name': 'N081',
#   'Longitude': -71.1437022727,
#   'Latitude': 42.3522124091,
#   'Street Length': 335.25,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e8'),
#   'Full Name': 'Talbot Ave',
#   'Longitude': -71.074470473,
#   'Latitude': 42.2908715676,
#   'Street Length': 2290.58,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5e9'),
#   'Full Name': 'W Roxbury Pkwy',
#   'Longitude': -71.1455801324,
#   'Latitude': 42.2856296103,
#   'Street Length': 3458.74,
#   'Cluster': 0},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ea'),
#   'Full Name': 'St Theresa Ave',
#   'Longitude': -71.1552899302,
#   'Latitude': 42.2765166744,
#   'Street Length': 887.72,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5eb'),
#   'Full Name': 'Georgetowne Dr',
#   'Longitude': -71.1461386667,
#   'Latitude': 42.2582918254,
#   'Street Length': 910.83,
#   'Cluster': 19},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ec'),
#   'Full Name': 'Southampton St',
#   'Longitude': -71.0631771154,
#   'Latitude': 42.3307279231,
#   'Street Length': 1326.18,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ed'),
#   'Full Name': 'Sun Court St',
#   'Longitude': -71.05299775,
#   'Latitude': 42.3638225,
#   'Street Length': 58.38,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ee'),
#   'Full Name': 'Causeway St',
#   'Longitude': -71.0606786939,
#   'Latitude': 42.3657432449,
#   'Street Length': 646.89,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ef'),
#   'Full Name': 'Essex St',
#   'Longitude': -71.0690088846,
#   'Latitude': 42.3567289231,
#   'Street Length': 773.26,
#   'Cluster': 16},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f0'),
#   'Full Name': 'Foundry St',
#   'Longitude': -71.0582601,
#   'Latitude': 42.3430983,
#   'Street Length': 341.64,
#   'Cluster': 2},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f1'),
#   'Full Name': 'Jamaicaway',
#   'Longitude': -71.1147224071,
#   'Latitude': 42.3246905214,
#   'Street Length': 2681.24,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f2'),
#   'Full Name': 'Kilmarnock St',
#   'Longitude': -71.0994122381,
#   'Latitude': 42.3427717619,
#   'Street Length': 477.0,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f3'),
#   'Full Name': 'Blackfan St',
#   'Longitude': -71.1053545,
#   'Latitude': 42.33758925,
#   'Street Length': 171.08,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f4'),
#   'Full Name': 'Longwood Ave',
#   'Longitude': -71.1051214107,
#   'Latitude': 42.3379896607,
#   'Street Length': 1122.31,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f5'),
#   'Full Name': 'Fenway',
#   'Longitude': -71.0947926961,
#   'Latitude': 42.3424150294,
#   'Street Length': 2151.23,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f6'),
#   'Full Name': 'Queensberry St',
#   'Longitude': -71.0976457222,
#   'Latitude': 42.3426882778,
#   'Street Length': 567.7,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f7'),
#   'Full Name': 'Barry St',
#   'Longitude': -71.0844046087,
#   'Latitude': 42.2940205217,
#   'Street Length': 635.19,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f8'),
#   'Full Name': 'Massachusetts Ave',
#   'Longitude': -71.0780630299,
#   'Latitude': 42.3376660085,
#   'Street Length': 6561.93,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5f9'),
#   'Full Name': 'Westland Ave',
#   'Longitude': -71.0892874783,
#   'Latitude': 42.3438886522,
#   'Street Length': 475.65,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5fa'),
#   'Full Name': 'Perkins St',
#   'Longitude': -71.1156812929,
#   'Latitude': 42.3271696566,
#   'Street Length': 1905.7,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5fb'),
#   'Full Name': 'Maffa Way',
#   'Longitude': -71.0767330526,
#   'Latitude': 42.3854854737,
#   'Street Length': 229.16,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5fc'),
#   'Full Name': 'Sherman St',
#   'Longitude': -71.0849663333,
#   'Latitude': 42.3462556111,
#   'Street Length': 351.73,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5fd'),
#   'Full Name': 'Hamblen St',
#   'Longitude': -71.0755145,
#   'Latitude': 42.387353,
#   'Street Length': 47.1,
#   'Cluster': 7},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5fe'),
#   'Full Name': 'N Jewish War Vets Dr',
#   'Longitude': -71.0950201765,
#   'Latitude': 42.3057199412,
#   'Street Length': 394.32,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c5ff'),
#   'Full Name': 'Orchardhill Rd',
#   'Longitude': -71.1113360455,
#   'Latitude': 42.2999115,
#   'Street Length': 307.47,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c600'),
#   'Full Name': 'Wenham St',
#   'Longitude': -71.1146555333,
#   'Latitude': 42.2966336667,
#   'Street Length': 406.3,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c601'),
#   'Full Name': 'Eastland Rd',
#   'Longitude': -71.1135201667,
#   'Latitude': 42.2908974,
#   'Street Length': 470.74,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c602'),
#   'Full Name': 'Goodway Rd',
#   'Longitude': -71.1153878333,
#   'Latitude': 42.2895776667,
#   'Street Length': 189.22,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c603'),
#   'Full Name': 'Southbourne Rd',
#   'Longitude': -71.1160341053,
#   'Latitude': 42.2901540526,
#   'Street Length': 405.48,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c604'),
#   'Full Name': 'N Shea Cir',
#   'Longitude': -71.106555871,
#   'Latitude': 42.3005653548,
#   'Street Length': 229.04,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c605'),
#   'Full Name': 'Forest Hills Dr Exd',
#   'Longitude': -71.1062593333,
#   'Latitude': 42.300894,
#   'Street Length': 32.53,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c606'),
#   'Full Name': 'Sigourney St',
#   'Longitude': -71.09934715,
#   'Latitude': 42.30908605,
#   'Street Length': 302.19,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c607'),
#   'Full Name': 'Dixwell St',
#   'Longitude': -71.0979233333,
#   'Latitude': 42.3143093333,
#   'Street Length': 141.96,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c608'),
#   'Full Name': 'Columbus Ave',
#   'Longitude': -71.0877075884,
#   'Latitude': 42.3328326209,
#   'Street Length': 8393.45,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c609'),
#   'Full Name': 'School St',
#   'Longitude': -71.0899360659,
#   'Latitude': 42.3305395385,
#   'Street Length': 1843.11,
#   'Cluster': 10},
#  {'_id': ObjectId('5cc64f121877df94dfc0c60a'),
#   'Full Name': 'Westminster Ave',
#   'Longitude': -71.0949908667,
#   'Latitude': 42.3160046,
#   'Street Length': 339.47,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c60b'),
#   'Full Name': 'Pierpont Rd',
#   'Longitude': -71.113547,
#   'Latitude': 42.3012689231,
#   'Street Length': 833.99,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c60c'),
#   'Full Name': 'Seaver St',
#   'Longitude': -71.0882137117,
#   'Latitude': 42.3094324324,
#   'Street Length': 3256.41,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c60d'),
#   'Full Name': 'Harold St',
#   'Longitude': -71.0902596122,
#   'Latitude': 42.3164196939,
#   'Street Length': 1007.69,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c60e'),
#   'Full Name': 'Howland St',
#   'Longitude': -71.0867231579,
#   'Latitude': 42.3130088421,
#   'Street Length': 735.76,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c60f'),
#   'Full Name': 'Humboldt Ave',
#   'Longitude': -71.0881985333,
#   'Latitude': 42.3153214,
#   'Street Length': 1326.09,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c610'),
#   'Full Name': 'Brookledge St',
# ...
#   'Full Name': 'Burrell St',
#   'Longitude': -71.069912,
#   'Latitude': 42.323213375,
#   'Street Length': 417.93,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c896'),
#   'Full Name': 'Shirley St',
#   'Longitude': -71.0692384583,
#   'Latitude': 42.3251095417,
#   'Street Length': 677.7,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c897'),
#   'Full Name': 'Shetland St',
#   'Longitude': -71.0679455455,
#   'Latitude': 42.325234,
#   'Street Length': 206.45,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c898'),
#   'Full Name': 'Norfolk Ave',
#   'Longitude': -71.0693101944,
#   'Latitude': 42.324814,
#   'Street Length': 1153.13,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c899'),
#   'Full Name': 'Marshfield St',
#   'Longitude': -71.0691605,
#   'Latitude': 42.3228564,
#   'Street Length': 267.39,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c89a'),
#   'Full Name': 'Alexander St',
#   'Longitude': -71.0702904762,
#   'Latitude': 42.315700381,
#   'Street Length': 647.5,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c89b'),
#   'Full Name': 'Bird St',
#   'Longitude': -71.069193,
#   'Latitude': 42.3140081562,
#   'Street Length': 608.37,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c89c'),
#   'Full Name': 'Cedar Pl',
#   'Longitude': -71.0697405,
#   'Latitude': 42.314404,
#   'Street Length': 80.7,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c89d'),
#   'Full Name': 'Elder St',
#   'Longitude': -71.0637965455,
#   'Latitude': 42.3203931818,
#   'Street Length': 268.33,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c89e'),
#   'Full Name': 'Hamlet St',
#   'Longitude': -71.06466625,
#   'Latitude': 42.31828175,
#   'Street Length': 136.63,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c89f'),
#   'Full Name': 'Way St',
#   'Longitude': -71.12027425,
#   'Latitude': 42.25576375,
#   'Street Length': 94.71,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a0'),
#   'Full Name': 'Nott St',
#   'Longitude': -71.1195698,
#   'Latitude': 42.254563,
#   'Street Length': 98.96,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a1'),
#   'Full Name': 'Riverside Sq',
#   'Longitude': -71.1143635714,
#   'Latitude': 42.2599912857,
#   'Street Length': 279.37,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a2'),
#   'Full Name': 'Dacy St',
#   'Longitude': -71.12680475,
#   'Latitude': 42.24924875,
#   'Street Length': 41.44,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a3'),
#   'Full Name': 'Stanbro St',
#   'Longitude': -71.1307586667,
#   'Latitude': 42.2349043333,
#   'Street Length': 497.81,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a4'),
#   'Full Name': 'Parkson St',
#   'Longitude': -71.1320725,
#   'Latitude': 42.23442275,
#   'Street Length': 172.9,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a5'),
#   'Full Name': 'Neponset Valley Pkwy',
#   'Longitude': -71.1301815227,
#   'Latitude': 42.2390459659,
#   'Street Length': 1749.97,
#   'Cluster': 4},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a6'),
#   'Full Name': 'Bourne St',
#   'Longitude': -71.1130167179,
#   'Latitude': 42.2896673077,
#   'Street Length': 840.58,
#   'Cluster': 8},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a7'),
#   'Full Name': 'Paine St',
#   'Longitude': -71.1078701538,
#   'Latitude': 42.2853280769,
#   'Street Length': 402.31,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a8'),
#   'Full Name': 'Yuletide Rd',
#   'Longitude': -71.108389,
#   'Latitude': 42.2723365,
#   'Street Length': 60.16,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8a9'),
#   'Full Name': 'Wilton St',
#   'Longitude': -71.1303275714,
#   'Latitude': 42.3099604286,
#   'Street Length': 245.06,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8aa'),
#   'Full Name': 'Spurr St',
#   'Longitude': -71.1309766667,
#   'Latitude': 42.3629143333,
#   'Street Length': 116.56,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ab'),
#   'Full Name': 'Easton St',
#   'Longitude': -71.1315613636,
#   'Latitude': 42.3594974545,
#   'Street Length': 374.5,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ac'),
#   'Full Name': 'Bertram St',
#   'Longitude': -71.1294288,
#   'Latitude': 42.3625971,
#   'Street Length': 130.58,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ad'),
#   'Full Name': 'Myrick St',
#   'Longitude': -71.13143775,
#   'Latitude': 42.359687,
#   'Street Length': 207.95,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ae'),
#   'Full Name': 'Mansfield St',
#   'Longitude': -71.1313237,
#   'Latitude': 42.3583447,
#   'Street Length': 298.66,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8af'),
#   'Full Name': 'Highgate St',
#   'Longitude': -71.1317908333,
#   'Latitude': 42.355127,
#   'Street Length': 170.83,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b0'),
#   'Full Name': 'Farrington Ave',
#   'Longitude': -71.1314095,
#   'Latitude': 42.35437625,
#   'Street Length': 169.08,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b1'),
#   'Full Name': 'Summit Ave',
#   'Longitude': -71.1400805714,
#   'Latitude': 42.345211,
#   'Street Length': 376.88,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b2'),
#   'Full Name': 'Armington St',
#   'Longitude': -71.1372896364,
#   'Latitude': 42.3525257273,
#   'Street Length': 178.72,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b3'),
#   'Full Name': 'Quint Ave',
#   'Longitude': -71.1337957,
#   'Latitude': 42.3514032,
#   'Street Length': 336.89,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b4'),
#   'Full Name': 'Glenville Ave',
#   'Longitude': -71.1345135,
#   'Latitude': 42.3497433214,
#   'Street Length': 554.11,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b5'),
#   'Full Name': 'Boulevard Ter',
#   'Longitude': -71.13947675,
#   'Latitude': 42.34715425,
#   'Street Length': 157.01,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b6'),
#   'Full Name': 'Commonwealth Ter',
#   'Longitude': -71.1396476667,
#   'Latitude': 42.346611,
#   'Street Length': 149.62,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b7'),
#   'Full Name': 'Feneno Ter',
#   'Longitude': -71.132206,
#   'Latitude': 42.348034,
#   'Street Length': 31.67,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b8'),
#   'Full Name': 'Parkvale Ave',
#   'Longitude': -71.13301975,
#   'Latitude': 42.35180225,
#   'Street Length': 280.08,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8b9'),
#   'Full Name': 'Harvard Ave',
#   'Longitude': -71.1196759552,
#   'Latitude': 42.3166769552,
#   'Street Length': 1517.34,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ba'),
#   'Full Name': 'River Street Brg',
#   'Longitude': -71.11723925,
#   'Latitude': 42.361085375,
#   'Street Length': 81.69,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8bb'),
#   'Full Name': 'Ashford St',
#   'Longitude': -71.12532925,
#   'Latitude': 42.3543298571,
#   'Street Length': 753.71,
#   'Cluster': 3},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8bc'),
#   'Full Name': 'Winchester St',
#   'Longitude': -71.0685227,
#   'Latitude': 42.3495818,
#   'Street Length': 210.15,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8bd'),
#   'Full Name': 'Stuart St',
#   'Longitude': -71.069826575,
#   'Latitude': 42.350038875,
#   'Street Length': 1238.34,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8be'),
#   'Full Name': 'Marginal Rd',
#   'Longitude': -71.0665288571,
#   'Latitude': 42.3477313571,
#   'Street Length': 527.4,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8bf'),
#   'Full Name': 'Herald St',
#   'Longitude': -71.0655494667,
#   'Latitude': 42.3468148,
#   'Street Length': 630.11,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c0'),
#   'Full Name': 'E Berkeley St',
#   'Longitude': -71.0668456667,
#   'Latitude': 42.3442729524,
#   'Street Length': 654.21,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c1'),
#   'Full Name': 'Perry St',
#   'Longitude': -71.0666255,
#   'Latitude': 42.3424205,
#   'Street Length': 113.82,
#   'Cluster': 22},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c2'),
#   'Full Name': 'Autumn St',
#   'Longitude': -71.1281178571,
#   'Latitude': 42.3167475,
#   'Street Length': 295.11,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c3'),
#   'Full Name': 'S Huntington Ave',
#   'Longitude': -71.1115646441,
#   'Latitude': 42.3258593729,
#   'Street Length': 1419.88,
#   'Cluster': 14},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c4'),
#   'Full Name': 'Cheney St',
#   'Longitude': -71.0847972308,
#   'Latitude': 42.3091756923,
#   'Street Length': 363.48,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c5'),
#   'Full Name': 'Schuyler St',
#   'Longitude': -71.08543225,
#   'Latitude': 42.3083726667,
#   'Street Length': 368.61,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c6'),
#   'Full Name': 'Pasadena Rd',
#   'Longitude': -71.0833335455,
#   'Latitude': 42.305542,
#   'Street Length': 283.58,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c7'),
#   'Full Name': 'Normandy St',
#   'Longitude': -71.0807466562,
#   'Latitude': 42.3083691562,
#   'Street Length': 963.74,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c8'),
#   'Full Name': 'Gannett St',
#   'Longitude': -71.0817286,
#   'Latitude': 42.3144786,
#   'Street Length': 152.64,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8c9'),
#   'Full Name': 'Intervale St',
#   'Longitude': -71.07874856,
#   'Latitude': 42.31103252,
#   'Street Length': 833.03,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ca'),
#   'Full Name': 'Sunderland St',
#   'Longitude': -71.0827504286,
#   'Latitude': 42.3105245714,
#   'Street Length': 114.51,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8cb'),
#   'Full Name': 'Devon St',
#   'Longitude': -71.07881084,
#   'Latitude': 42.30921176,
#   'Street Length': 834.88,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8cc'),
#   'Full Name': 'Fernboro St',
#   'Longitude': -71.077344,
#   'Latitude': 42.3111484,
#   'Street Length': 159.54,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8cd'),
#   'Full Name': 'Oldfields Rd',
#   'Longitude': -71.07971724,
#   'Latitude': 42.3080256,
#   'Street Length': 337.49,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ce'),
#   'Full Name': 'Michigan Ave',
#   'Longitude': -71.0834433333,
#   'Latitude': 42.3026581111,
#   'Street Length': 255.0,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8cf'),
#   'Full Name': 'Erie St',
#   'Longitude': -71.0806925217,
#   'Latitude': 42.30233,
#   'Street Length': 512.2,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d0'),
#   'Full Name': 'Laredo St',
#   'Longitude': -71.07785925,
#   'Latitude': 42.30859625,
#   'Street Length': 108.03,
#   'Cluster': 1},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d1'),
#   'Full Name': 'Olney St',
#   'Longitude': -71.0723974048,
#   'Latitude': 42.3051445,
#   'Street Length': 650.0,
#   'Cluster': 18},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d2'),
#   'Full Name': 'Vesta Rd',
#   'Longitude': -71.0868448889,
#   'Latitude': 42.2962614444,
#   'Street Length': 175.03,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d3'),
#   'Full Name': 'Bradshaw St',
#   'Longitude': -71.0832905625,
#   'Latitude': 42.2984746875,
#   'Street Length': 287.95,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d4'),
#   'Full Name': 'Charlotte St',
#   'Longitude': -71.0846846,
#   'Latitude': 42.2992798,
#   'Street Length': 287.53,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d5'),
#   'Full Name': 'Glenway St',
#   'Longitude': -71.0827046129,
#   'Latitude': 42.2999300645,
#   'Street Length': 800.16,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d6'),
#   'Full Name': 'Greenwood St',
#   'Longitude': -71.0796282963,
#   'Latitude': 42.2994064074,
#   'Street Length': 726.37,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d7'),
#   'Full Name': 'Westview St',
#   'Longitude': -71.084652375,
#   'Latitude': 42.2908858125,
#   'Street Length': 611.37,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d8'),
#   'Full Name': 'Bernard St',
#   'Longitude': -71.0797316,
#   'Latitude': 42.2929338571,
#   'Street Length': 725.2,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8d9'),
#   'Full Name': 'Bicknell St',
#   'Longitude': -71.0826488333,
#   'Latitude': 42.2972436667,
#   'Street Length': 267.98,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8da'),
#   'Full Name': 'Bowdoin Ave',
#   'Longitude': -71.0749273182,
#   'Latitude': 42.3012436364,
#   'Street Length': 600.5,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8db'),
#   'Full Name': 'W Park St',
#   'Longitude': -71.079292,
#   'Latitude': 42.2941927143,
#   'Street Length': 114.9,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8dc'),
#   'Full Name': 'Standish St',
#   'Longitude': -71.079087875,
#   'Latitude': 42.295294125,
#   'Street Length': 259.05,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8dd'),
#   'Full Name': 'Westcott St',
#   'Longitude': -71.07887875,
#   'Latitude': 42.293237,
#   'Street Length': 228.88,
#   'Cluster': 13},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8de'),
#   'Full Name': 'Derry Rd',
#   'Longitude': -71.1137566667,
#   'Latitude': 42.265913,
#   'Street Length': 168.35,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8df'),
#   'Full Name': 'Ayles Rd',
#   'Longitude': -71.112483625,
#   'Latitude': 42.265498625,
#   'Street Length': 404.12,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e0'),
#   'Full Name': 'Wood Ave',
#   'Longitude': -71.11033172,
#   'Latitude': 42.26800128,
#   'Street Length': 1415.51,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e1'),
#   'Full Name': 'Kennebec St',
#   'Longitude': -71.106036,
#   'Latitude': 42.2732525333,
#   'Street Length': 909.64,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e2'),
#   'Full Name': 'Oakwood St',
#   'Longitude': -71.1007965833,
#   'Latitude': 42.2734153333,
#   'Street Length': 444.2,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e3'),
#   'Full Name': 'Roseglen Rd',
#   'Longitude': -71.108955,
#   'Latitude': 42.2669135,
#   'Street Length': 81.2,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e4'),
#   'Full Name': 'Birchcroft Rd',
#   'Longitude': -71.1087943125,
#   'Latitude': 42.2662065625,
#   'Street Length': 349.88,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e5'),
#   'Full Name': 'Orchard St',
#   'Longitude': -71.1169606,
#   'Latitude': 42.2992641333,
#   'Street Length': 598.8,
#   'Cluster': 6},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e6'),
#   'Full Name': 'Taunton Ave',
#   'Longitude': -71.1063697619,
#   'Latitude': 42.267195,
#   'Street Length': 753.87,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e7'),
#   'Full Name': 'Ruskindale Rd',
#   'Longitude': -71.1059187273,
#   'Latitude': 42.2676264545,
#   'Street Length': 768.97,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e8'),
#   'Full Name': 'Lewiston St',
#   'Longitude': -71.1110608571,
#   'Latitude': 42.264829,
#   'Street Length': 510.56,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8e9'),
#   'Full Name': 'Danbury Rd',
#   'Longitude': -71.109116,
#   'Latitude': 42.2644168,
#   'Street Length': 117.43,
#   'Cluster': 15},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ea'),
#   'Full Name': 'Trelawney Rd',
#   'Longitude': -71.10797325,
#   'Latitude': 42.266306125,
#   'Street Length': 165.38,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8eb'),
#   'Full Name': 'Hebron St',
#   'Longitude': -71.1062022963,
#   'Latitude': 42.2741892963,
#   'Street Length': 985.97,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ec'),
#   'Full Name': 'Greenfield Rd',
#   'Longitude': -71.1041678667,
#   'Latitude': 42.2693797667,
#   'Street Length': 662.0,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ed'),
#   'Full Name': 'Ralwood Rd',
#   'Longitude': -71.1027365,
#   'Latitude': 42.266609,
#   'Street Length': 84.56,
#   'Cluster': 5},
#  {'_id': ObjectId('5cc64f121877df94dfc0c8ee'),
#   'Full Name': 'Hazelton St',
#   'Longitude': -71.0965875,
#   'Latitude': 42.2809671923,
#   'Street Length': 700.22,
#   'Cluster': 5},
#  ...]

# %%
repo.logout()
endTime = datetime.datetime.now()
{"start":startTime, "end":endTime}
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Database.logout() is deprecated
#   """Entry point for launching an IPython kernel.
# {'start': datetime.datetime(2019, 4, 28, 21, 10, 23, 624038),
#  'end': datetime.datetime(2019, 4, 28, 21, 10, 42, 847114)}

# %%
# doc = prov.model.ProvDocument()
# startTime = None
# endTime = None
# client = dml.pymongo.MongoClient()
# repo = client.repo
# repo.authenticate(contributor, contributor)

# doc.add_namespace('alg', 'http://datamechanics.io/algorithm/') # The scripts are in <folder>#<filename> format.
# doc.add_namespace('dat', 'http://datamechanics.io/data/') # The data sets are in <user>#<collection> format.
# doc.add_namespace('ont', 'http://datamechanics.io/ontology#') # 'Extension', 'DataResource', 'DataSet', 'Retrieval', 'Query', or 'Computation'.
# doc.add_namespace('log', 'http://datamechanics.io/log/') # The event log.
# doc.add_namespace('bdp', 'https://www.50states.com/bio/mass.htm')

# this_script = doc.agent('alg:'+contributor+'#filtered_famous_people_streets', {prov.model.PROV_TYPE:prov.model.PROV['SoftwareAgent'], 'ont:Extension':'py'})
# res_fp = doc.entity('bdp:fp', {'prov:label':'Famous People in MA', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
# res_sb = doc.entity('bdp:sb', {'prov:label':'Street Book', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
# filter_names = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime)
# doc.wasAssociatedWith(filter_names, this_script)
# doc.usage(filter_names, res_fp, startTime, None,
#     {prov.model.PROV_TYPE: 'ont:Computation',
#     'ont:Computation':'Selection, Differentiate'
#     }
# )
# doc.usage(filter_names, res_sb, startTime, None,
#     {prov.model.PROV_TYPE: 'ont:Computation',
#     'ont:Computation':'Selection, Differentiate'
#     }
# )
# result = doc.entity('dat:'+contributor+'#filtered_famous_people_streets', {prov.model.PROV_LABEL:'Streets without Famous People', prov.model.PROV_TYPE:'ont:DataSet'})
# doc.wasAttributedTo(result, this_script)
# doc.wasGeneratedBy(result, filter_names, endTime)
# doc.wasDerivedFrom(result, res_fp, filter_names, filter_names, filter_names)
# doc.wasDerivedFrom(result, res_sb, filter_names, filter_names, filter_names)

# repo.logout()
# doc

# %%
print(result)
# Out:
# [[0, 'Berwick', 'Porter', 'Newfield', 'Glenham', 'Lasell', 'Vermont', 'Chellman', 'Westover', 'Cerdan', 'Pender', 'March', 'Rutledge', 'March', 'Pelton', 'Stratford', 'Colbert', 'Colberg', 'Ardent', 'Edgemont', 'Tennyson', 'Landseer', 'Perham', 'Lyall', 'Ruskin', 'Grayfield', 'Dent', 'Westmount', 'Richwood', 'Landseer', 'Aldrich', 'Clement', 'Burard', 'Houston', 'Broadlawn', 'Brucewood', 'Sanborn', 'Wolfe', 'Potomac', 'Maxfield', 'March', 'Hackensack', 'Thurlow', 'Elgin', 'Graham', 'Ellswood', 'Caspar', 'Carlson', 'Montview', 'Chapin', 'Lyall', 'Durant', 'Capital', 'Kirk', 'Allenwood', 'Bradwood'], [1, 'Dubois', 'Seaver', 'Seaver', 'Howland', 'Tileston', 'Tileston', 'Dearborn', 'Hampden', 'Copeland', 'Burton', 'Dunreath', 'Julian', 'Stafford', 'Gerard', 'Farnham', 'Langdon', 'Burgess', 'Rusfield', 'Sunderland', 'Laredo', 'Thornton', 'Clifton', 'Deckard', 'Ballard', 'Edgewood', 'Kearsarge', 'Moreland', 'Cedric', 'Partridge', 'Judson', 'Leyland', 'Wabeno', 'Otisfield', 'Perth', 'Dorr', 'Millmont', 'Guild', 'Crispus', 'Elbert', 'Akron', 'Kavanaugh', 'Regent', 'Akron', 'Bower', 'Copeland', 'Regent', 'Keegan', 'Roswell', 'Wabon', 'Dunkeld', 'Stanwood', 'Greenheys', 'Logan', 'Munroe', 'Mayfair', 'Creston', 'Balfour', 'Dalkeith', 'Maywood', 'Woodward', 'Gayland', 'Woodledge', 'Hartwell', 'Woodcliff', 'Blanchard', 'Hulbert', 'Maywood', 'Fairland', 'Jarvis', 'Dalin', 'Lester', 'Shabazz', 'Marvin', 'Irwin', 'Irwin', 'Half', 'Woodford', 'Rockledge', 'Fenwick', 'Weldon', 'Stanwood', 'Fenno', 'Regent', 'Edgewood', 'Bard', 'Presby', 'Rockford', 'Newman'], [2, 'Newmarket', 'Binford', 'Damrell', 'Wendeller', 'Burke', 'Cottrell', 'Athens', 'Gustin', 'Iron', 'Cypher', 'Woodward', 'Woodward', 'Earl', 'Mercer', 'Mercer', 'Pacific', 'Covington', 'Rawson', 'Dyer', 'Costello', 'Wormwood', 'Ewer', 'Gifford', 'Patterson', 'Dixfield', 'Carpenter', 'Von', 'Wendell', 'Humboldt', 'Transit', 'Knowlton', 'Grimes', 'Washburn', 'Tuckerman', 'Lovis', 'Rogers', 'Jenkins'], [3, 'Hooker', 'Hichborn', 'Gordon', 'Pomeroy', 'Saunders', 'Spurr', 'Bertram', 'Myrick', 'Farrington', 'Armington', 'Quint', 'Feneno', 'Ashford', 'Athol', 'Wadsworth', 'Windom', 'Kelton', 'Antwerp', 'Guilford', 'Melvin', 'Craftsman', 'Pratt', 'Manton', 'Raymond', 'Babcock', 'McDonald', 'Higgins', 'Portsmouth', 'Duval', 'Bradbury', 'Adamson', 'Telford', 'Ashford', 'Harvester', 'Travis', 'Holman', 'Redford', 'Amboy', 'Ascot', 'Clevemont', 'Appian', 'Mackin', 'Brentwood', 'Alcott', 'Bayard', 'Barrows', 'Vinal', 'Woodstock', 'Walbridge', 'Benson', 'Malvern', 'Harry', 'Fiske', 'Ridgemont', 'Arden', 'Islington', 'Lothrop', 'Wilton'], [4, 'Lawton', 'Chesterfield', 'Perkins', 'Stanbro', 'Knight', 'Glenwood', 'Glenwood', 'Colchester', 'Damon', 'Van', 'Van', 'Fairview', 'Ernest', 'Alvarado', 'Brainard', 'Lawton', 'Waterloo'], [5, 'Clifford', 'Clifford', 'Canaan', 'Kennebec', 'Oakwood', 'Oakwood', 'Hebron', 'Woolson', 'Fessenden', 'Almont', 'Woodhaven', 'Rexford', 'Edgewater', 'Colorado', 'Croydon', 'Harmon', 'Ormond', 'Viking', 'Verrill', 'Crown', 'Poydras', 'Caton', 'Mattakeeset', 'Hollingsworth', 'Hallowell', 'Frazer', 'Frazer', 'Pleasantview', 'Sefton', 'Gilmer', 'Culbert', 'Fairlawn', 'Fremont', 'Banfield', 'Errol', 'Arborcrest', 'Holmfield', 'Rockway', 'Leston', 'Halborn', 'Jamestown'], [6, 'Meehan', 'Whitcomb', 'Arborway', 'Barlow', 'Wilton', 'Wilton', 'Arborway', 'Ballard', 'Seaverns', 'Alveston', 'Newbern', 'Anson', 'Bismarck', 'Bismarck', 'Ellis', 'Ellis', 'Gartland', 'Bardwell', 'Weld', 'Regent', 'Burnett', 'Plainfield', 'Woodman', 'Lochstead', 'Custer', 'Rodman', 'Spalding', 'Atwood', 'Jaeger', 'Patten', 'Lester', 'Greenview', 'Boynton', 'Woodlawn', 'Alveston', 'Craft', 'Aldworth', 'Shurland'], [7, 'Alford', 'Hamblen', 'Cordis', 'Cordis', 'Walford', 'Blaban', 'Cook', 'Cook', 'Holden', 'Polk', 'Arrow', 'Phipps', 'Caldwell', 'Mishawum', 'Dexter', 'Roland', 'Cordis', 'Devens', 'Lawnwood', 'Hathon', 'Holston', 'Ludlow', 'Ellwood', 'Albion'], [8, 'Hillock', 'Penfield', 'Walworth', 'Albano', 'Birc ...

# %%
Street_list = []
for i in range(0, 23):
    for j in range(1, len(result[i])):
        if(result[i][j] not in Street_list):
            Street_list += [result[i][j]]
print(len(Street_list))
# Out:
# 898

# %%
for i in range(0, len(Street_list)):
    num = 0
    for j in range(0, 23):
        for k in range(1, len(result[j])):
            if(Street_list[i] == result[j][k]):
                num = num + 1
    Street_list[i] = (Street_list[i], num)
print(Street_list)
# Out:
# [('Berwick', 1), ('Porter', 3), ('Newfield', 1), ('Glenham', 1), ('Lasell', 1), ('Vermont', 1), ('Chellman', 1), ('Westover', 1), ('Cerdan', 1), ('Pender', 1), ('March', 3), ('Rutledge', 1), ('Pelton', 1), ('Stratford', 1), ('Colbert', 1), ('Colberg', 1), ('Ardent', 1), ('Edgemont', 1), ('Tennyson', 1), ('Landseer', 2), ('Perham', 1), ('Lyall', 2), ('Ruskin', 1), ('Grayfield', 1), ('Dent', 1), ('Westmount', 1), ('Richwood', 1), ('Aldrich', 1), ('Clement', 1), ('Burard', 1), ('Houston', 1), ('Broadlawn', 1), ('Brucewood', 1), ('Sanborn', 1), ('Wolfe', 1), ('Potomac', 1), ('Maxfield', 1), ('Hackensack', 1), ('Thurlow', 1), ('Elgin', 1), ('Graham', 1), ('Ellswood', 1), ('Caspar', 1), ('Carlson', 1), ('Montview', 1), ('Chapin', 1), ('Durant', 1), ('Capital', 1), ('Kirk', 1), ('Allenwood', 1), ('Bradwood', 1), ('Dubois', 1), ('Seaver', 3), ('Howland', 1), ('Tileston', 3), ('Dearborn', 1), ('Hampden', 1), ('Copeland', 2), ('Burton', 2), ('Dunreath', 1), ('Julian', 1), ('Stafford', 1), ('Gerard', 1), ('Farnham', 1), ('Langdon', 2), ('Burgess', 1), ('Rusfield', 1), ('Sunderland', 1), ('Laredo', 1), ('Thornton', 3), ('Clifton', 1), ('Deckard', 1), ('Ballard', 2), ('Edgewood', 2), ('Kearsarge', 1), ('Moreland', 1), ('Cedric', 1), ('Partridge', 2), ('Judson', 1), ('Leyland', 1), ('Wabeno', 1), ('Otisfield', 1), ('Perth', 1), ('Dorr', 1), ('Millmont', 1), ('Guild', 1), ('Crispus', 1), ('Elbert', 1), ('Akron', 2), ('Kavanaugh', 1), ('Regent', 4), ('Bower', 1), ('Keegan', 1), ('Roswell', 1), ('Wabon', 1), ('Dunkeld', 1), ('Stanwood', 2), ('Greenheys', 1), ('Logan', 1), ('Munroe', 1), ('Mayfair', 1), ('Creston', 1), ('Balfour', 1), ('Dalkeith', 1), ('Maywood', 2), ('Woodward', 3), ('Gayland', 1), ('Woodledge', 1), ('Hartwell', 1), ('Woodcliff', 1), ('Blanchard', 1), ('Hulbert', 1), ('Fairland', 1), ('Jarvis', 1), ('Dalin', 1), ('Lester', 2), ('Shabazz', 1), ('Marvin', 1), ('Irwin', 2), ('Half', 1), ('Woodford', 1), ('Rockledge', 1), ('Fenwick', 1), ('Weldon', 1), ('Fenno', 1), ('Bard', 1), ('Presby', 1), ('Rockford', 1), ('Newman', 1), ('Newmarket', 1), ('Binford', 1), ('Damrell', 1), ('Wendeller', 1), ('Burke', 1), ('Cottrell', 1), ('Athens', 1), ('Gustin', 1), ('Iron', 1), ('Cypher', 1), ('Earl', 1), ('Mercer', 2), ('Pacific', 1), ('Covington', 1), ('Rawson', 1), ('Dyer', 2), ('Costello', 1), ('Wormwood', 1), ('Ewer', 1), ('Gifford', 1), ('Patterson', 2), ('Dixfield', 1), ('Carpenter', 1), ('Von', 1), ('Wendell', 2), ('Humboldt', 1), ('Transit', 1), ('Knowlton', 1), ('Grimes', 1), ('Washburn', 1), ('Tuckerman', 1), ('Lovis', 1), ('Rogers', 1), ('Jenkins', 1), ('Hooker', 1), ('Hichborn', 1), ('Gordon', 3), ('Pomeroy', 1), ('Saunders', 1), ('Spurr', 1), ('Bertram', 1), ('Myrick', 1), ('Farrington', 1), ('Armington', 1), ('Quint', 1), ('Feneno', 1), ('Ashford', 2), ('Athol', 1), ('Wadsworth', 1), ('Windom', 1), ('Kelton', 1), ('Antwerp', 1), ('Guilford', 1), ('Melvin', 1), ('Craftsman', 1), ('Pratt', 1), ('Manton', 1), ('Raymond', 1), ('Babcock', 1), ('McDonald', 1), ('Higgins', 1), ('Portsmouth', 1), ('Duval', 1), ('Bradbury', 1), ('Adamson', 1), ('Telford', 1), ('Harvester', 1), ('Travis', 1), ('Holman', 1), ('Redford', 1), ('Amboy', 1), ('Ascot', 1), ('Clevemont', 1), ('Appian', 1), ('Mackin', 1), ('Brentwood', 1), ('Alcott', 1), ('Bayard', 1), ('Barrows', 1), ('Vinal', 1), ('Woodstock', 1), ('Walbridge', 1), ('Benson', 1), ('Malvern', 1), ('Harry', 1), ('Fiske', 1), ('Ridgemont', 1), ('Arden', 1), ('Islington', 1), ('Lothrop', 1), ('Wilton', 3), ('Lawton', 2), ('Chesterfield', 1), ('Perkins', 3), ('Stanbro', 1), ('Knight', 1), ('Glenwood', 2), ('Colchester', 1), ('Damon', 1), ('Van', 4), ('Fairview', 2), ('Ernest', 1), ('Alvarado', 1), ('Brainard', 1), ('Waterloo', 1), ('Clifford', 2), ('Canaan', 1), ('Kennebec', 1), ('Oakwood', 2), ('Hebron', 1), ('Woolson', 1), ('Fessenden', 1), ('Almont', 1), ('Woodhaven', 1), ('Rexford', 1), ('Edgewater', 1), ('Colorado', 1), ('Croydon', 1), ('Harmon', 1), ('Ormond', 1), ('Viking', 2), ('Verrill', 1), ...

# %%
Street_list = [(name, number) for (name, number) in Street_list if number > 1]
print(Street_list)
# Out:
# [('Porter', 3), ('March', 3), ('Landseer', 2), ('Lyall', 2), ('Seaver', 3), ('Tileston', 3), ('Copeland', 2), ('Burton', 2), ('Langdon', 2), ('Thornton', 3), ('Ballard', 2), ('Edgewood', 2), ('Partridge', 2), ('Akron', 2), ('Regent', 4), ('Stanwood', 2), ('Maywood', 2), ('Woodward', 3), ('Lester', 2), ('Irwin', 2), ('Mercer', 2), ('Dyer', 2), ('Patterson', 2), ('Wendell', 2), ('Gordon', 3), ('Ashford', 2), ('Wilton', 3), ('Lawton', 2), ('Perkins', 3), ('Glenwood', 2), ('Van', 4), ('Fairview', 2), ('Clifford', 2), ('Oakwood', 2), ('Viking', 2), ('Crown', 3), ('Frazer', 2), ('Meehan', 2), ('Arborway', 2), ('Alveston', 2), ('Bismarck', 2), ('Ellis', 2), ('Weld', 2), ('Cordis', 3), ('Cook', 2), ('Holden', 2), ('Dexter', 3), ('Albion', 3), ('Ainsworth', 2), ('Florian', 2), ('Walter', 2), ('Atherton', 3), ('Hilburn', 2), ('Larch', 2), ('Lindall', 2), ('Newhall', 2), ('Lombard', 2), ('Endicott', 2), ('Parkman', 3), ('Folsom', 4), ('Leverett', 2), ('Lawn', 2), ('Whitby', 2), ('Bigelow', 2), ('Hardwick', 2), ('Murdock', 2), ('Winship', 2), ('Eastburn', 2), ('Fulton', 2), ('Westcott', 2), ('Eldon', 2), ('Jones', 2), ('Paul', 3), ('Wyman', 2), ('Rockview', 2), ('Fort', 3), ('Hilton', 2), ('Bickford', 2), ('Thatcher', 2), ('Dell', 2), ('Butler', 5), ('Anderson', 2), ('Kilby', 2), ('Bartlett', 5), ('Warrenton', 2), ('Rollins', 2), ('Euclid', 2), ('Greenwich', 3), ('Dawes', 2), ('Freeman', 2), ('Quincefield', 2), ('Belden', 2), ('Duncan', 3), ('Beechwood', 2), ('Birchland', 2), ('Alaric', 2), ('Barnard', 2), ('Decatur', 2), ('Swift', 2), ('Cunard', 2), ('Newland', 2), ('Rutland', 2), ('Pelham', 2), ('Cumston', 2)]

# %%
print(result)
# Out:
# [[0, 'Berwick', 'Porter', 'Newfield', 'Glenham', 'Lasell', 'Vermont', 'Chellman', 'Westover', 'Cerdan', 'Pender', 'March', 'Rutledge', 'March', 'Pelton', 'Stratford', 'Colbert', 'Colberg', 'Ardent', 'Edgemont', 'Tennyson', 'Landseer', 'Perham', 'Lyall', 'Ruskin', 'Grayfield', 'Dent', 'Westmount', 'Richwood', 'Landseer', 'Aldrich', 'Clement', 'Burard', 'Houston', 'Broadlawn', 'Brucewood', 'Sanborn', 'Wolfe', 'Potomac', 'Maxfield', 'March', 'Hackensack', 'Thurlow', 'Elgin', 'Graham', 'Ellswood', 'Caspar', 'Carlson', 'Montview', 'Chapin', 'Lyall', 'Durant', 'Capital', 'Kirk', 'Allenwood', 'Bradwood'], [1, 'Dubois', 'Seaver', 'Seaver', 'Howland', 'Tileston', 'Tileston', 'Dearborn', 'Hampden', 'Copeland', 'Burton', 'Dunreath', 'Julian', 'Stafford', 'Gerard', 'Farnham', 'Langdon', 'Burgess', 'Rusfield', 'Sunderland', 'Laredo', 'Thornton', 'Clifton', 'Deckard', 'Ballard', 'Edgewood', 'Kearsarge', 'Moreland', 'Cedric', 'Partridge', 'Judson', 'Leyland', 'Wabeno', 'Otisfield', 'Perth', 'Dorr', 'Millmont', 'Guild', 'Crispus', 'Elbert', 'Akron', 'Kavanaugh', 'Regent', 'Akron', 'Bower', 'Copeland', 'Regent', 'Keegan', 'Roswell', 'Wabon', 'Dunkeld', 'Stanwood', 'Greenheys', 'Logan', 'Munroe', 'Mayfair', 'Creston', 'Balfour', 'Dalkeith', 'Maywood', 'Woodward', 'Gayland', 'Woodledge', 'Hartwell', 'Woodcliff', 'Blanchard', 'Hulbert', 'Maywood', 'Fairland', 'Jarvis', 'Dalin', 'Lester', 'Shabazz', 'Marvin', 'Irwin', 'Irwin', 'Half', 'Woodford', 'Rockledge', 'Fenwick', 'Weldon', 'Stanwood', 'Fenno', 'Regent', 'Edgewood', 'Bard', 'Presby', 'Rockford', 'Newman'], [2, 'Newmarket', 'Binford', 'Damrell', 'Wendeller', 'Burke', 'Cottrell', 'Athens', 'Gustin', 'Iron', 'Cypher', 'Woodward', 'Woodward', 'Earl', 'Mercer', 'Mercer', 'Pacific', 'Covington', 'Rawson', 'Dyer', 'Costello', 'Wormwood', 'Ewer', 'Gifford', 'Patterson', 'Dixfield', 'Carpenter', 'Von', 'Wendell', 'Humboldt', 'Transit', 'Knowlton', 'Grimes', 'Washburn', 'Tuckerman', 'Lovis', 'Rogers', 'Jenkins'], [3, 'Hooker', 'Hichborn', 'Gordon', 'Pomeroy', 'Saunders', 'Spurr', 'Bertram', 'Myrick', 'Farrington', 'Armington', 'Quint', 'Feneno', 'Ashford', 'Athol', 'Wadsworth', 'Windom', 'Kelton', 'Antwerp', 'Guilford', 'Melvin', 'Craftsman', 'Pratt', 'Manton', 'Raymond', 'Babcock', 'McDonald', 'Higgins', 'Portsmouth', 'Duval', 'Bradbury', 'Adamson', 'Telford', 'Ashford', 'Harvester', 'Travis', 'Holman', 'Redford', 'Amboy', 'Ascot', 'Clevemont', 'Appian', 'Mackin', 'Brentwood', 'Alcott', 'Bayard', 'Barrows', 'Vinal', 'Woodstock', 'Walbridge', 'Benson', 'Malvern', 'Harry', 'Fiske', 'Ridgemont', 'Arden', 'Islington', 'Lothrop', 'Wilton'], [4, 'Lawton', 'Chesterfield', 'Perkins', 'Stanbro', 'Knight', 'Glenwood', 'Glenwood', 'Colchester', 'Damon', 'Van', 'Van', 'Fairview', 'Ernest', 'Alvarado', 'Brainard', 'Lawton', 'Waterloo'], [5, 'Clifford', 'Clifford', 'Canaan', 'Kennebec', 'Oakwood', 'Oakwood', 'Hebron', 'Woolson', 'Fessenden', 'Almont', 'Woodhaven', 'Rexford', 'Edgewater', 'Colorado', 'Croydon', 'Harmon', 'Ormond', 'Viking', 'Verrill', 'Crown', 'Poydras', 'Caton', 'Mattakeeset', 'Hollingsworth', 'Hallowell', 'Frazer', 'Frazer', 'Pleasantview', 'Sefton', 'Gilmer', 'Culbert', 'Fairlawn', 'Fremont', 'Banfield', 'Errol', 'Arborcrest', 'Holmfield', 'Rockway', 'Leston', 'Halborn', 'Jamestown'], [6, 'Meehan', 'Whitcomb', 'Arborway', 'Barlow', 'Wilton', 'Wilton', 'Arborway', 'Ballard', 'Seaverns', 'Alveston', 'Newbern', 'Anson', 'Bismarck', 'Bismarck', 'Ellis', 'Ellis', 'Gartland', 'Bardwell', 'Weld', 'Regent', 'Burnett', 'Plainfield', 'Woodman', 'Lochstead', 'Custer', 'Rodman', 'Spalding', 'Atwood', 'Jaeger', 'Patten', 'Lester', 'Greenview', 'Boynton', 'Woodlawn', 'Alveston', 'Craft', 'Aldworth', 'Shurland'], [7, 'Alford', 'Hamblen', 'Cordis', 'Cordis', 'Walford', 'Blaban', 'Cook', 'Cook', 'Holden', 'Polk', 'Arrow', 'Phipps', 'Caldwell', 'Mishawum', 'Dexter', 'Roland', 'Cordis', 'Devens', 'Lawnwood', 'Hathon', 'Holston', 'Ludlow', 'Ellwood', 'Albion'], [8, 'Hillock', 'Penfield', 'Walworth', 'Albano', 'Birc ...

# %%
for k in range(0, len(Street_list)):
    for i in range(0, 23):
        for j in range(1, len(result[i])):
            if(Street_list[k][0] == result[i][j]):
                Street_list[k] = (i, Street_list[k][0], Street_list[k][1])
print(Street_list)
# Out:
# [(0, 'Porter', 3), (0, 'March', 3), (0, 'Landseer', 2), (0, 'Lyall', 2), (1, 'Seaver', 3), (1, 'Tileston', 3), (1, 'Copeland', 2), (1, 'Burton', 2), (1, 'Langdon', 2), (1, 'Thornton', 3), (1, 'Ballard', 2), (1, 'Edgewood', 2), (1, 'Partridge', 2), (1, 'Akron', 2), (1, 'Regent', 4), (1, 'Stanwood', 2), (1, 'Maywood', 2), (1, 'Woodward', 3), (1, 'Lester', 2), (1, 'Irwin', 2), (2, 'Mercer', 2), (2, 'Dyer', 2), (2, 'Patterson', 2), (2, 'Wendell', 2), (3, 'Gordon', 3), (3, 'Ashford', 2), (3, 'Wilton', 3), (4, 'Lawton', 2), (4, 'Perkins', 3), (4, 'Glenwood', 2), (4, 'Van', 4), (4, 'Fairview', 2), (5, 'Clifford', 2), (5, 'Oakwood', 2), (5, 'Viking', 2), (5, 'Crown', 3), (5, 'Frazer', 2), (6, 'Meehan', 2), (6, 'Arborway', 2), (6, 'Alveston', 2), (6, 'Bismarck', 2), (6, 'Ellis', 2), (6, 'Weld', 2), (7, 'Cordis', 3), (7, 'Cook', 2), (7, 'Holden', 2), (7, 'Dexter', 3), (7, 'Albion', 3), (8, 'Ainsworth', 2), (8, 'Florian', 2), (8, 'Walter', 2), (8, 'Atherton', 3), (8, 'Hilburn', 2), (8, 'Larch', 2), (8, 'Lindall', 2), (9, 'Newhall', 2), (9, 'Lombard', 2), (9, 'Endicott', 2), (9, 'Parkman', 3), (10, 'Folsom', 4), (11, 'Leverett', 2), (11, 'Lawn', 2), (11, 'Whitby', 2), (12, 'Bigelow', 2), (12, 'Hardwick', 2), (12, 'Murdock', 2), (12, 'Winship', 2), (12, 'Eastburn', 2), (13, 'Fulton', 2), (13, 'Westcott', 2), (13, 'Eldon', 2), (13, 'Jones', 2), (14, 'Paul', 3), (14, 'Wyman', 2), (14, 'Rockview', 2), (14, 'Fort', 3), (14, 'Hilton', 2), (14, 'Bickford', 2), (15, 'Thatcher', 2), (15, 'Dell', 2), (16, 'Butler', 5), (16, 'Anderson', 2), (16, 'Kilby', 2), (16, 'Bartlett', 5), (16, 'Warrenton', 2), (16, 'Rollins', 2), (17, 'Euclid', 2), (18, 'Greenwich', 3), (18, 'Dawes', 2), (18, 'Freeman', 2), (18, 'Quincefield', 2), (18, 'Belden', 2), (18, 'Duncan', 3), (18, 'Beechwood', 2), (19, 'Birchland', 2), (19, 'Alaric', 2), (20, 'Barnard', 2), (21, 'Decatur', 2), (21, 'Swift', 2), (21, 'Cunard', 2), (22, 'Newland', 2), (22, 'Rutland', 2), (22, 'Pelham', 2), (22, 'Cumston', 2)]

# %%
cluster_num = []
for i in range(0, 23):
    max = 0
    for j in range(0, len(Street_list)):
        if(i == Street_list[j][0]):
            if(max < Street_list[j][2]):
                max = Street_list[j][2]
    cluster_num += [(i, max)]
print(cluster_num)
# Out:
# [(0, 3), (1, 4), (2, 2), (3, 3), (4, 4), (5, 3), (6, 2), (7, 3), (8, 3), (9, 3), (10, 4), (11, 2), (12, 2), (13, 2), (14, 3), (15, 2), (16, 5), (17, 2), (18, 3), (19, 2), (20, 2), (21, 2), (22, 2)]

# %%
Street_list = [(cluster, name, number) for (cluster, name, number) in Street_list 
               for (cluster2, num) in cluster_num if number == num and cluster == cluster2]
print(Street_list)
# Out:
# [(0, 'Porter', 3), (0, 'March', 3), (1, 'Regent', 4), (2, 'Mercer', 2), (2, 'Dyer', 2), (2, 'Patterson', 2), (2, 'Wendell', 2), (3, 'Gordon', 3), (3, 'Wilton', 3), (4, 'Van', 4), (5, 'Crown', 3), (6, 'Meehan', 2), (6, 'Arborway', 2), (6, 'Alveston', 2), (6, 'Bismarck', 2), (6, 'Ellis', 2), (6, 'Weld', 2), (7, 'Cordis', 3), (7, 'Dexter', 3), (7, 'Albion', 3), (8, 'Atherton', 3), (9, 'Parkman', 3), (10, 'Folsom', 4), (11, 'Leverett', 2), (11, 'Lawn', 2), (11, 'Whitby', 2), (12, 'Bigelow', 2), (12, 'Hardwick', 2), (12, 'Murdock', 2), (12, 'Winship', 2), (12, 'Eastburn', 2), (13, 'Fulton', 2), (13, 'Westcott', 2), (13, 'Eldon', 2), (13, 'Jones', 2), (14, 'Paul', 3), (14, 'Fort', 3), (15, 'Thatcher', 2), (15, 'Dell', 2), (16, 'Butler', 5), (16, 'Bartlett', 5), (17, 'Euclid', 2), (18, 'Greenwich', 3), (18, 'Duncan', 3), (19, 'Birchland', 2), (19, 'Alaric', 2), (20, 'Barnard', 2), (21, 'Decatur', 2), (21, 'Swift', 2), (21, 'Cunard', 2), (22, 'Newland', 2), (22, 'Rutland', 2), (22, 'Pelham', 2), (22, 'Cumston', 2)]

# %%
Street_list = [(cluster, fullName, number) for (cluster, name, number) in Street_list 
               for (cluster2, fullName) in later_use if fullName.startswith(name) and cluster == cluster2 ]
print(Street_list)
# Out:
# [(0, 'Porter Ter', 3), (0, 'March Ave', 3), (0, 'March Way', 3), (0, 'March Ter', 3), (1, 'Regent Pl', 4), (1, 'Regent St', 4), (1, 'Regent Sq', 4), (2, 'Mercer St', 2), (2, 'Dyer Ave', 2), (2, 'Patterson Way', 2), (2, 'Wendeller St', 2), (2, 'Wendell Pl', 2), (3, 'Gordon St', 3), (3, 'Gordon Rd', 3), (3, 'Wilton Ter', 3), (4, 'Van Brunt St', 4), (4, 'Van Brunt', 4), (5, 'Crown St', 3), (6, 'Meehan St', 2), (6, 'Arborway', 2), (6, 'Arborway Ter', 2), (6, 'Alveston St', 2), (6, 'Alveston Ter', 2), (6, 'Bismarck St', 2), (6, 'Ellis St', 2), (6, 'Weld Hill St', 2), (7, 'Cordis St', 3), (7, 'Cordis Street Ave', 3), (7, 'Dexter Row', 3), (7, 'Dexter Ct', 3), (7, 'Albion Pl', 3), (8, 'Atherton Ave', 3), (9, 'Parkman Pl', 3), (10, 'Folsom Ave', 4), (11, 'Leverett Ave', 2), (11, 'Lawn Ave', 2), (11, 'Whitby St', 2), (12, 'Bigelow St', 2), (12, 'Bigelow Cir', 2), (12, 'Hardwick St', 2), (12, 'Hardwick Ter', 2), (12, 'Murdock Ter', 2), (12, 'Murdock St', 2), (12, 'Winship St', 2), (12, 'Winship Pl', 2), (12, 'Eastburn Footway', 2), (12, 'Eastburn Pl', 2), (12, 'Eastburn St', 2), (13, 'Fulton St', 2), (13, 'Westcott St', 2), (13, 'Eldon St', 2), (13, 'Jones Ave', 2), (14, 'Paul Gore St', 3), (14, 'Paul Gore Ter', 3), (14, 'Fort Ave', 3), (14, 'Fort Avenue Ter', 3), (15, 'Thatcher St', 2), (15, 'Dell Ter', 2), (15, 'Dell Ave', 2), (16, 'Butler Row', 5), (16, 'Butler Sq', 5), (16, 'Butler Pl', 5), (16, 'Bartlett Pl', 5), (17, 'Euclid St', 2), (18, 'Greenwich St', 3), (18, 'Duncan St', 3), (18, 'Duncan Ter', 3), (18, 'Duncan Pl', 3), (19, 'Birchland Ave', 2), (19, 'Birchland Ter', 2), (19, 'Alaric St', 2), (19, 'Alaric Ter', 2), (20, 'Barnard Pl', 2), (21, 'Decatur St', 2), (21, 'Swift St', 2), (21, 'Swift Ter', 2), (21, 'Cunard Way', 2), (22, 'Newland St', 2), (22, 'Newland Pl', 2), (22, 'Rutland St', 2), (22, 'Rutland Sq', 2), (22, 'Pelham St', 2), (22, 'Pelham Ter', 2), (22, 'Cumston St', 2), (22, 'Cumston Pl', 2)]

# %%
Street_list = [(cluster, fullName, length) for (cluster, fullName, length) in Street_list
              for (name, loc, length) in street_agg_list if fullName == name]

print(Street_list)
# Out:
# [(0, 'Porter Ter', 112.11), (0, 'March Ave', 158.2), (0, 'March Way', 48.97), (0, 'March Ter', 40.75), (1, 'Regent Pl', 28.93), (1, 'Regent St', 631.5699999999999), (1, 'Regent Sq', 37.58), (2, 'Mercer St', 548.87), (2, 'Dyer Ave', 53.72), (2, 'Patterson Way', 306.58), (2, 'Wendeller St', 73.24), (2, 'Wendell Pl', 39.11), (3, 'Gordon St', 722.96), (3, 'Gordon Rd', 159.93), (3, 'Wilton Ter', 27.03), (4, 'Van Brunt St', 280.53), (4, 'Van Brunt', 7.19), (5, 'Crown St', 71.48), (6, 'Meehan St', 187.62), (6, 'Arborway', 6485.029999999997), (6, 'Arborway Ter', 77.42), (6, 'Alveston St', 282.65), (6, 'Alveston Ter', 59.33), (6, 'Bismarck St', 325.92999999999995), (6, 'Ellis St', 261.4), (6, 'Weld Hill St', 323.74999999999994), (7, 'Cordis St', 169.63), (7, 'Cordis Street Ave', 51.34), (7, 'Dexter Row', 46.800000000000004), (7, 'Dexter Ct', 69.63), (7, 'Albion Pl', 119.3), (8, 'Atherton Ave', 158.63), (9, 'Parkman Pl', 61.22), (10, 'Folsom Ave', 85.28), (11, 'Leverett Ave', 156.9), (11, 'Lawn Ave', 93.29), (11, 'Whitby St', 133.83), (12, 'Bigelow St', 973.05), (12, 'Bigelow Cir', 75.84), (12, 'Hardwick St', 231.25), (12, 'Hardwick Ter', 35.58), (12, 'Murdock Ter', 31.45), (12, 'Murdock St', 621.21), (12, 'Winship St', 458.33), (12, 'Winship Pl', 35.47), (12, 'Eastburn Footway', 69.7), (12, 'Eastburn Pl', 83.22), (12, 'Eastburn St', 204.73000000000002), (13, 'Fulton St', 429.79999999999995), (13, 'Westcott St', 228.88), (13, 'Eldon St', 313.12), (13, 'Jones Ave', 393.19), (14, 'Paul Gore St', 612.03), (14, 'Paul Gore Ter', 43.3), (14, 'Fort Ave', 412.88), (14, 'Fort Avenue Ter', 92.8), (15, 'Thatcher St', 454.35), (15, 'Dell Ter', 90.98), (15, 'Dell Ave', 250.42), (16, 'Butler Row', 56.38), (16, 'Butler Sq', 33.84), (16, 'Butler Pl', 19.17), (16, 'Bartlett Pl', 106.39), (17, 'Euclid St', 143.03), (18, 'Greenwich St', 445.69), (18, 'Duncan St', 199.48000000000002), (18, 'Duncan Ter', 47.48), (18, 'Duncan Pl', 47.84), (19, 'Birchland Ave', 196.01999999999998), (19, 'Birchland Ter', 57.95), (19, 'Alaric St', 220.32), (19, 'Alaric Ter', 57.44), (20, 'Barnard Pl', 44.66), (21, 'Decatur St', 494.41), (21, 'Swift St', 185.77), (21, 'Swift Ter', 75.44), (21, 'Cunard Way', 61.03), (22, 'Newland St', 558.92), (22, 'Newland Pl', 182.89), (22, 'Rutland St', 377.55999999999995), (22, 'Rutland Sq', 248.03), (22, 'Pelham St', 112.3), (22, 'Pelham Ter', 50.73), (22, 'Cumston St', 74.94), (22, 'Cumston Pl', 50.85)]

# %%
alternate_street = [(0, 'March Ter', 40.75),
                    (1, 'Regent Pl', 28.93),
                    (2, 'Wendell Pl', 39.11),
                    (3, 'Gordon Rd', 159.93),
                    (4, 'Van Brunt', 7.19),
                    (5, 'Crown St', 71.48),
                    (6, 'Alveston Ter', 59.33),
                    (7, 'Dexter Row', 46.800000000000004),
                    (8, 'Atherton Ave', 158.63),
                    (9, 'Parkman Pl', 61.22),
                    (10, 'Folsom Ave', 85.28),
                    (11, 'Lawn Ave', 93.29),
                    (12, 'Winship Pl', 35.47),
                    (13, 'Westcott St', 228.88),
                    (14, 'Paul Gore Ter', 43.3),
                    (15, 'Dell Ter', 90.98),
                    (16, 'Butler Pl', 19.17),
                    (17, 'Euclid St', 143.03),
                    (18, 'Duncan Ter', 47.48),
                    (19, 'Alaric Ter', 57.44),
                    (20, 'Barnard Pl', 44.66),
                    (21, 'Swift Ter', 75.44),
                    (22, 'Pelham Ter', 50.73)]
print(alternate_street)
# Out:
# [(0, 'March Ter', 40.75), (1, 'Regent Pl', 28.93), (2, 'Wendell Pl', 39.11), (3, 'Gordon Rd', 159.93), (4, 'Van Brunt', 7.19), (5, 'Crown St', 71.48), (6, 'Alveston Ter', 59.33), (7, 'Dexter Row', 46.800000000000004), (8, 'Atherton Ave', 158.63), (9, 'Parkman Pl', 61.22), (10, 'Folsom Ave', 85.28), (11, 'Lawn Ave', 93.29), (12, 'Winship Pl', 35.47), (13, 'Westcott St', 228.88), (14, 'Paul Gore Ter', 43.3), (15, 'Dell Ter', 90.98), (16, 'Butler Pl', 19.17), (17, 'Euclid St', 143.03), (18, 'Duncan Ter', 47.48), (19, 'Alaric Ter', 57.44), (20, 'Barnard Pl', 44.66), (21, 'Swift Ter', 75.44), (22, 'Pelham Ter', 50.73)]

# %%
alternate_street = [(name, length, loc) for (cluster, name, length) in alternate_street
                   for (fullName, loc, len) in street_agg_list if name == fullName]
print(alternate_street)
# Out:
# [('March Ter', 40.75, [[-71.15531399999999, 42.283204], [-71.154899, 42.283004999999996]]), ('Regent Pl', 28.93, [[-71.084115, 42.325593999999995], [-71.084358, 42.325782]]), ('Wendell Pl', 39.11, [[-71.05377299999999, 42.329260999999995], [-71.053735, 42.32891]]), ('Gordon Rd', 159.93, [[-71.12512399999999, 42.366144999999996], [-71.12477099999998, 42.365984999999995], [-71.124133, 42.365726999999985], [-71.12372599999999, 42.36560099999999], [-71.12338799999999, 42.365508999999996]]), ('Van Brunt', 7.19, [[-71.122568, 42.241206999999996], [-71.12254799999998, 42.24114399999999]]), ('Crown St', 71.48, [[-71.108099, 42.266566], [-71.10864, 42.266408], [-71.108892, 42.266309]]), ('Alveston Ter', 59.33, [[-71.11139299999999, 42.311398], [-71.11202899999999, 42.311648]]), ('Dexter Row', 46.800000000000004, [[-71.063828, 42.375704999999996], [-71.06378499999998, 42.37574999999999], [-71.06396699999999, 42.375276], [-71.063644, 42.375553]]), ('Atherton Ave', 158.63, [[-71.130348, 42.284393], [-71.130253, 42.284074], [-71.130242, 42.283849], [-71.13095, 42.283148]]), ('Parkman Pl', 61.22, [[-71.0578, 42.29757], [-71.05754999999999, 42.297050999999996]]), ('Folsom Ave', 85.28, [[-71.09875999999998, 42.32970699999999], [-71.099197, 42.329895], [-71.099197, 42.329895], [-71.09908899999999, 42.330062999999996], [-71.099197, 42.329895], [-71.09931, 42.329706]]), ('Lawn Ave', 93.29, [[-70.996403, 42.38841399999999], [-70.995671, 42.38905499999999]]), ('Winship Pl', 35.47, [[-71.15162899999999, 42.34740399999999], [-71.15124899999999, 42.347253999999985]]), ('Westcott St', 228.88, [[-71.079033, 42.294239999999995], [-71.078969, 42.293766], [-71.078808, 42.292747999999996], [-71.078705, 42.292193999999995]]), ('Paul Gore Ter', 43.3, [[-71.107238, 42.319626], [-71.107528, 42.319300999999996]]), ('Dell Ter', 90.98, [[-71.119401, 42.259192999999996], [-71.119299, 42.259122], [-71.120105, 42.259681], [-71.119401, 42.259192999999996]]), ('Butler Pl', 19.17, [[-71.05781899999998, 42.366987999999985], [-71.057985, 42.366866999999985]]), ('Euclid St', 143.03, [[-71.071119, 42.288734999999996], [-71.071846, 42.288488], [-71.072728, 42.288258]]), ('Duncan Ter', 47.48, [[-71.058149, 42.302210999999986], [-71.058649, 42.301998999999995]]), ('Alaric Ter', 57.44, [[-71.162238, 42.276587], [-71.162196, 42.276669], [-71.16203399999999, 42.276813999999995], [-71.16178, 42.276964]]), ('Barnard Pl', 44.66, [[-71.039264, 42.337246], [-71.039276, 42.336844]]), ('Swift Ter', 75.44, [[-71.02176699999998, 42.38051399999999], [-71.021776, 42.380486999999995], [-71.02183099999999, 42.38040699999999], [-71.022322, 42.38001899999999], [-71.022361, 42.38001299999999]]), ('Pelham Ter', 50.73, [[-71.0708, 42.341595], [-71.071247, 42.341280999999995]])]

# %%
# output_street_location_df = pd.DataFrame(output_street_location)
# output_street_location_df.columns = ['Full Name', 'Longitude', 'Latitude', 'Street Length', 'Cluster']
# output_street_location_df.to_csv("/Users/zjallenjiang/Documents/GitHub/street_location.csv")

alternate_street_df = pd.DataFrame(alternate_street)
alternate_street_df.columns = ["FullName", "Length", "Location"]
alternate_street_df.to_json(path_or_buf = "/Users/zjallenjiang/Documents/GitHub/street_alternate.json", orient="records")
