# %%
import pandas as pd
import requests
import json
import dml
import prov.model
import datetime
import uuid
import csv 
from io import StringIO
import json
import pymongo
import numpy as np

# %%
contributor = 'mmao95_Dongyihe_weijiang_zhukk'
reads = [contributor + '.cau_landmark_merge', contributor + '.public_libraries', contributor + '.street_book']
writes = [contributor + '.filter_Streetbook_version_1']

# %%
startTime = datetime.datetime.now()

# Set up the database connection.
client = dml.pymongo.MongoClient()
repo = client.repo
repo.authenticate(contributor, contributor)
# Out:
# True

# %%
CAU_landmark_merge_list = list(repo[reads[0]].find())
CAU_landmark_merge_df = pd.DataFrame(CAU_landmark_merge_list)
CAU_landmark_merge_list = np.array(CAU_landmark_merge_df).tolist()

Public_libraries_list = list(repo[reads[1]].find())
Public_libraries_df = pd.DataFrame(Public_libraries_list)
Public_libraries_list = np.array(Public_libraries_df).tolist()

Streetbook_list = list(repo[reads[2]].find())
Streetbook_df = pd.DataFrame(Streetbook_list)
Streetbook_list = np.array(Streetbook_df).tolist()

# %%
# process CAU_landmark dataset
CAU_landmark = [(adress, name) for (adress, name, neighbourhood, id) in CAU_landmark_merge_list]
CAU_landmark = [(adress.split(",")[0], name) for (adress, name) in CAU_landmark]

# process public library dataset
Public_libraries = [adress for (adress, branchName, city, latitude, longitude, numbers, zipcode, id) in Public_libraries_list]

# process street book dataset
Streetbook = [(fullName, streetName, zipcode) for (fullName, gender, gender2, nameLength, rank, streetName, zipcode, id) in Streetbook_list]
Streetbook = [(fullName, streetName.split(' ')[0], zipcode) for (fullName, streetName, zipcode) in Streetbook]

# %%
# filter CAU_landmark
for i in range(len(Streetbook) - 1, -1, -1):
    for j in range(0, len(CAU_landmark)):
        if ((Streetbook[i][1] in CAU_landmark[j][0]) or (Streetbook[i][1] in CAU_landmark[j][1])):
            del Streetbook[i]
            

# filter public libraries
for i in range(len(Streetbook) - 1, -1, -1):
    for j in range(0, len(Public_libraries)):
        if (Streetbook[i][1] in Public_libraries[j]):
            del Streetbook[i]

print(len(Streetbook))
# Out:
# 40020

# %%
# filter public library names
Public_library_names = ["Boston Public Library", "Honan-Allston Branch of the Boston Public Library", "Brighton Branch of the Boston Public Library",
                       "Chinatown Branch Boston Public Library", "South End Branch of the Boston Public Library", "West End Branch of the Boston Public Library",
                       "North End Branch of the Boston Public Library", "Connolly Branch of the Boston Public Library", "Faneuil Branch of the Boston Public Library",
                       "Mugar Memorial Library", "Parker Hill Branch of the Boston Public Library", "Dudley Branch of the Boston Public Library", "East Boston Branch of the Boston Public Library",
                       "South Boston Branch Boston Public Library", "Codman Square Branch of the Boston Public Library", "Frederick S. Pardee Management Library",
                       "Jamaica Plain Branch of the Boston Public Library", "Egleston Square Branch of the Boston Public Library", "Charlestown Branch of the Boston Public Library",
                       "Grove Hall Branch of the Boston Public Library", "West Roxbury Branch of the Boston Public Library","Roslindale Branch of the Boston Public Library",
                       "Uphams Corner Branch of the Boston Public Library", "Boston College Theology and Ministry Library", "Music Library Boston University", "Stone Science Library", 
                       "Adams Street Branch of the Boston Public Library", "Fields Corner Branch Boston Public Library", "Hyde Park Branch of the Boston Public Library",
                       "Albert Alphin Music Library", "Mattapan Branch of the Boston Public Library", "Lower Mills Branch of the Boston Public Library", "State Library of Massachusetts",
                       "Boston University Visual Arts Resource Library", "Insurance Library Association-Boston", "Fineman & Pappas Law Libraries","African Studies Library",
                       "Science and Engineering Library", "Pickering Educational Resources Library"]
Old_names = [
"Adjutant-Generals Library",
"Almshouse Library",
"American Academy of Arts and Sciences Library",
"American Baptist Union Library",
"American Board of Commissioners for Foreign Missions Library",
"American Institute of Instruction Library",
"American Peace Society Library",
"American Statistical Association Library",
"American Unitarian Association",
"Mary Ashley, no.124 Charles St.",
"Asylum and Farm School Library",
"Backups Circulating Library",
"Luke Bakers circulating library, no.69 Court St.",
"Berkeley Circulating Library",
"Bigelow School Library",
"Bixbys Circulating Library;2 L.W. Bixby, Washington St.6",
"William Pinson Blake and Lemuel Blake, circulating library at the Boston Book-Store, no.1, Cornhill7",
"Board of Trade Library12",
"Boston and Albany Railroad Library (est.1868)8",
"Boston Art Club Library2",
"Boston Athenaeum",
"Boston Circulating Library, no.3 School St.; E. Penniman Jr.;9 no.5 Cornhill-Square10",
"Boston City Hospital Library2",
"Boston College Library2",
"Boston Library Society2",
"Boston Lunatic Hospital Library2",
"Boston Medical Library (1805-1826)11",
"Boston Medical Library (est. 1875)",
"Boston Public Library",
"Boston Society for Medical Improvement1",
"Boston Society of Natural History Library12",
"Boston Society of the New Jerusalem Church Library2",
"Boston Theological Library211",
"Boston Turnverein Library2",
"Boston University",
"Boston University Library2",
"Boston University School of Medicine Library2",
"Boston University Theological Library2",
"Boston Young Mens Christian Union Library,2 no.20 Boylston6",
"Bowditch Library1",
"Bowdoin Literary Association1",
"Boylston Library12",
"Brattle Square Church Library2",
"Broadway Circulating Library2",
"Bromfield Street Church Library2",
"Eliza Brown, circulating library13",
"Bulfinch Place Chapel Library2",
"Burnham & Bros., no.60 Cornhill;14 Thomas Burnham, Perry Burnham12",
"Kezia Butler, no.82 Newbury Street1215",
"Campbells Circulating Library2",
"Carney Hospital Library2",
"Carters Circulating Library212",
"Callenders Library, School St.; also known as the Shakespeare Library; Charles Callender, H.G. Callender31216",
"Charlestown High School Library2",
"Christ Church Library2",
"Christian Unity Library2",
"Church Home for Orphans Library2",
"Church of the Advent Library2",
"City Point Circulating Library2",
"Clarendon Library, Clarendon St.6",
"W.B. Clarkes circulating library12",
"Columbian Circulating Library, no.43 Cornhill",
"Columbian Social Library (est.1813), Boylston Hall1718",
"Comers Commercial College1",
"Congregational Library & Archives,2 corner of Beacon and Somerset16",
"Consumptives Home Library2",
"Deaf Mute Library Association2",
"Democratic reading room, corner Congress St. and Congress Sq.3",
"Dorchester Athenaeum Library2",
"Dramatic Fund Association1",
"J.H. Duclos & Bro., no.57 Warren St.6",
"East Boston Library Association1",
"Ministerial Library of Eliot Church2",
"Caroline Fanning19",
"Farrers Circulating Library2",
"First Christian Church Library2",
"First Universalist Church Library2",
"Frederick Fletcher, no.55 Meridian, East Boston20",
"Franklin Circulating Library, no.69 Court St.21",
"Franklin Typographical Society Library12",
"Gate of Heaven Church Library2",
"Library of the General Court1",
"General Theological Library (est.1860);212 no.12 West St.6",
"Gills Circulating Library2",
"Good Samaritan Church Library2",
"Grand Lodge of Masons Library2",
"Grant & Brown, no.873 Washington St.6",
"Guild Library of Church of the Advent2",
"Hallidays Circulating Library, West St.25",
"Hancock Library, 42 Hancock; A. Boyden22",
"Handel and Haydn Library1",
"Harvard Chapel Library2",
"Harvard Musical Library2",
"Medical College of Harvard University Library2",
"C.W. Holbrooks circulating library; no.88 Dover6",
"Holy Trinity Church Library2",
"Home for Aged Women Library2",
"House of Correction Library2",
"House of Industry Library2",
"House of Reformation Library2",
"Jamaica Plain Circulating Library2",
"Joy Street Baptist Church Library2",
"Keatings Circulating Library;2 no.1027 Washington St.6",
"Kings Chapel Library1",
"Ladies Circulating Library, Washington St.; N. Nutting, proprietor19",
"Lawrence Association Library2",
"R.L. Learneds circulating library, Tremont St.5",
"Lincoln School Library2",
"Lindsays Circulating Library;2 George W. Lindsey, Washington St.20",
"Liscombs Circulating Library2",
"Lorings Circulating Library;2 Lorings Select Library, Washington St.;20 A.K. Loring12",
"A.F. Lows circulating library, Meridian St.5",
"Lowes Circulating Library2",
"Marine Board of Underwriters Library2",
"Mariners Exchange reading room, no.1 Lewis20",
"Mariners House, North Square23",
"Thomas Marshs circulating library, Beach St.5",
"Massachusetts College of Pharmacy1",
"Massachusetts Historical Society",
"Massachusetts Horticultural Society Library2",
"Massachusetts Hospital1",
"Massachusetts New Church Union Library2",
"Massachusetts School for Idiotic and Feeble-minded Youth1",
"Massachusetts Society for Promotion of Agriculture1",
"Massachusetts State Library",
"Massachusetts State Prison Library2",
"Massachusetts Teachers Association1",
"Massachusetts Total Abstinence Society Library2",
"Mayhew and Bakers Juvenile Circulating Library, no.208 Washington St.12",
"McGraths Circulating Library2",
"Mechanic Apprentices Library Association2",
"J.O. Mendums circulating library, Tremont St.5",
"Mercantile Library Association Library2",
"Merchants Exchange reading room, Merchants Exchange building, State St.;24 basement, Old State House",
"Merrills Circulating Library;2 C.H. Merrill, no.1575 Washington St.6",
"Methodist Episcopal Church Library2",
"Catherine Moores circulating library, no.436 Washington St.314",
"Mount Vernon Church Library2",
"Mount Vernon School for Young Ladies1",
"Munroe & Francis, juvenile library, no.4 Cornhill25",
"Musical Society Library12",
"New England Conservatory of Music Library2",
"New England Female Medical College1",
"New England Historic Genealogical Society2",
"New England Hospital Library2",
"New England Methodist Historical Society1",
"Norcross School Library2",
"North End Circulating Library, no.123 Hanover St.; Thomas Hiller Jr.326",
"Notre Dame Academy Library2",
"Odd Fellows Library2",
"Old Colony Chapel Library2",
"Osgoods Circulating Library2",
"Paines Circulating Library2",
"Samuel H. Parkers circulating library",
"H.B. Payne & Co.s circulating library5",
"Elizabeth Peabodys foreign circulating library, no.13 West St.3",
"William Pelhams circulating library, no.59 Cornhill",
"Penitent Female Refuge Society Library2",
"F.W. Perkins circulating library5",
"Library of Perkins Institution for the Blind12",
"Pioneer Circulating Library2",
"Prince Library27",
"Quinns Circulating Library2",
"Lydia Reed19",
"Republican Institution1",
"Republican Reading Room, Bromfield St.20",
"E.R. Rich & Son; no.477 West Broadway6",
"Roxbury Athenaeum Library2",
"Roxbury High School Library2",
"Sages Circulating Library;2 William Sage, no.371 Tremont6",
"Sailors Home Library2",
"School of Technology Library2",
"Second Methodist Church Library2",
"W.F. & M.H. Shattuck, no.106 Main6",
"Shawmut Avenue Baptist Church Library2",
"Shawmut Mission Library2",
"Social Law Library2",
"Society to Encourage Studies at Home",
"South End Circulating Library2",
"Mary Spragues circulating library, no.9 Milk St.1228",
"St. Francis de Sales Church Library2",
"St. Joseph Circulating Library2",
"St. Marys Young Mens Sodality Library2",
"St. Stephens Church Library2",
"State Agricultural Library2",
"Stoughton Street Church Library2",
"Suffolk Circulating Library; corner of Court and Brattle St.; N.S. Simpkins, J. Simpkins29",
"Sumner library, no.6 Winthrop block, East Boston20",
"Teuthorns Circulating Library;2 Julius Teuthorn, no.10 Beach6",
"George Ticknors private library, no.8 Park St.",
"Toll-Gate Circulating Library,2 no.665 East Broadway56",
"D.A. Tompkins, no.127 Hanover St.14",
"Treadwell Library, Massachusetts General Hospital2",
"Union Circulating Library, no.4 Cornhill, corner of Water St.;30 William Blagrove",
"Union Mission Church Library2",
"Unitarian Association Library2",
"S.R. Urbino, foreign circulating library",
"Village Church Library2",
"Vine Street Congregational Church Library2",
"Walkers Circulating Library2",
"J.B. Walker, no.1392 Tremont6",
"Thomas O. Walker, no.68 Cornhill3512",
"Warren Street Chapel Library2",
"Washington Circulating Library, no.38 Newbury St.31",
"Washington Circulating Library, no.11 School St.32",
"Washingtonian Home Library2",
"West Boston Library, Cambridge St.12",
"West Church Library2",
"West Roxbury Free library, Centre St.6",
"West Roxbury High School Library2",
"Whig reading room, no.144 Washington St.3",
"Winkley & Boyds Central library20",
"Workingmens Reading Room",
"Boston Young Mens Christian Association Library (YMCA),2 Tremont Temple120",
"Young Mens Christian Union1",
"Young Womens Christian Association (YWCA), no.68 Warrenton6",
"Young Mens Working Association Library2",
"Zion Church Library2"]

Public_library_names = Public_library_names + Old_names

for i in range(len(Streetbook) - 1, -1, -1):
    for j in range(0, len(Public_library_names)):
        if (Streetbook[i][1] in Public_library_names[j]):
            del Streetbook[i]



print(len(Streetbook))
# Out:
# 38300

# %%
#  filter reduant zipCode
for i in range(len(Streetbook) - 1, -1, -1):
    if(Streetbook[i][2].find("-") != -1):
        del Streetbook[i]

for i in range(len(Streetbook) - 1, -1, -1):
    if(Streetbook[i][0] == '' or Streetbook[i][1] == '' or Streetbook[i][2] == ''):
        del Streetbook[i]

print(Streetbook)
# Out:
# [('Abbot Street,', 'Abbot', '02124'), ('Abbotsford Street,', 'Abbotsford', '02121'), ('Abby Road,', 'Abby', '02135'), ('Aberdeen Street,', 'Aberdeen', '02215'), ('Acacia Road,', 'Acacia', '02132'), ('Academic Way,', 'Academic', '02134'), ('Acadia Street,', 'Acadia', '02127'), ('Achorn Circle,', 'Achorn', '02130'), ('Ackley Place,', 'Ackley', '02130'), ('Acorn Street,', 'Acorn', '02108'), ('Acton Street,', 'Acton', '02136'), ('Adair Road,', 'Adair', '02135'), ('Adamson Street,', 'Adamson', '02134'), ('Adanac Terrace,', 'Adanac', '02124'), ('Addington Road,', 'Addington', '02132'), ('Addison Street,', 'Addison', '02128'), ('Adelaide Street,', 'Adelaide', '02130'), ('Adelaide Terrace,', 'Adelaide', '02130'), ('Adella Place,', 'Adella', '02134'), ('Adirondack Place,', 'Adirondack', '02124'), ('Admiral George Dewey Square,', 'Admiral', '02210'), ('Adrian Street,', 'Adrian', '02125'), ('Agassiz Park', 'Agassiz', '02130'), ('Agassiz Road,', 'Agassiz', '02215'), ('Agawam Street,', 'Agawam', '02122'), ('Agnes Avenue,', 'Agnes', '02126'), ('Aguadilla Street,', 'Aguadilla', '02118'), ('Ainsley Street,', 'Ainsley', '02122'), ('Ainsworth Street,', 'Ainsworth', '02131'), ('Ainsworth Street Footway,', 'Ainsworth', '02131'), ('Akron Place,', 'Akron', '02119'), ('Akron Street,', 'Akron', '02119'), ('Alabama Street,', 'Alabama', '02126'), ('Alameda Road,', 'Alameda', '02132'), ('Alaric Street,', 'Alaric', '02132'), ('Alaric Terrace,', 'Alaric', '02132'), ('Alaska Street,', 'Alaska', '02119'), ('Albano Street,', 'Albano', '02131'), ('Albemarle Court,', 'Albemarle', '02136'), ('Albemarle Street,', 'Albemarle', '02136'), ('Albemarle Street,', 'Albemarle', '02115'), ('Albemarle Terrace,', 'Albemarle', '02115'), ('Alberta Street,', 'Alberta', '02132'), ('Albion Place,', 'Albion', '02129'), ('Albion Street,', 'Albion', '02119'), ('Albion Street,', 'Albion', '02136'), ('Albright Street,', 'Albright', '02132'), ('Alcorn Street,', 'Alcorn', '02134'), ('Alcott Street,', 'Alcott', '02134'), ('Alder Street,', 'Alder', '02131'), ('Aldie Street,', 'Aldie', '02134'), ('Aldo Terrace,', 'Aldo', '02136'), ('Aldrich Street,', 'Aldrich', '02131'), ('Aldwin Road,', 'Aldwin', '02131'), ('Aldworth Street,', 'Aldworth', '02130'), ('Alexander Street,', 'Alexander', '02125'), ('Alford Street,', 'Alford', '02129'), ('Alfred Street,', 'Alfred', '02130'), ('Alger Street,', 'Alger', '02127'), ('Algonquin Square,', 'Algonquin', '02124'), ('Algonquin Street,', 'Algonquin', '02124'), ('Alhambra Road,', 'Alhambra', '02132'), ('Alicia Road,', 'Alicia', '02124'), ('Alkyris Road,', 'Alkyris', '02132'), ('Allandale Street,', 'Allandale', '02130'), ('Alleghany Street,', 'Alleghany', '02120'), ("Allen's Alley,", "Allen's", '02116'), ('Allenwood Street,', 'Allenwood', '02132'), ('Allerton Street,', 'Allerton', '02119'), ('Allstate Road,', 'Allstate', '02125'), ('Almont Street,', 'Almont', '02126'), ('Almy Street,', 'Almy', '02134'), ('Alna Place,', 'Alna', '02128'), ('Alpha Road,', 'Alpha', '02124'), ('Alpheus Road,', 'Alpheus', '02131'), ('Alpine Place,', 'Alpine', '02119'), ('Alpine Street,', 'Alpine', '02126'), ('Alpine Street,', 'Alpine', '02119'), ('Alpine Way', 'Alpine', '02125'), ('Altacrest Road,', 'Altacrest', '02132'), ('Altair Road,', 'Altair', '02132'), ('Althea Street,', 'Althea', '02122'), ('Alther Street,', 'Alther', '02119'), ('Alvan Terrace,', 'Alvan', '02125'), ('Alvarado Avenue,', 'Alvarado', '02136'), ('Alveston Street,', 'Alveston', '02130'), ('Alveston Terrace,', 'Alveston', '02130'), ('Alward Road,', 'Alward', '02131'), ('Alwin Street,', 'Alwin', '02136'), ('Amboy Street,', 'Amboy', '02134'), ('Ambrose Street,', 'Ambrose', '02119'), ('Amesbury Street,', 'Amesbury', '02132'), ('Amherst Street,', 'Amherst', '02131'), ('Amoret Road,', 'Amoret', '02130'), ('Amory Avenue,', 'Amory', '02119'), ('Amory Street Connector,', 'Amory', '02119'), ('Amory Terrace,', 'Amory', '02119'), ('Amy Court,', 'Amy', '02114'), ('Anawan Avenue,', 'Anawan', '02132'), ('Anawan Terrace,', ' ...

# %%
columnName = ['FullName', 'StreetName', 'Zipcode']
df = pd.DataFrame(columns = columnName, data = Streetbook)
data = json.loads(df.to_json(orient="records"))


Filter_Streetbook_version_1 = Streetbook
Filter_Streetbook_version_1_df = pd.DataFrame(Filter_Streetbook_version_1)
Filter_Streetbook_version_1_df.to_csv("/Users/zjallenjiang/Documents/GitHub/Partner_file/filter_Streetbook_version_1.csv", index = False)

# %%
repo.dropCollection('filter_Streetbook_version_1')
repo.createCollection('filter_Streetbook_version_1')
repo[writes[0]].insert_many(data)

# %%
repo[writes[0]].metadata({'complete': True})
print(repo[writes[0]].metadata())
[record for record in repo[writes[0]].find()]
# Out:
# {'_id': ObjectId('5ca28c271877df249365da7d'), 'complete': True}
# [{'_id': ObjectId('5ca28c251877df2493654a1d'),
#   'FullName': 'Abbot Street,',
#   'StreetName': 'Abbot',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a1e'),
#   'FullName': 'Abbotsford Street,',
#   'StreetName': 'Abbotsford',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654a1f'),
#   'FullName': 'Abby Road,',
#   'StreetName': 'Abby',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654a20'),
#   'FullName': 'Aberdeen Street,',
#   'StreetName': 'Aberdeen',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654a21'),
#   'FullName': 'Acacia Road,',
#   'StreetName': 'Acacia',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a22'),
#   'FullName': 'Academic Way,',
#   'StreetName': 'Academic',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a23'),
#   'FullName': 'Acadia Street,',
#   'StreetName': 'Acadia',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654a24'),
#   'FullName': 'Achorn Circle,',
#   'StreetName': 'Achorn',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a25'),
#   'FullName': 'Ackley Place,',
#   'StreetName': 'Ackley',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a26'),
#   'FullName': 'Acorn Street,',
#   'StreetName': 'Acorn',
#   'Zipcode': '02108'},
#  {'_id': ObjectId('5ca28c251877df2493654a27'),
#   'FullName': 'Acton Street,',
#   'StreetName': 'Acton',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654a28'),
#   'FullName': 'Adair Road,',
#   'StreetName': 'Adair',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654a29'),
#   'FullName': 'Adamson Street,',
#   'StreetName': 'Adamson',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a2a'),
#   'FullName': 'Adanac Terrace,',
#   'StreetName': 'Adanac',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a2b'),
#   'FullName': 'Addington Road,',
#   'StreetName': 'Addington',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a2c'),
#   'FullName': 'Addison Street,',
#   'StreetName': 'Addison',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a2d'),
#   'FullName': 'Adelaide Street,',
#   'StreetName': 'Adelaide',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a2e'),
#   'FullName': 'Adelaide Terrace,',
#   'StreetName': 'Adelaide',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a2f'),
#   'FullName': 'Adella Place,',
#   'StreetName': 'Adella',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a30'),
#   'FullName': 'Adirondack Place,',
#   'StreetName': 'Adirondack',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a31'),
#   'FullName': 'Admiral George Dewey Square,',
#   'StreetName': 'Admiral',
#   'Zipcode': '02210'},
#  {'_id': ObjectId('5ca28c251877df2493654a32'),
#   'FullName': 'Adrian Street,',
#   'StreetName': 'Adrian',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654a33'),
#   'FullName': 'Agassiz Park',
#   'StreetName': 'Agassiz',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a34'),
#   'FullName': 'Agassiz Road,',
#   'StreetName': 'Agassiz',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654a35'),
#   'FullName': 'Agawam Street,',
#   'StreetName': 'Agawam',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654a36'),
#   'FullName': 'Agnes Avenue,',
#   'StreetName': 'Agnes',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654a37'),
#   'FullName': 'Aguadilla Street,',
#   'StreetName': 'Aguadilla',
#   'Zipcode': '02118'},
#  {'_id': ObjectId('5ca28c251877df2493654a38'),
#   'FullName': 'Ainsley Street,',
#   'StreetName': 'Ainsley',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654a39'),
#   'FullName': 'Ainsworth Street,',
#   'StreetName': 'Ainsworth',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a3a'),
#   'FullName': 'Ainsworth Street Footway,',
#   'StreetName': 'Ainsworth',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a3b'),
#   'FullName': 'Akron Place,',
#   'StreetName': 'Akron',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a3c'),
#   'FullName': 'Akron Street,',
#   'StreetName': 'Akron',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a3d'),
#   'FullName': 'Alabama Street,',
#   'StreetName': 'Alabama',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654a3e'),
#   'FullName': 'Alameda Road,',
#   'StreetName': 'Alameda',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a3f'),
#   'FullName': 'Alaric Street,',
#   'StreetName': 'Alaric',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a40'),
#   'FullName': 'Alaric Terrace,',
#   'StreetName': 'Alaric',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a41'),
#   'FullName': 'Alaska Street,',
#   'StreetName': 'Alaska',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a42'),
#   'FullName': 'Albano Street,',
#   'StreetName': 'Albano',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a43'),
#   'FullName': 'Albemarle Court,',
#   'StreetName': 'Albemarle',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654a44'),
#   'FullName': 'Albemarle Street,',
#   'StreetName': 'Albemarle',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654a45'),
#   'FullName': 'Albemarle Street,',
#   'StreetName': 'Albemarle',
#   'Zipcode': '02115'},
#  {'_id': ObjectId('5ca28c251877df2493654a46'),
#   'FullName': 'Albemarle Terrace,',
#   'StreetName': 'Albemarle',
#   'Zipcode': '02115'},
#  {'_id': ObjectId('5ca28c251877df2493654a47'),
#   'FullName': 'Alberta Street,',
#   'StreetName': 'Alberta',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a48'),
#   'FullName': 'Albion Place,',
#   'StreetName': 'Albion',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654a49'),
#   'FullName': 'Albion Street,',
#   'StreetName': 'Albion',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a4a'),
#   'FullName': 'Albion Street,',
#   'StreetName': 'Albion',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654a4b'),
#   'FullName': 'Albright Street,',
#   'StreetName': 'Albright',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a4c'),
#   'FullName': 'Alcorn Street,',
#   'StreetName': 'Alcorn',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a4d'),
#   'FullName': 'Alcott Street,',
#   'StreetName': 'Alcott',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a4e'),
#   'FullName': 'Alder Street,',
#   'StreetName': 'Alder',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a4f'),
#   'FullName': 'Aldie Street,',
#   'StreetName': 'Aldie',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a50'),
#   'FullName': 'Aldo Terrace,',
#   'StreetName': 'Aldo',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654a51'),
#   'FullName': 'Aldrich Street,',
#   'StreetName': 'Aldrich',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a52'),
#   'FullName': 'Aldwin Road,',
#   'StreetName': 'Aldwin',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a53'),
#   'FullName': 'Aldworth Street,',
#   'StreetName': 'Aldworth',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a54'),
#   'FullName': 'Alexander Street,',
#   'StreetName': 'Alexander',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654a55'),
#   'FullName': 'Alford Street,',
#   'StreetName': 'Alford',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654a56'),
#   'FullName': 'Alfred Street,',
#   'StreetName': 'Alfred',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a57'),
#   'FullName': 'Alger Street,',
#   'StreetName': 'Alger',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654a58'),
#   'FullName': 'Algonquin Square,',
#   'StreetName': 'Algonquin',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a59'),
#   'FullName': 'Algonquin Street,',
#   'StreetName': 'Algonquin',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a5a'),
#   'FullName': 'Alhambra Road,',
#   'StreetName': 'Alhambra',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a5b'),
#   'FullName': 'Alicia Road,',
#   'StreetName': 'Alicia',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a5c'),
#   'FullName': 'Alkyris Road,',
#   'StreetName': 'Alkyris',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a5d'),
#   'FullName': 'Allandale Street,',
#   'StreetName': 'Allandale',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a5e'),
#   'FullName': 'Alleghany Street,',
#   'StreetName': 'Alleghany',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654a5f'),
#   'FullName': "Allen's Alley,",
#   'StreetName': "Allen's",
#   'Zipcode': '02116'},
#  {'_id': ObjectId('5ca28c251877df2493654a60'),
#   'FullName': 'Allenwood Street,',
#   'StreetName': 'Allenwood',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a61'),
#   'FullName': 'Allerton Street,',
#   'StreetName': 'Allerton',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a62'),
#   'FullName': 'Allstate Road,',
#   'StreetName': 'Allstate',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654a63'),
#   'FullName': 'Almont Street,',
#   'StreetName': 'Almont',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654a64'),
#   'FullName': 'Almy Street,',
#   'StreetName': 'Almy',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a65'),
#   'FullName': 'Alna Place,',
#   'StreetName': 'Alna',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a66'),
#   'FullName': 'Alpha Road,',
#   'StreetName': 'Alpha',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a67'),
#   'FullName': 'Alpheus Road,',
#   'StreetName': 'Alpheus',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a68'),
#   'FullName': 'Alpine Place,',
#   'StreetName': 'Alpine',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a69'),
#   'FullName': 'Alpine Street,',
#   'StreetName': 'Alpine',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654a6a'),
#   'FullName': 'Alpine Street,',
#   'StreetName': 'Alpine',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a6b'),
#   'FullName': 'Alpine Way',
#   'StreetName': 'Alpine',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654a6c'),
#   'FullName': 'Altacrest Road,',
#   'StreetName': 'Altacrest',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a6d'),
#   'FullName': 'Altair Road,',
#   'StreetName': 'Altair',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a6e'),
#   'FullName': 'Althea Street,',
#   'StreetName': 'Althea',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654a6f'),
#   'FullName': 'Alther Street,',
#   'StreetName': 'Alther',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a70'),
#   'FullName': 'Alvan Terrace,',
#   'StreetName': 'Alvan',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654a71'),
#   'FullName': 'Alvarado Avenue,',
#   'StreetName': 'Alvarado',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654a72'),
#   'FullName': 'Alveston Street,',
#   'StreetName': 'Alveston',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a73'),
#   'FullName': 'Alveston Terrace,',
#   'StreetName': 'Alveston',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a74'),
#   'FullName': 'Alward Road,',
#   'StreetName': 'Alward',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a75'),
#   'FullName': 'Alwin Street,',
#   'StreetName': 'Alwin',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654a76'),
#   'FullName': 'Amboy Street,',
#   'StreetName': 'Amboy',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a77'),
#   'FullName': 'Ambrose Street,',
#   'StreetName': 'Ambrose',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a78'),
#   'FullName': 'Amesbury Street,',
#   'StreetName': 'Amesbury',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a79'),
#   'FullName': 'Amherst Street,',
#   'StreetName': 'Amherst',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a7a'),
#   'FullName': 'Amoret Road,',
#   'StreetName': 'Amoret',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a7b'),
#   'FullName': 'Amory Avenue,',
#   'StreetName': 'Amory',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a7c'),
#   'FullName': 'Amory Street Connector,',
#   'StreetName': 'Amory',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a7d'),
#   'FullName': 'Amory Terrace,',
#   'StreetName': 'Amory',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a7e'),
#   'FullName': 'Amy Court,',
#   'StreetName': 'Amy',
#   'Zipcode': '02114'},
#  {'_id': ObjectId('5ca28c251877df2493654a7f'),
#   'FullName': 'Anawan Avenue,',
#   'StreetName': 'Anawan',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a80'),
#   'FullName': 'Anawan Terrace,',
#   'StreetName': 'Anawan',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a81'),
#   'FullName': 'Anchor Street,',
#   'StreetName': 'Anchor',
#   'Zipcode': '02210'},
#  {'_id': ObjectId('5ca28c251877df2493654a82'),
#   'FullName': 'Anchor Way',
#   'StreetName': 'Anchor',
#   'Zipcode': '02210'},
#  {'_id': ObjectId('5ca28c251877df2493654a83'),
#   'FullName': 'Anderer Lane,',
#   'StreetName': 'Anderer',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a84'),
#   'FullName': 'Anderson Place,',
#   'StreetName': 'Anderson',
#   'Zipcode': '02114'},
#  {'_id': ObjectId('5ca28c251877df2493654a85'),
#   'FullName': 'Anderson Street,',
#   'StreetName': 'Anderson',
#   'Zipcode': '02114'},
#  {'_id': ObjectId('5ca28c251877df2493654a86'),
#   'FullName': 'Andover Road,',
#   'StreetName': 'Andover',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a87'),
#   'FullName': 'Andrew Square,',
#   'StreetName': 'Andrew',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654a88'),
#   'FullName': 'Andrew P. McArdle Bridge,',
#   'StreetName': 'Andrew',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a89'),
#   'FullName': 'Andria Road,',
#   'StreetName': 'Andria',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654a8a'),
#   'FullName': 'Angell Street,',
#   'StreetName': 'Angell',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a8b'),
#   'FullName': 'Angus Place,',
#   'StreetName': 'Angus',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654a8c'),
#   'FullName': 'Anita Terrace,',
#   'StreetName': 'Anita',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654a8d'),
#   'FullName': 'Ann Street,',
#   'StreetName': 'Ann',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654a8e'),
#   'FullName': 'Annabel Street,',
#   'StreetName': 'Annabel',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654a8f'),
#   'FullName': 'Annafran Street,',
#   'StreetName': 'Annafran',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654a90'),
#   'FullName': 'Annapolis Street,',
#   'StreetName': 'Annapolis',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654a91'),
#   'FullName': 'Annavoy Street,',
#   'StreetName': 'Annavoy',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a92'),
#   'FullName': 'Annunciation Road,',
#   'StreetName': 'Annunciation',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654a93'),
#   'FullName': 'Ansel Road,',
#   'StreetName': 'Ansel',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a94'),
#   'FullName': 'Anselm Terrace,',
#   'StreetName': 'Anselm',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654a95'),
#   'FullName': 'Anson Street,',
#   'StreetName': 'Anson',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654a96'),
#   'FullName': 'Ansonia Road,',
#   'StreetName': 'Ansonia',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654a97'),
#   'FullName': 'Anthony J. Grieco Terrace,',
#   'StreetName': 'Anthony',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a98'),
#   'FullName': 'Anthony "Rip" Valenti Way',
#   'StreetName': 'Anthony',
#   'Zipcode': '02114'},
#  {'_id': ObjectId('5ca28c251877df2493654a99'),
#   'FullName': 'Antrim Street,',
#   'StreetName': 'Antrim',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a9a'),
#   'FullName': 'Antwerp Street,',
#   'StreetName': 'Antwerp',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654a9b'),
#   'FullName': 'Appian Place,',
#   'StreetName': 'Appian',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a9c'),
#   'FullName': 'Appian Way',
#   'StreetName': 'Appian',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654a9d'),
#   'FullName': 'Aramon Street,',
#   'StreetName': 'Aramon',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654a9e'),
#   'FullName': 'Arbella Road,',
#   'StreetName': 'Arbella',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654a9f'),
#   'FullName': 'Arborcrest Terrace,',
#   'StreetName': 'Arborcrest',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654aa0'),
#   'FullName': 'Arboretum Road,',
#   'StreetName': 'Arboretum',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654aa1'),
#   'FullName': 'Arborfield Road,',
#   'StreetName': 'Arborfield',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654aa2'),
#   'FullName': 'Arborough Road,',
#   'StreetName': 'Arborough',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654aa3'),
#   'FullName': 'Arborview Road,',
#   'StreetName': 'Arborview',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654aa4'),
#   'FullName': 'Arborway',
#   'StreetName': 'Arborway',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654aa5'),
#   'FullName': 'Arborway Terrace,',
#   'StreetName': 'Arborway',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654aa6'),
#   'FullName': 'Arbroth Street,',
#   'StreetName': 'Arbroth',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654aa7'),
#   'FullName': 'Arbutus Street,',
#   'StreetName': 'Arbutus',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654aa8'),
#   'FullName': 'Arcadia Park',
#   'StreetName': 'Arcadia',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654aa9'),
#   'FullName': 'Arcadia Street,',
#   'StreetName': 'Arcadia',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654aaa'),
#   'FullName': 'Arcadia Street,',
#   'StreetName': 'Arcadia',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654aab'),
#   'FullName': 'Arcadia Terrace,',
#   'StreetName': 'Arcadia',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654aac'),
#   'FullName': 'Archdale Road,',
#   'StreetName': 'Archdale',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654aad'),
#   'FullName': 'Archway Street,',
#   'StreetName': 'Archway',
#   'Zipcode': '02109'},
#  {'_id': ObjectId('5ca28c251877df2493654aae'),
#   'FullName': 'Arcola Street,',
#   'StreetName': 'Arcola',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654aaf'),
#   'FullName': 'Ardale Street,',
#   'StreetName': 'Ardale',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654ab0'),
#   'FullName': 'Ardee Street,',
#   'StreetName': 'Ardee',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654ab1'),
#   'FullName': 'Arden Street,',
#   'StreetName': 'Arden',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654ab2'),
#   'FullName': 'Ardent Street,',
#   'StreetName': 'Ardent',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654ab3'),
#   'FullName': 'Ardmore Road,',
#   'StreetName': 'Ardmore',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654ab4'),
#   'FullName': 'Argus Place,',
#   'StreetName': 'Argus',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654ab5'),
#   'FullName': 'Argyle Street,',
#   'StreetName': 'Argyle',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654ab6'),
#   'FullName': 'Argyle Terrace,',
#   'StreetName': 'Argyle',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654ab7'),
#   'FullName': 'Arion Street,',
#   'StreetName': 'Arion',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654ab8'),
#   'FullName': 'Arklow Street,',
#   'StreetName': 'Arklow',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654ab9'),
#   'FullName': 'Armandine Street,',
#   'StreetName': 'Armandine',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654aba'),
#   'FullName': 'Armington Street,',
#   'StreetName': 'Armington',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654abb'),
#   'FullName': 'Armstrong Street,',
#   'StreetName': 'Armstrong',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654abc'),
#   'FullName': 'Arnold Place,',
#   'StreetName': 'Arnold',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654abd'),
#   'FullName': 'Arrow Street,',
#   'StreetName': 'Arrow',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654abe'),
#   'FullName': 'Arthur Street,',
#   'StreetName': 'Arthur',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654abf'),
#   'FullName': 'Arundel Street,',
#   'StreetName': 'Arundel',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654ac0'),
#   'FullName': 'Arvale Road,',
#   'StreetName': 'Arvale',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654ac1'),
#   'FullName': 'Ascot Street,',
#   'StreetName': 'Ascot',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654ac2'),
#   'FullName': 'Ashcroft Street,',
#   'StreetName': 'Ashcroft',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654ac3'),
#   'FullName': 'Asheville Path',
#   'StreetName': 'Asheville',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654ac4'),
#   'FullName': 'Asheville Road,',
#   'StreetName': 'Asheville',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654ac5'),
#   'FullName': 'Ashfield Street,',
#   'StreetName': 'Ashfield',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654ac6'),
#   'FullName': 'Ashford Court,',
#   'StreetName': 'Ashford',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654ac7'),
#   'FullName': 'Ashford Street,',
#   'StreetName': 'Ashford',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654ac8'),
#   'FullName': 'Ashford Terrace,',
#   'StreetName': 'Ashford',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654ac9'),
#   'FullName': 'Ashland Avenue,',
#   'StreetName': 'Ashland',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654aca'),
#   'FullName': 'Ashland Street,',
#   'StreetName': 'Ashland',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654acb'),
#   'FullName': 'Ashmont Court,',
#   'StreetName': 'Ashmont',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654acc'),
#   'FullName': 'Ashmont Park',
#   'StreetName': 'Ashmont',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654acd'),
#   'FullName': 'Ashmore Road,',
#   'StreetName': 'Ashmore',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654ace'),
#   'FullName': 'Ashton Street,',
#   'StreetName': 'Ashton',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654acf'),
#   'FullName': 'Ashwood Terrace,',
#   'StreetName': 'Ashwood',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654ad0'),
#   'FullName': 'Aspen Street,',
#   'StreetName': 'Aspen',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654ad1'),
#   'FullName': 'Aspinwall Road,',
#   'StreetName': 'Aspinwall',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654ad2'),
#   'FullName': 'Asticou Road,',
#   'StreetName': 'Asticou',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654ad3'),
#   'FullName': 'Astoria Street,',
#   'StreetName': 'Astoria',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654ad4'),
#   'FullName': 'Athelwold Street,',
#   'StreetName': 'Athelwold',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654ad5'),
#   'FullName': 'Athens Street,',
#   'StreetName': 'Athens',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654ad6'),
#   'FullName': 'Atherstone Street,',
#   'StreetName': 'Atherstone',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654ad7'),
#   'FullName': 'Atherton Avenue,',
#   'StreetName': 'Atherton',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654ad8'),
#   'FullName': 'Atherton Place,',
#   'StreetName': 'Atherton',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654ad9'),
#   'FullName': 'Atherton Street,',
#   'StreetName': 'Atherton',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654ada'),
#   'FullName': 'Athol Street,',
#   'StreetName': 'Athol',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654adb'),
#   'FullName': 'Atkins Street,',
#   'StreetName': 'Atkins',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654adc'),
#   'FullName': 'Atkinson Street,',
#   'StreetName': 'Atkinson',
#   'Zipcode': '02118'},
#  {'_id': ObjectId('5ca28c251877df2493654add'),
#   'FullName': 'Atlantic Street,',
#   'StreetName': 'Atlantic',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654ade'),
#   'FullName': 'Atlantis Street,',
#   'StreetName': 'Atlantis',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654adf'),
#   'FullName': 'Atwill Road,',
#   'StreetName': 'Atwill',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654ae0'),
#   'FullName': 'Atwood Square,',
#   'StreetName': 'Atwood',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654ae1'),
#   'FullName': 'Auburn Place,',
#   'StreetName': 'Auburn',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654ae2'),
#   'FullName': 'Auburn Square,',
#   'StreetName': 'Auburn',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654ae3'),
#   'FullName': 'Auburn Street,',
#   'StreetName': 'Auburn',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654ae4'),
#   'FullName': 'Auburn Terrace,',
#   'StreetName': 'Auburn',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654ae5'),
#   'FullName': 'Auckland Street,',
#   'StreetName': 'Auckland',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654ae6'),
#   'FullName': 'Audubon Circle,',
#   'StreetName': 'Audubon',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654ae7'),
#   'FullName': 'Augustus Avenue,',
#   'StreetName': 'Augustus',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654ae8'),
#   'FullName': 'Auriga Street,',
#   'StreetName': 'Auriga',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654ae9'),
#   'FullName': 'Autumn Lane,',
#   'StreetName': 'Autumn',
#   'Zipcode': '02201'},
#  {'_id': ObjectId('5ca28c251877df2493654aea'),
#   'FullName': 'Autumn Street,',
#   'StreetName': 'Autumn',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654aeb'),
#   'FullName': 'Avalon Road,',
#   'StreetName': 'Avalon',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654aec'),
#   'FullName': 'Averbuch Terrace,',
#   'StreetName': 'Averbuch',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654aed'),
#   'FullName': 'Averton Street,',
#   'StreetName': 'Averton',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654aee'),
#   'FullName': 'Avery Place,',
#   'StreetName': 'Avery',
#   'Zipcode': '02111'},
#  {'_id': ObjectId('5ca28c251877df2493654aef'),
#   'FullName': 'Avery Street,',
#   'StreetName': 'Avery',
#   'Zipcode': '02111'},
#  {'_id': ObjectId('5ca28c251877df2493654af0'),
#   'FullName': 'Avila Road,',
#   'StreetName': 'Avila',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654af1'),
#   'FullName': 'Avon Place,',
#   'StreetName': 'Avon',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654af2'),
#   'FullName': 'Avon Street,',
#   'StreetName': 'Avon',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654af3'),
#   'FullName': 'Avondale Street,',
#   'StreetName': 'Avondale',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654af4'),
#   'FullName': 'Ayles Road,',
#   'StreetName': 'Ayles',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654af5'),
#   'FullName': 'Ayr Road,',
#   'StreetName': 'Ayr',
#   'Zipcode': '02146'},
#  {'_id': ObjectId('5ca28c251877df2493654af6'),
#   'FullName': 'Babbitt Street,',
#   'StreetName': 'Babbitt',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654af7'),
#   'FullName': 'Babcock Street,',
#   'StreetName': 'Babcock',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654af8'),
#   'FullName': 'Babe Ruth Park Drive,',
#   'StreetName': 'Babe',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654af9'),
#   'FullName': 'Babson Street,',
#   'StreetName': 'Babson',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654afa'),
#   'FullName': 'Badger Place,',
#   'StreetName': 'Badger',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654afb'),
#   'FullName': 'Badger Road,',
#   'StreetName': 'Badger',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654afc'),
#   'FullName': 'Bagnal Street,',
#   'StreetName': 'Bagnal',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654afd'),
#   'FullName': 'Bailey Street,',
#   'StreetName': 'Bailey',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654afe'),
#   'FullName': 'Baird Street,',
#   'StreetName': 'Baird',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654aff'),
#   'FullName': "Baker's Alley,",
#   'StreetName': "Baker's",
#   'Zipcode': '02113'},
#  {'_id': ObjectId('5ca28c251877df2493654b00'),
#   'FullName': 'Bakersfield Street,',
#   'StreetName': 'Bakersfield',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b01'),
#   'FullName': 'Baldwin Place,',
#   'StreetName': 'Baldwin',
#   'Zipcode': '02113'},
#  {'_id': ObjectId('5ca28c251877df2493654b02'),
#   'FullName': 'Baldwin Place,',
#   'StreetName': 'Baldwin',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654b03'),
#   'FullName': 'Baldwin Street,',
#   'StreetName': 'Baldwin',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654b04'),
#   'FullName': 'Baldwin Street,',
#   'StreetName': 'Baldwin',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654b05'),
#   'FullName': 'Balfour Street,',
#   'StreetName': 'Balfour',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b06'),
#   'FullName': 'Balina Place,',
#   'StreetName': 'Balina',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b07'),
#   'FullName': 'Ball Street,',
#   'StreetName': 'Ball',
#   'Zipcode': '21119'},
#  {'_id': ObjectId('5ca28c251877df2493654b08'),
#   'FullName': 'Ballard Street,',
#   'StreetName': 'Ballard',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b09'),
#   'FullName': 'Ballard Way',
#   'StreetName': 'Ballard',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b0a'),
#   'FullName': 'Ballou Avenue,',
#   'StreetName': 'Ballou',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b0b'),
#   'FullName': 'Ballou Place,',
#   'StreetName': 'Ballou',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b0c'),
#   'FullName': 'Balmoral Park',
#   'StreetName': 'Balmoral',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b0d'),
#   'FullName': 'Balsam Street,',
#   'StreetName': 'Balsam',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b0e'),
#   'FullName': 'Bancroft Street,',
#   'StreetName': 'Bancroft',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654b0f'),
#   'FullName': 'Banfield Avenue,',
#   'StreetName': 'Banfield',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654b10'),
#   'FullName': 'Bangor Road,',
#   'StreetName': 'Bangor',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b11'),
#   'FullName': 'Banks Street,',
#   'StreetName': 'Banks',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b12'),
#   'FullName': 'Banton Street,',
#   'StreetName': 'Banton',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b13'),
#   'FullName': 'Bantry Way',
#   'StreetName': 'Bantry',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b14'),
#   'FullName': 'Barbara Street,',
#   'StreetName': 'Barbara',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b15'),
#   'FullName': 'Barclay Road,',
#   'StreetName': 'Barclay',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b16'),
#   'FullName': 'Bard Avenue,',
#   'StreetName': 'Bard',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654b17'),
#   'FullName': 'Bardwell Street,',
#   'StreetName': 'Bardwell',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b18'),
#   'FullName': 'Barker Street,',
#   'StreetName': 'Barker',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654b19'),
#   'FullName': 'Barlow Street,',
#   'StreetName': 'Barlow',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b1a'),
#   'FullName': 'Barna Road,',
#   'StreetName': 'Barna',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b1b'),
#   'FullName': 'Barnard Place,',
#   'StreetName': 'Barnard',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b1c'),
#   'FullName': 'Barnard Place,',
#   'StreetName': 'Barnard',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b1d'),
#   'FullName': 'Barrett Avenue,',
#   'StreetName': 'Barrett',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b1e'),
#   'FullName': 'Barrington Road,',
#   'StreetName': 'Barrington',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b1f'),
#   'FullName': 'Barrows Street,',
#   'StreetName': 'Barrows',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654b20'),
#   'FullName': 'Barry Park',
#   'StreetName': 'Barry',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b21'),
#   'FullName': 'Barry Street,',
#   'StreetName': 'Barry',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b22'),
#   'FullName': 'Barry Street,',
#   'StreetName': 'Barry',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654b23'),
#   'FullName': 'Barstow Street,',
#   'StreetName': 'Barstow',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654b24'),
#   'FullName': 'Bartlett Avenue,',
#   'StreetName': 'Bartlett',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b25'),
#   'FullName': 'Bartlett Place,',
#   'StreetName': 'Bartlett',
#   'Zipcode': '02113'},
#  {'_id': ObjectId('5ca28c251877df2493654b26'),
#   'FullName': 'Bartlett Street,',
#   'StreetName': 'Bartlett',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654b27'),
#   'FullName': 'Bartlett Street,',
#   'StreetName': 'Bartlett',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654b28'),
#   'FullName': 'Bartlett Station Drive,',
#   'StreetName': 'Bartlett',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654b29'),
#   'FullName': 'Basile Street,',
#   'StreetName': 'Basile',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b2a'),
#   'FullName': 'Basto Terrace,',
#   'StreetName': 'Basto',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b2b'),
#   'FullName': 'Bateswell Road,',
#   'StreetName': 'Bateswell',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b2c'),
#   'FullName': 'Baxter Street,',
#   'StreetName': 'Baxter',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b2d'),
#   'FullName': 'Bayard Street,',
#   'StreetName': 'Bayard',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654b2e'),
#   'FullName': 'Bayside Street,',
#   'StreetName': 'Bayside',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b2f'),
#   'FullName': 'Bayswater Street,',
#   'StreetName': 'Bayswater',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654b30'),
#   'FullName': 'Beacham Street,',
#   'StreetName': 'Beacham',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654b31'),
#   'FullName': 'Beachview Road,',
#   'StreetName': 'Beachview',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654b32'),
#   'FullName': 'Beal Place,',
#   'StreetName': 'Beal',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654b33'),
#   'FullName': 'Beale Street,',
#   'StreetName': 'Beale',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b34'),
#   'FullName': 'Bearse Avenue,',
#   'StreetName': 'Bearse',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b35'),
#   'FullName': 'Beaufield Street,',
#   'StreetName': 'Beaufield',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b36'),
#   'FullName': 'Beauford Lane,',
#   'StreetName': 'Beauford',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b37'),
#   'FullName': 'Beaufort Road,',
#   'StreetName': 'Beaufort',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b38'),
#   'FullName': 'Beaumont Street,',
#   'StreetName': 'Beaumont',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b39'),
#   'FullName': 'Beaver Place,',
#   'StreetName': 'Beaver',
#   'Zipcode': '02108'},
#  {'_id': ObjectId('5ca28c251877df2493654b3a'),
#   'FullName': 'Beaver Street,',
#   'StreetName': 'Beaver',
#   'Zipcode': '02108'},
#  {'_id': ObjectId('5ca28c251877df2493654b3b'),
#   'FullName': 'Beaver Street,',
#   'StreetName': 'Beaver',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654b3c'),
#   'FullName': 'Beck Street,',
#   'StreetName': 'Beck',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654b3d'),
#   'FullName': 'Becket Street,',
#   'StreetName': 'Becket',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b3e'),
#   'FullName': 'Beckler Avenue,',
#   'StreetName': 'Beckler',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b3f'),
#   'FullName': 'Beckwith Street,',
#   'StreetName': 'Beckwith',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b40'),
#   'FullName': 'Beechcroft Street,',
#   'StreetName': 'Beechcroft',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654b41'),
#   'FullName': 'Beecher Street,',
#   'StreetName': 'Beecher',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b42'),
#   'FullName': 'Beech Glen Street,',
#   'StreetName': 'Beech',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654b43'),
#   'FullName': 'Beechland Circle,',
#   'StreetName': 'Beechland',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b44'),
#   'FullName': 'Beechmont Footway,',
#   'StreetName': 'Beechmont',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654b45'),
#   'FullName': 'Beechmont Street,',
#   'StreetName': 'Beechmont',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654b46'),
#   'FullName': 'Beechmont Terrace,',
#   'StreetName': 'Beechmont',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654b47'),
#   'FullName': 'Beechwood Street,',
#   'StreetName': 'Beechwood',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654b48'),
#   'FullName': 'Beechwood Street,',
#   'StreetName': 'Beechwood',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654b49'),
#   'FullName': 'Beethoven Street,',
#   'StreetName': 'Beethoven',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654b4a'),
#   'FullName': 'Belden Square,',
#   'StreetName': 'Belden',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b4b'),
#   'FullName': 'Belden Street,',
#   'StreetName': 'Belden',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b4c'),
#   'FullName': 'Belfort Street,',
#   'StreetName': 'Belfort',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b4d'),
#   'FullName': 'Belgrade Terrace,',
#   'StreetName': 'Belgrade',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b4e'),
#   'FullName': 'Belgravia Place,',
#   'StreetName': 'Belgravia',
#   'Zipcode': '02113'},
#  {'_id': ObjectId('5ca28c251877df2493654b4f'),
#   'FullName': 'Bell Court,',
#   'StreetName': 'Bell',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654b50'),
#   'FullName': 'Bellaire Road,',
#   'StreetName': 'Bellaire',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b51'),
#   'FullName': 'Bellamy Street,',
#   'StreetName': 'Bellamy',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654b52'),
#   'FullName': 'Belle Avenue,',
#   'StreetName': 'Belle',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b53'),
#   'FullName': 'Bellevue Street,',
#   'StreetName': 'Bellevue',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b54'),
#   'FullName': 'Bellevue Street,',
#   'StreetName': 'Bellevue',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b55'),
#   'FullName': 'Bellevue Hill Road,',
#   'StreetName': 'Bellevue',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b56'),
#   'FullName': 'Bellflower Street,',
#   'StreetName': 'Bellflower',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b57'),
#   'FullName': 'Bellingham Place,',
#   'StreetName': 'Bellingham',
#   'Zipcode': '02114'},
#  {'_id': ObjectId('5ca28c251877df2493654b58'),
#   'FullName': 'Bellvista Road,',
#   'StreetName': 'Bellvista',
#   'Zipcode': '02146'},
#  {'_id': ObjectId('5ca28c251877df2493654b59'),
#   'FullName': 'Belmont Place,',
#   'StreetName': 'Belmont',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654b5a'),
#   'FullName': 'Belmont Street,',
#   'StreetName': 'Belmont',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654b5b'),
#   'FullName': 'Belmore Terrace,',
#   'StreetName': 'Belmore',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b5c'),
#   'FullName': 'Belnap Road,',
#   'StreetName': 'Belnap',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654b5d'),
#   'FullName': 'Belnel Road,',
#   'StreetName': 'Belnel',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654b5e'),
#   'FullName': 'Belton Street,',
#   'StreetName': 'Belton',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b5f'),
#   'FullName': 'Belvidere Street,',
#   'StreetName': 'Belvidere',
#   'Zipcode': '02115'},
#  {'_id': ObjectId('5ca28c251877df2493654b60'),
#   'FullName': 'Bennett Street,',
#   'StreetName': 'Bennett',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654b61'),
#   'FullName': 'Bennington Street,',
#   'StreetName': 'Bennington',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654b62'),
#   'FullName': 'Benson Street,',
#   'StreetName': 'Benson',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654b63'),
#   'FullName': 'Bentham Road,',
#   'StreetName': 'Bentham',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654b64'),
#   'FullName': 'Bentley Street,',
#   'StreetName': 'Bentley',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654b65'),
#   'FullName': 'Benton Street,',
#   'StreetName': 'Benton',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654b66'),
#   'FullName': 'Beram Avenue,',
#   'StreetName': 'Beram',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b67'),
#   'FullName': 'Berkshire Street,',
#   'StreetName': 'Berkshire',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b68'),
#   'FullName': 'Bernard Street,',
#   'StreetName': 'Bernard',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654b69'),
#   'FullName': "Bernardo O'Higgins Circle",
#   'StreetName': 'Bernardo',
#   'Zipcode': '02146'},
#  {'_id': ObjectId('5ca28c251877df2493654b6a'),
#   'FullName': 'Bernice Street,',
#   'StreetName': 'Bernice',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654b6b'),
#   'FullName': 'Berry Street,',
#   'StreetName': 'Berry',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654b6c'),
#   'FullName': 'Bertram Street,',
#   'StreetName': 'Bertram',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654b6d'),
#   'FullName': 'Bertson Avenue,',
#   'StreetName': 'Bertson',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b6e'),
#   'FullName': 'Berwick Street,',
#   'StreetName': 'Berwick',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b6f'),
#   'FullName': 'Beryl Street,',
#   'StreetName': 'Beryl',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b70'),
#   'FullName': 'Bethune Way',
#   'StreetName': 'Bethune',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654b71'),
#   'FullName': 'Beverly Street,',
#   'StreetName': 'Beverly',
#   'Zipcode': '02114'},
#  {'_id': ObjectId('5ca28c251877df2493654b72'),
#   'FullName': 'Bexley Road,',
#   'StreetName': 'Bexley',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b73'),
#   'FullName': 'Bickford Avenue,',
#   'StreetName': 'Bickford',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654b74'),
#   'FullName': 'Bickford Street,',
#   'StreetName': 'Bickford',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b75'),
#   'FullName': 'Bicknell Street,',
#   'StreetName': 'Bicknell',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654b76'),
#   'FullName': 'Billings Lane,',
#   'StreetName': 'Billings',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b77'),
#   'FullName': 'Billings Street,',
#   'StreetName': 'Billings',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b78'),
#   'FullName': 'Bilodeau Road,',
#   'StreetName': 'Bilodeau',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654b79'),
#   'FullName': 'Biltmore Street,',
#   'StreetName': 'Biltmore',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b7a'),
#   'FullName': 'Binford Street,',
#   'StreetName': 'Binford',
#   'Zipcode': '02210'},
#  {'_id': ObjectId('5ca28c251877df2493654b7b'),
#   'FullName': 'Binney Street,',
#   'StreetName': 'Binney',
#   'Zipcode': '02115'},
#  {'_id': ObjectId('5ca28c251877df2493654b7c'),
#   'FullName': 'Biosquare Drive,',
#   'StreetName': 'Biosquare',
#   'Zipcode': '02118'},
#  {'_id': ObjectId('5ca28c251877df2493654b7d'),
#   'FullName': 'Birch Road,',
#   'StreetName': 'Birch',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b7e'),
#   'FullName': 'Birch Street,',
#   'StreetName': 'Birch',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654b7f'),
#   'FullName': 'Birchcroft Road,',
#   'StreetName': 'Birchcroft',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654b80'),
#   'FullName': 'Birchland Avenue,',
#   'StreetName': 'Birchland',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b81'),
#   'FullName': 'Birchland Terrace,',
#   'StreetName': 'Birchland',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b82'),
#   'FullName': 'Birchwood Street,',
#   'StreetName': 'Birchwood',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b83'),
#   'FullName': 'Bird Place,',
#   'StreetName': 'Bird',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654b84'),
#   'FullName': 'Bird Street,',
#   'StreetName': 'Bird',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654b85'),
#   'FullName': 'Biscoe Place,',
#   'StreetName': 'Biscoe',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654b86'),
#   'FullName': 'Bishop Street,',
#   'StreetName': 'Bishop',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b87'),
#   'FullName': 'Bishop Joe L. Smith Way,',
#   'StreetName': 'Bishop',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654b88'),
#   'FullName': 'Bismarck Street,',
#   'StreetName': 'Bismarck',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654b89'),
#   'FullName': 'Bismarck Street,',
#   'StreetName': 'Bismarck',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654b8a'),
#   'FullName': 'Bispham Street,',
#   'StreetName': 'Bispham',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654b8b'),
#   'FullName': 'Blaban Place,',
#   'StreetName': 'Blaban',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654b8c'),
#   'FullName': 'Blackfan Circle,',
#   'StreetName': 'Blackfan',
#   'Zipcode': '02115'},
#  {'_id': ObjectId('5ca28c251877df2493654b8d'),
#   'FullName': 'Blackfan Street,',
#   'StreetName': 'Blackfan',
#   'Zipcode': '02115'},
#  {'_id': ObjectId('5ca28c251877df2493654b8e'),
#   'FullName': 'Blackinton Street,',
#   'StreetName': 'Blackinton',
#   'Zipcode': '02128'},
# ...
#  {'_id': ObjectId('5ca28c251877df2493654d88'),
#   'FullName': 'Cypress Terrace,',
#   'StreetName': 'Cypress',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654d89'),
#   'FullName': 'Dabney Street,',
#   'StreetName': 'Dabney',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654d8a'),
#   'FullName': 'Dacia Street,',
#   'StreetName': 'Dacia',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654d8b'),
#   'FullName': 'Dacy Street,',
#   'StreetName': 'Dacy',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654d8c'),
#   'FullName': 'Dade Street,',
#   'StreetName': 'Dade',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654d8d'),
#   'FullName': 'Dakota Street,',
#   'StreetName': 'Dakota',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654d8e'),
#   'FullName': 'Dakota Terrace,',
#   'StreetName': 'Dakota',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654d8f'),
#   'FullName': 'Dalin Place,',
#   'StreetName': 'Dalin',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654d90'),
#   'FullName': 'Dalkeith Street,',
#   'StreetName': 'Dalkeith',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654d91'),
#   'FullName': 'Dalrymple Street,',
#   'StreetName': 'Dalrymple',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654d92'),
#   'FullName': 'Daly Street,',
#   'StreetName': 'Daly',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654d93'),
#   'FullName': 'Damon Place,',
#   'StreetName': 'Damon',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654d94'),
#   'FullName': 'Damrell Street,',
#   'StreetName': 'Damrell',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654d95'),
#   'FullName': 'Dana Avenue,',
#   'StreetName': 'Dana',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654d96'),
#   'FullName': 'Dana Avenue Footway,',
#   'StreetName': 'Dana',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654d97'),
#   'FullName': 'Dana Road,',
#   'StreetName': 'Dana',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654d98'),
#   'FullName': 'Danbury Road,',
#   'StreetName': 'Danbury',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654d99'),
#   'FullName': 'Danby Street,',
#   'StreetName': 'Danby',
#   'Zipcode': '02210'},
#  {'_id': ObjectId('5ca28c251877df2493654d9a'),
#   'FullName': 'Dane Street,',
#   'StreetName': 'Dane',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654d9b'),
#   'FullName': 'Danforth Street,',
#   'StreetName': 'Danforth',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654d9c'),
#   'FullName': 'Dania Street,',
#   'StreetName': 'Dania',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654d9d'),
#   'FullName': 'Dania Terrace,',
#   'StreetName': 'Dania',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654d9e'),
#   'FullName': 'Daniel Court,',
#   'StreetName': 'Daniel',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654d9f'),
#   'FullName': 'Daniel Webster Square,',
#   'StreetName': 'Daniel',
#   'Zipcode': '02110'},
#  {'_id': ObjectId('5ca28c251877df2493654da0'),
#   'FullName': 'Danny Road,',
#   'StreetName': 'Danny',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654da1'),
#   'FullName': 'Danube Street,',
#   'StreetName': 'Danube',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654da2'),
#   'FullName': 'Danville Street,',
#   'StreetName': 'Danville',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654da3'),
#   'FullName': 'Darling Street,',
#   'StreetName': 'Darling',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654da4'),
#   'FullName': 'Darlington Street,',
#   'StreetName': 'Darlington',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654da5'),
#   'FullName': 'Dartmouth Place,',
#   'StreetName': 'Dartmouth',
#   'Zipcode': '02116'},
#  {'_id': ObjectId('5ca28c251877df2493654da6'),
#   'FullName': 'Dartmouth Street,',
#   'StreetName': 'Dartmouth',
#   'Zipcode': '02116'},
#  {'_id': ObjectId('5ca28c251877df2493654da7'),
#   'FullName': 'Davenport Street,',
#   'StreetName': 'Davenport',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654da8'),
#   'FullName': 'Davern Avenue,',
#   'StreetName': 'Davern',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654da9'),
#   'FullName': 'David Road,',
#   'StreetName': 'David',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654daa'),
#   'FullName': 'David G. Mugar Way,',
#   'StreetName': 'David',
#   'Zipcode': '02108'},
#  {'_id': ObjectId('5ca28c251877df2493654dab'),
#   'FullName': 'David Ortiz Drive,',
#   'StreetName': 'David',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654dac'),
#   'FullName': 'Davidson Avenue,',
#   'StreetName': 'Davidson',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654dad'),
#   'FullName': 'Davis Court,',
#   'StreetName': 'Davis',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654dae'),
#   'FullName': 'Davison Street,',
#   'StreetName': 'Davison',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654daf'),
#   'FullName': 'Davitt Street,',
#   'StreetName': 'Davitt',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654db0'),
#   'FullName': 'Dawes Street,',
#   'StreetName': 'Dawes',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654db1'),
#   'FullName': 'Dawes Terrace,',
#   'StreetName': 'Dawes',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654db2'),
#   'FullName': 'Day Square,',
#   'StreetName': 'Day',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654db3'),
#   'FullName': 'Day Street,',
#   'StreetName': 'Day',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654db4'),
#   'FullName': 'Dayton Street,',
#   'StreetName': 'Dayton',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654db5'),
#   'FullName': 'Deacon Street,',
#   'StreetName': 'Deacon',
#   'Zipcode': '02118'},
#  {'_id': ObjectId('5ca28c251877df2493654db6'),
#   'FullName': 'Deaconess Road,',
#   'StreetName': 'Deaconess',
#   'Zipcode': '02215'},
#  {'_id': ObjectId('5ca28c251877df2493654db7'),
#   'FullName': "Deady's Lane,",
#   'StreetName': "Deady's",
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654db8'),
#   'FullName': 'Dean Street,',
#   'StreetName': 'Dean',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654db9'),
#   'FullName': 'Dean Way',
#   'StreetName': 'Dean',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654dba'),
#   'FullName': 'Dearborn Square,',
#   'StreetName': 'Dearborn',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654dbb'),
#   'FullName': 'Dearborn Street,',
#   'StreetName': 'Dearborn',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654dbc'),
#   'FullName': 'Deblois Street,',
#   'StreetName': 'Deblois',
#   'Zipcode': '02118'},
#  {'_id': ObjectId('5ca28c251877df2493654dbd'),
#   'FullName': 'Decatur Street,',
#   'StreetName': 'Decatur',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654dbe'),
#   'FullName': 'Decatur Street,',
#   'StreetName': 'Decatur',
#   'Zipcode': '02128'},
#  {'_id': ObjectId('5ca28c251877df2493654dbf'),
#   'FullName': 'Deckard Street,',
#   'StreetName': 'Deckard',
#   'Zipcode': '02121'},
#  {'_id': ObjectId('5ca28c251877df2493654dc0'),
#   'FullName': 'Dedham Parkway,',
#   'StreetName': 'Dedham',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654dc1'),
#   'FullName': 'Dedham Street,',
#   'StreetName': 'Dedham',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654dc2'),
#   'FullName': 'Deering Road,',
#   'StreetName': 'Deering',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654dc3'),
#   'FullName': 'Deforest Street,',
#   'StreetName': 'Deforest',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654dc4'),
#   'FullName': 'Degautier Way',
#   'StreetName': 'Degautier',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654dc5'),
#   'FullName': 'Delano Court,',
#   'StreetName': 'Delano',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654dc6'),
#   'FullName': 'Delano Park',
#   'StreetName': 'Delano',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654dc7'),
#   'FullName': 'Delano Street,',
#   'StreetName': 'Delano',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654dc8'),
#   'FullName': 'Delany Circle,',
#   'StreetName': 'Delany',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654dc9'),
#   'FullName': 'Delaware Place,',
#   'StreetName': 'Delaware',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654dca'),
#   'FullName': 'Deldorf Street,',
#   'StreetName': 'Deldorf',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654dcb'),
#   'FullName': 'Delford Street,',
#   'StreetName': 'Delford',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654dcc'),
#   'FullName': 'Delhi Street,',
#   'StreetName': 'Delhi',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654dcd'),
#   'FullName': 'Dell Avenue,',
#   'StreetName': 'Dell',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654dce'),
#   'FullName': 'Dell Terrace,',
#   'StreetName': 'Dell',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654dcf'),
#   'FullName': 'Delle Avenue,',
#   'StreetName': 'Delle',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654dd0'),
#   'FullName': 'Dellmore Road,',
#   'StreetName': 'Dellmore',
#   'Zipcode': '02130'},
#  {'_id': ObjectId('5ca28c251877df2493654dd1'),
#   'FullName': 'Delmont Street,',
#   'StreetName': 'Delmont',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654dd2'),
#   'FullName': 'Delnore Place,',
#   'StreetName': 'Delnore',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654dd3'),
#   'FullName': 'Delore Circle,',
#   'StreetName': 'Delore',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654dd4'),
#   'FullName': 'Delos Street,',
#   'StreetName': 'Delos',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654dd5'),
#   'FullName': 'Denby Road,',
#   'StreetName': 'Denby',
#   'Zipcode': '02134'},
#  {'_id': ObjectId('5ca28c251877df2493654dd6'),
#   'FullName': 'Dennis Street,',
#   'StreetName': 'Dennis',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654dd7'),
#   'FullName': 'Dennison Street,',
#   'StreetName': 'Dennison',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654dd8'),
#   'FullName': 'Denny Street,',
#   'StreetName': 'Denny',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654dd9'),
#   'FullName': 'Dent Street,',
#   'StreetName': 'Dent',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654dda'),
#   'FullName': 'Denton Terrace,',
#   'StreetName': 'Denton',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654ddb'),
#   'FullName': 'Denvir Street,',
#   'StreetName': 'Denvir',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654ddc'),
#   'FullName': 'Derne Street,',
#   'StreetName': 'Derne',
#   'Zipcode': '02114'},
#  {'_id': ObjectId('5ca28c251877df2493654ddd'),
#   'FullName': 'DeRoma Road,',
#   'StreetName': 'DeRoma',
#   'Zipcode': '02132'},
#  {'_id': ObjectId('5ca28c251877df2493654dde'),
#   'FullName': 'Derry Road,',
#   'StreetName': 'Derry',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654ddf'),
#   'FullName': 'Desmond Road,',
#   'StreetName': 'Desmond',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654de0'),
#   'FullName': 'DeStefano Road,',
#   'StreetName': 'DeStefano',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654de1'),
#   'FullName': 'Devens Street,',
#   'StreetName': 'Devens',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654de2'),
#   'FullName': 'Dever Street,',
#   'StreetName': 'Dever',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654de3'),
#   'FullName': 'Dewar Street,',
#   'StreetName': 'Dewar',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654de4'),
#   'FullName': 'Dewey Street,',
#   'StreetName': 'Dewey',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654de5'),
#   'FullName': 'Dewey Terrace,',
#   'StreetName': 'Dewey',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654de6'),
#   'FullName': 'Dewitt Drive,',
#   'StreetName': 'Dewitt',
#   'Zipcode': '02120'},
#  {'_id': ObjectId('5ca28c251877df2493654de7'),
#   'FullName': 'Dexter Row',
#   'StreetName': 'Dexter',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654de8'),
#   'FullName': 'Dexter Street,',
#   'StreetName': 'Dexter',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654de9'),
#   'FullName': 'Dexter Street,',
#   'StreetName': 'Dexter',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654dea'),
#   'FullName': 'Dickens Street,',
#   'StreetName': 'Dickens',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654deb'),
#   'FullName': 'Dickinson Road,',
#   'StreetName': 'Dickinson',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654dec'),
#   'FullName': 'Dietz Court,',
#   'StreetName': 'Dietz',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654ded'),
#   'FullName': 'Dietz Road,',
#   'StreetName': 'Dietz',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654dee'),
#   'FullName': 'Dighton Street,',
#   'StreetName': 'Dighton',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654def'),
#   'FullName': 'Dimock Street,',
#   'StreetName': 'Dimock',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654df0'),
#   'FullName': 'Dingley Place,',
#   'StreetName': 'Dingley',
#   'Zipcode': '02116'},
#  {'_id': ObjectId('5ca28c251877df2493654df1'),
#   'FullName': 'Ditmus Court,',
#   'StreetName': 'Ditmus',
#   'Zipcode': '02118'},
#  {'_id': ObjectId('5ca28c251877df2493654df2'),
#   'FullName': 'Ditson Street,',
#   'StreetName': 'Ditson',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654df3'),
#   'FullName': 'Dix Street,',
#   'StreetName': 'Dix',
#   'Zipcode': '02122'},
#  {'_id': ObjectId('5ca28c251877df2493654df4'),
#   'FullName': 'Dixfield Street,',
#   'StreetName': 'Dixfield',
#   'Zipcode': '02127'},
#  {'_id': ObjectId('5ca28c251877df2493654df5'),
#   'FullName': 'Dixwell Street,',
#   'StreetName': 'Dixwell',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654df6'),
#   'FullName': 'Dock Square,',
#   'StreetName': 'Dock',
#   'Zipcode': '02109'},
#  {'_id': ObjectId('5ca28c251877df2493654df7'),
#   'FullName': 'Dodge Road,',
#   'StreetName': 'Dodge',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654df8'),
#   'FullName': 'Dolphin Way',
#   'StreetName': 'Dolphin',
#   'Zipcode': '02210'},
#  {'_id': ObjectId('5ca28c251877df2493654df9'),
#   'FullName': 'Don Street,',
#   'StreetName': 'Don',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654dfa'),
#   'FullName': 'Donald Road,',
#   'StreetName': 'Donald',
#   'Zipcode': '02124'},
#  {'_id': ObjectId('5ca28c251877df2493654dfb'),
#   'FullName': 'Doncaster Street,',
#   'StreetName': 'Doncaster',
#   'Zipcode': '02131'},
#  {'_id': ObjectId('5ca28c251877df2493654dfc'),
#   'FullName': 'Donegal Square,',
#   'StreetName': 'Donegal',
#   'Zipcode': '02113'},
#  {'_id': ObjectId('5ca28c251877df2493654dfd'),
#   'FullName': 'Donna Terrace,',
#   'StreetName': 'Donna',
#   'Zipcode': '02136'},
#  {'_id': ObjectId('5ca28c251877df2493654dfe'),
#   'FullName': 'Donnybrook Road,',
#   'StreetName': 'Donnybrook',
#   'Zipcode': '02135'},
#  {'_id': ObjectId('5ca28c251877df2493654dff'),
#   'FullName': 'Donwood Terrace,',
#   'StreetName': 'Donwood',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654e00'),
#   'FullName': 'Doone Avenue,',
#   'StreetName': 'Doone',
#   'Zipcode': '02126'},
#  {'_id': ObjectId('5ca28c251877df2493654e01'),
#   'FullName': 'Doris Street,',
#   'StreetName': 'Doris',
#   'Zipcode': '02125'},
#  {'_id': ObjectId('5ca28c251877df2493654e02'),
#   'FullName': 'Dorr Street,',
#   'StreetName': 'Dorr',
#   'Zipcode': '02119'},
#  {'_id': ObjectId('5ca28c251877df2493654e03'),
#   'FullName': 'Dorrance Street,',
#   'StreetName': 'Dorrance',
#   'Zipcode': '02129'},
#  {'_id': ObjectId('5ca28c251877df2493654e04'),
#   'FullName': 'Dorset Street,',
#   'StreetName': 'Dorset',
#   'Zipcode': '02125'},
#  ...]

# %%
repo.logout()
endTime = datetime.datetime.now()
{"start":startTime, "end":endTime}
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Database.logout() is deprecated
#   """Entry point for launching an IPython kernel.
# {'start': datetime.datetime(2019, 4, 1, 18, 9, 27, 37921),
#  'end': datetime.datetime(2019, 4, 1, 18, 9, 46, 342469)}

# %%
doc = prov.model.ProvDocument()
startTime = None
endTime = None
client = dml.pymongo.MongoClient()
repo = client.repo
repo.authenticate(contributor, contributor)

doc.add_namespace('alg', 'http://datamechanics.io/algorithm/') # The scripts are in <folder>#<filename> format.
doc.add_namespace('dat', 'http://datamechanics.io/data/') # The data sets are in <user>#<collection> format.
doc.add_namespace('ont', 'http://datamechanics.io/ontology#') # 'Extension', 'DataResource', 'DataSet', 'Retrieval', 'Query', or 'Computation'.
doc.add_namespace('log', 'http://datamechanics.io/log/') # The event log.
doc.add_namespace('bdp', 'https://www.50states.com/bio/mass.htm')

this_script = doc.agent('alg:'+contributor+'#filter_Streetbook_version_1', {prov.model.PROV_TYPE:prov.model.PROV['SoftwareAgent'], 'ont:Extension':'py'})
resource = doc.entity('bdp:wc8w-nujj', {'prov:label':'311, Service Requests', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
get_names = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime)
doc.wasAssociatedWith(get_names, this_script)
doc.usage(get_names, resource, startTime, None,
    {prov.model.PROV_TYPE:'ont:Retrieval',
    'ont:Computation':'Data cleaning'
    }
)

fp = doc.entity('dat:'+contributor+'#filter_Streetbook_version_1', {prov.model.PROV_LABEL:'filter_Streetbook_version_1', prov.model.PROV_TYPE:'ont:DataSet'})
doc.wasAttributedTo(fp, this_script)
doc.wasGeneratedBy(fp, get_names, endTime)
doc.wasDerivedFrom(fp, resource, get_names, get_names, get_names)

repo.logout()
doc
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: DeprecationWarning: Database.logout() is deprecated

# %%
print(doc.get_provn())
print(json.dumps(json.loads(doc.serialize()), indent=4))
# Out:
# document
#   prefix alg <http://datamechanics.io/algorithm/>
#   prefix dat <http://datamechanics.io/data/>
#   prefix ont <http://datamechanics.io/ontology#>
#   prefix log <http://datamechanics.io/log/>
#   prefix bdp <https://www.50states.com/bio/mass.htm>
#
#   agent(alg:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1, [prov:type='prov:SoftwareAgent', ont:Extension="py"])
#   entity(bdp:wc8w-nujj, [prov:label="311, Service Requests", prov:type="ont:DataResource", ont:Extension="json"])
#   activity(log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a, -, -)
#   wasAssociatedWith(log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a, alg:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1, -)
#   used(log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a, bdp:wc8w-nujj, -, [prov:type="ont:Retrieval", ont:Computation="Data cleaning"])
#   entity(dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1, [prov:label="filter_Streetbook_version_1", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1, alg:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1)
#   wasGeneratedBy(dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1, log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a, -)
#   wasDerivedFrom(dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1, bdp:wc8w-nujj, log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a, log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a, log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a)
# endDocument
# {
#     "prefix": {
#         "alg": "http://datamechanics.io/algorithm/",
#         "dat": "http://datamechanics.io/data/",
#         "ont": "http://datamechanics.io/ontology#",
#         "log": "http://datamechanics.io/log/",
#         "bdp": "https://www.50states.com/bio/mass.htm"
#     },
#     "agent": {
#         "alg:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1": {
#             "prov:type": {
#                 "$": "prov:SoftwareAgent",
#                 "type": "prov:QUALIFIED_NAME"
#             },
#             "ont:Extension": "py"
#         }
#     },
#     "entity": {
#         "bdp:wc8w-nujj": {
#             "prov:label": "311, Service Requests",
#             "prov:type": "ont:DataResource",
#             "ont:Extension": "json"
#         },
#         "dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1": {
#             "prov:label": "filter_Streetbook_version_1",
#             "prov:type": "ont:DataSet"
#         }
#     },
#     "activity": {
#         "log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a": {}
#     },
#     "wasAssociatedWith": {
#         "_:id1": {
#             "prov:activity": "log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a",
#             "prov:agent": "alg:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1"
#         }
#     },
#     "used": {
#         "_:id2": {
#             "prov:activity": "log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a",
#             "prov:entity": "bdp:wc8w-nujj",
#             "prov:type": "ont:Retrieval",
#             "ont:Computation": "Data cleaning"
#         }
#     },
#     "wasAttributedTo": {
#         "_:id3": {
#             "prov:entity": "dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1",
#             "prov:agent": "alg:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1"
#         }
#     },
#     "wasGeneratedBy": {
#         "_:id4": {
#             "prov:entity": "dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1",
#             "prov:activity": "log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a"
#         }
#     },
#     "wasDerivedFrom": {
#         "_:id5": {
#             "prov:generatedEntity": "dat:mmao95_Dongyihe_weijiang_zhukk#filter_Streetbook_version_1",
#             "prov:usedEntity": "bdp:wc8w-nujj",
#             "prov:activity": "log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a",
#             "prov:generation": "log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a",
#             "prov:usage": "log:uuid0f1c19df-2cd9-4c57-af2b-e8eef5a6273a"
#         }
#     }
# }
